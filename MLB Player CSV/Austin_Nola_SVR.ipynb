# %%
#import packages
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

#import data
col_list = ["Age", "AVG"]
dataset = pd.read_csv('PadresBatters.csv', usecols=col_list)
X = dataset.iloc[51:53, :-1].values
y = dataset.iloc[51:53, -1].values

print(X)
# Out:
# [[29]
#  [30]]

# %%
y_train = y
y_test = y
X_test = X
X_train = X

#reshape y 
y = y.reshape(len(y),1)

#Feature scaling the data
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
sc_y = StandardScaler()
X = sc_X.fit_transform(X)
y = sc_y.fit_transform(y)

#Train the SVR
from sklearn.svm import SVR
regressor = SVR(kernel = 'rbf')
regressor.fit(X, y)

#Predict a new result
print("Batting AVG for 2021: ", sc_y.inverse_transform(regressor.predict(sc_X.transform([[31]]))))

y_pred = sc_y.inverse_transform(regressor.predict(sc_X.transform(X_test)))
np.set_printoptions(precision=3)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))

from sklearn.metrics import mean_squared_error
print(mean_squared_error(y_test, y_pred))


X_grid = np.arange(min(sc_X.inverse_transform(X)), max(sc_X.inverse_transform(X)), 0.1)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(sc_X.inverse_transform(X), sc_y.inverse_transform(y), color = 'red')
plt.plot(X_grid, sc_y.inverse_transform(regressor.predict(sc_X.transform(X_grid))), color = 'blue')
plt.title('AVG (SVR)')
plt.xlabel('Age')
plt.ylabel('AVG')
plt.show()
# Out:
# Batting AVG for 2021:  [0.27103358]
# [[0.269 0.269]
#  [0.273 0.273]]
# 3.9999999664015495e-08
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)

# %%
#import data
col_list = ["Age", "SLG"]
dataset = pd.read_csv('PadresBatters.csv', usecols=col_list)
X = dataset.iloc[51:53, :-1].values
y = dataset.iloc[51:53, -1].values

y_train = y
y_test = y
X_test = X
X_train = X

#reshape y 
y = y.reshape(len(y),1)

#Feature scaling the data
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
sc_y = StandardScaler()
X = sc_X.fit_transform(X)
y = sc_y.fit_transform(y)

#Train the SVR
from sklearn.svm import SVR
regressor = SVR(kernel = 'rbf')
regressor.fit(X, y)

#Predict a new result
print("SLG for 2021: ", sc_y.inverse_transform(regressor.predict(sc_X.transform([[27]]))))

y_pred = sc_y.inverse_transform(regressor.predict(sc_X.transform(X_test)))
np.set_printoptions(precision=3)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))

from sklearn.metrics import mean_squared_error
print(mean_squared_error(y_test, y_pred))


X_grid = np.arange(min(sc_X.inverse_transform(X)), max(sc_X.inverse_transform(X)), 0.1)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(sc_X.inverse_transform(X), sc_y.inverse_transform(y), color = 'red')
plt.plot(X_grid, sc_y.inverse_transform(regressor.predict(sc_X.transform(X_grid))), color = 'blue')
plt.title('SLG (SVR)')
plt.xlabel('Age')
plt.ylabel('SLG')
plt.show()
# Out:
# SLG for 2021:  [0.463]
# [[0.455 0.454]
#  [0.471 0.472]]
# 8.099999931962638e-07
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)

# %%
#import data
col_list = ["Age", "OBP"]
dataset = pd.read_csv('PadresBatters.csv', usecols=col_list)
X = dataset.iloc[51:53, :-1].values
y = dataset.iloc[51:53, -1].values
y_train = y
y_test = y
X_test = X
X_train = X

#reshape y 
y = y.reshape(len(y),1)

#Feature scaling the data
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
sc_y = StandardScaler()
X = sc_X.fit_transform(X)
y = sc_y.fit_transform(y)

#Train the SVR
from sklearn.svm import SVR
regressor = SVR(kernel = 'rbf')
regressor.fit(X, y)

#Predict a new result
print("OBP for 2021: ", sc_y.inverse_transform(regressor.predict(sc_X.transform([[31]]))))

y_pred = sc_y.inverse_transform(regressor.predict(sc_X.transform(X_test)))
np.set_printoptions(precision=3)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))

from sklearn.metrics import mean_squared_error
print(mean_squared_error(y_test, y_pred))


X_grid = np.arange(min(sc_X.inverse_transform(X)), max(sc_X.inverse_transform(X)), 0.1)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(sc_X.inverse_transform(X), sc_y.inverse_transform(y), color = 'red')
plt.plot(X_grid, sc_y.inverse_transform(regressor.predict(sc_X.transform(X_grid))), color = 'blue')
plt.title('OBP (SVR)')
plt.xlabel('Age')
plt.ylabel('OBP')
plt.show()
# Out:
# OBP for 2021:  [0.348]
# [[0.343 0.342]
#  [0.352 0.353]]
# 3.0249999745907143e-07
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)

# %%
#import data
col_list = ["Age", "OPS"]
dataset = pd.read_csv('PadresBatters.csv', usecols=col_list)
X = dataset.iloc[51:53, :-1].values
y = dataset.iloc[51:53, -1].values

y_train = y
y_test = y
X_test = X
X_train = X

#reshape y 
y = y.reshape(len(y),1)

#Feature scaling the data
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
sc_y = StandardScaler()
X = sc_X.fit_transform(X)
y = sc_y.fit_transform(y)

#Train the SVR
from sklearn.svm import SVR
regressor = SVR(kernel = 'rbf')
regressor.fit(X, y)

#Predict a new result
print("OPS for 2021: ", sc_y.inverse_transform(regressor.predict(sc_X.transform([[31]]))))

y_pred = sc_y.inverse_transform(regressor.predict(sc_X.transform(X_test)))
np.set_printoptions(precision=3)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))

from sklearn.metrics import mean_squared_error
print(mean_squared_error(y_test, y_pred))


X_grid = np.arange(min(sc_X.inverse_transform(X)), max(sc_X.inverse_transform(X)), 0.1)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(sc_X.inverse_transform(X), sc_y.inverse_transform(y), color = 'red')
plt.plot(X_grid, sc_y.inverse_transform(regressor.predict(sc_X.transform(X_grid))), color = 'blue')
plt.title('OPS (SVR)')
plt.xlabel('Age')
plt.ylabel('OPS')
plt.show()
# Out:
# OPS for 2021:  [0.811]
# [[0.797 0.796]
#  [0.824 0.825]]
# 2.1024999823394526e-06
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)

# %%
#import data
col_list = ["Age", "%G"]
dataset = pd.read_csv('PadresBatters.csv', usecols=col_list)
X = dataset.iloc[51:53, :-1].values
y = dataset.iloc[51:53, -1].values

y_train = y
y_test = y
X_test = X
X_train = X

#reshape y 
y = y.reshape(len(y),1)

#Feature scaling the data
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
sc_y = StandardScaler()
X = sc_X.fit_transform(X)
y = sc_y.fit_transform(y)

#Train the SVR
from sklearn.svm import SVR
regressor = SVR(kernel = 'rbf')
regressor.fit(X, y)

#Predict a new result
print(" %G for 2021: ", sc_y.inverse_transform(regressor.predict(sc_X.transform([[31]]))))


y_pred = sc_y.inverse_transform(regressor.predict(sc_X.transform(X_test)))
np.set_printoptions(precision=3)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))

from sklearn.metrics import mean_squared_error
print(mean_squared_error(y_test, y_pred))


X_grid = np.arange(min(sc_X.inverse_transform(X)), max(sc_X.inverse_transform(X)), 0.1)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(sc_X.inverse_transform(X), sc_y.inverse_transform(y), color = 'red')
plt.plot(X_grid, sc_y.inverse_transform(regressor.predict(sc_X.transform(X_grid))), color = 'blue')
plt.title('%G (SVR)')
plt.xlabel('Age')
plt.ylabel('%G')
plt.show()
# Out:
#  %G for 2021:  [0.646]
# [[0.503 0.488]
#  [0.784 0.8  ]]
# 0.00024389955592624187
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)

# %%
print(.646 * 162, ' Games Played')
# Out:
# 104.652  Games Played

# %%
#import data
col_list = ["Age", "PA/G"]
dataset = pd.read_csv('PadresBatters.csv', usecols=col_list)
X = dataset.iloc[51:53, :-1].values
y = dataset.iloc[51:53, -1].values

y_train = y
y_test = y
X_test = X
X_train = X

#reshape y 
y = y.reshape(len(y),1)

#Feature scaling the data
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
sc_y = StandardScaler()
X = sc_X.fit_transform(X)
y = sc_y.fit_transform(y)

#Train the SVR
from sklearn.svm import SVR
regressor = SVR(kernel = 'rbf')
regressor.fit(X, y)

#Predict a new result
print(" PA/G for 2021: ", sc_y.inverse_transform(regressor.predict(sc_X.transform([[31]]))))


y_pred = sc_y.inverse_transform(regressor.predict(sc_X.transform(X_test)))
np.set_printoptions(precision=3)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))

from sklearn.metrics import mean_squared_error
print(mean_squared_error(y_test, y_pred))


X_grid = np.arange(min(sc_X.inverse_transform(X)), max(sc_X.inverse_transform(X)), 0.1)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(sc_X.inverse_transform(X), sc_y.inverse_transform(y), color = 'red')
plt.plot(X_grid, sc_y.inverse_transform(regressor.predict(sc_X.transform(X_grid))), color = 'blue')
plt.title('PA/G (SVR)')
plt.xlabel('Age')
plt.ylabel('PA/G')
plt.show()
# Out:
#  PA/G for 2021:  [3.61]
# [[3.402 3.38 ]
#  [3.811 3.833]]
# 0.0005143517735993431
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)

# %%
print(3.61 * 105, "PA")
# Out:
# 379.05 PA

# %%
#import data
col_list = ["Age", "HR/G"]
dataset = pd.read_csv('PadresBatters.csv', usecols=col_list)
X = dataset.iloc[51:53, :-1].values
y = dataset.iloc[51:53, -1].values

y_train = y
y_test = y
X_test = X
X_train = X

#reshape y 
y = y.reshape(len(y),1)

#Feature scaling the data
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
sc_y = StandardScaler()
X = sc_X.fit_transform(X)
y = sc_y.fit_transform(y)

#Train the SVR
from sklearn.svm import SVR
regressor = SVR(kernel = 'rbf')
regressor.fit(X, y)

#Predict a new result
print(" HR/G for 2021: ", sc_y.inverse_transform(regressor.predict(sc_X.transform([[31]]))))


y_pred = sc_y.inverse_transform(regressor.predict(sc_X.transform(X_test)))
np.set_printoptions(precision=3)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))

from sklearn.metrics import mean_squared_error
print(mean_squared_error(y_test, y_pred))


X_grid = np.arange(min(sc_X.inverse_transform(X)), max(sc_X.inverse_transform(X)), 0.1)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(sc_X.inverse_transform(X), sc_y.inverse_transform(y), color = 'red')
plt.plot(X_grid, sc_y.inverse_transform(regressor.predict(sc_X.transform(X_grid))), color = 'blue')
plt.title('HR/G (SVR)')
plt.xlabel('Age')
plt.ylabel('HR')
plt.show()
# Out:
#  HR/G for 2021:  [0.136]
# [[0.128 0.127]
#  [0.145 0.146]]
# 9.265077887501549e-07
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)

# %%
print(.136 * 105, " HRs")
# Out:
# 14.280000000000001  HRs

# %%
#import data
col_list = ["Age", "RBI/G"]
dataset = pd.read_csv('PadresBatters.csv', usecols=col_list)
X = dataset.iloc[51:53, :-1].values
y = dataset.iloc[51:53, -1].values

y_train = y
y_test = y
X_test = X
X_train = X

#reshape y 
y = y.reshape(len(y),1)

#Feature scaling the data
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
sc_y = StandardScaler()
X = sc_X.fit_transform(X)
y = sc_y.fit_transform(y)

#Train the SVR
from sklearn.svm import SVR
regressor = SVR(kernel = 'rbf')
regressor.fit(X, y)

#Predict a new result
print(" RBI/G for 2021: ", sc_y.inverse_transform(regressor.predict(sc_X.transform([[31]]))))


y_pred = sc_y.inverse_transform(regressor.predict(sc_X.transform(X_test)))
np.set_printoptions(precision=3)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))

from sklearn.metrics import mean_squared_error
print(mean_squared_error(y_test, y_pred))


X_grid = np.arange(min(sc_X.inverse_transform(X)), max(sc_X.inverse_transform(X)), 0.1)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(sc_X.inverse_transform(X), sc_y.inverse_transform(y), color = 'red')
plt.plot(X_grid, sc_y.inverse_transform(regressor.predict(sc_X.transform(X_grid))), color = 'blue')
plt.title('RBI/G (SVR)')
plt.xlabel('Age')
plt.ylabel('RBI/G')
plt.show()
# Out:
#  RBI/G for 2021:  [0.489]
# [[0.402 0.392]
#  [0.574 0.583]]
# 9.113400994748303e-05
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)

# %%
print(.489 * 105, " RBIs")
# Out:
# 51.345  RBIs

# %%
#import data
col_list = ["Age", "R/G"]
dataset = pd.read_csv('PadresBatters.csv', usecols=col_list)
X = dataset.iloc[51:53, :-1].values
y = dataset.iloc[51:53, -1].values

y_train = y
y_test = y
X_test = X
X_train = X

#reshape y 
y = y.reshape(len(y),1)

#Feature scaling the data
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
sc_y = StandardScaler()
X = sc_X.fit_transform(X)
y = sc_y.fit_transform(y)

#Train the SVR
from sklearn.svm import SVR
regressor = SVR(kernel = 'rbf')
regressor.fit(X, y)

#Predict a new result
print(" R/G for 2021: ", sc_y.inverse_transform(regressor.predict(sc_X.transform([[31]]))))


y_pred = sc_y.inverse_transform(regressor.predict(sc_X.transform(X_test)))
np.set_printoptions(precision=3)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))

from sklearn.metrics import mean_squared_error
print(mean_squared_error(y_test, y_pred))


X_grid = np.arange(min(sc_X.inverse_transform(X)), max(sc_X.inverse_transform(X)), 0.1)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(sc_X.inverse_transform(X), sc_y.inverse_transform(y), color = 'red')
plt.plot(X_grid, sc_y.inverse_transform(regressor.predict(sc_X.transform(X_grid))), color = 'blue')
plt.title('R/G (SVR)')
plt.xlabel('Age')
plt.ylabel('R/G')
plt.show()
# Out:
#  R/G for 2021:  [0.484]
# [[0.47  0.468]
#  [0.498 0.5  ]]
# 2.5036052305327657e-06
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)

# %%
print(.484 * 105, " runs")
# Out:
# 50.82  runs

# %%
#import data
col_list = ["Age", "SB/G"]
dataset = pd.read_csv('PadresBatters.csv', usecols=col_list)
X = dataset.iloc[51:53, :-1].values
y = dataset.iloc[51:53, -1].values

y_train = y
y_test = y
X_test = X
X_train = X

#reshape y 
y = y.reshape(len(y),1)

#Feature scaling the data
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
sc_y = StandardScaler()
X = sc_X.fit_transform(X)
y = sc_y.fit_transform(y)

#Train the SVR
from sklearn.svm import SVR
regressor = SVR(kernel = 'rbf')
regressor.fit(X, y)

#Predict a new result
print(" SB/G for 2021: ", sc_y.inverse_transform(regressor.predict(sc_X.transform([[31]]))))


y_pred = sc_y.inverse_transform(regressor.predict(sc_X.transform(X_test)))
np.set_printoptions(precision=3)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))

from sklearn.metrics import mean_squared_error
print(mean_squared_error(y_test, y_pred))


X_grid = np.arange(min(sc_X.inverse_transform(X)), max(sc_X.inverse_transform(X)), 0.1)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(sc_X.inverse_transform(X), sc_y.inverse_transform(y), color = 'red')
plt.plot(X_grid, sc_y.inverse_transform(regressor.predict(sc_X.transform(X_grid))), color = 'blue')
plt.title('SB/G (SVR)')
plt.xlabel('Age')
plt.ylabel('SB/G')
plt.show()
# Out:
#  SB/G for 2021:  [0.006]
# [[0.012 0.013]
#  [0.001 0.   ]]
# 4.0057683688522885e-07
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)

# %%
print(.006 * 105, " SBs")
# Out:
# 0.63  SBs

# %%
#import data
col_list = ["Age", "2B/G"]
dataset = pd.read_csv('PadresBatters.csv', usecols=col_list)
X = dataset.iloc[51:53, :-1].values
y = dataset.iloc[51:53, -1].values

y_train = y
y_test = y
X_test = X
X_train = X

#reshape y 
y = y.reshape(len(y),1)

#Feature scaling the data
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
sc_y = StandardScaler()
X = sc_X.fit_transform(X)
y = sc_y.fit_transform(y)

#Train the SVR
from sklearn.svm import SVR
regressor = SVR(kernel = 'rbf')
regressor.fit(X, y)

#Predict a new result
print(" 2B/G for 2021: ", sc_y.inverse_transform(regressor.predict(sc_X.transform([[31]]))))


y_pred = sc_y.inverse_transform(regressor.predict(sc_X.transform(X_test)))
np.set_printoptions(precision=3)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))

from sklearn.metrics import mean_squared_error
print(mean_squared_error(y_test, y_pred))


X_grid = np.arange(min(sc_X.inverse_transform(X)), max(sc_X.inverse_transform(X)), 0.1)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(sc_X.inverse_transform(X), sc_y.inverse_transform(y), color = 'red')
plt.plot(X_grid, sc_y.inverse_transform(regressor.predict(sc_X.transform(X_grid))), color = 'blue')
plt.title('2B/G (SVR)')
plt.xlabel('Age')
plt.ylabel('2B/G')
plt.show()
# Out:
#  2B/G for 2021:  [0.17]
# [[0.154 0.152]
#  [0.186 0.188]]
# 3.168625325391297e-06
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)

# %%
print(.17 * 105, " 2Bs")
# Out:
# 17.85  2Bs

# %%
#import data
col_list = ["Age", "3B/G"]
dataset = pd.read_csv('PadresBatters.csv', usecols=col_list)
X = dataset.iloc[51:53, :-1].values
y = dataset.iloc[51:53, -1].values

y_train = y
y_test = y
X_test = X
X_train = X

#reshape y 
y = y.reshape(len(y),1)

#Feature scaling the data
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
sc_y = StandardScaler()
X = sc_X.fit_transform(X)
y = sc_y.fit_transform(y)

#Train the SVR
from sklearn.svm import SVR
regressor = SVR(kernel = 'rbf')
regressor.fit(X, y)

#Predict a new result
print(" 3B/G for 2021: ", sc_y.inverse_transform(regressor.predict(sc_X.transform([[31]]))))


y_pred = sc_y.inverse_transform(regressor.predict(sc_X.transform(X_test)))
np.set_printoptions(precision=3)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))

from sklearn.metrics import mean_squared_error
print(mean_squared_error(y_test, y_pred))


X_grid = np.arange(min(sc_X.inverse_transform(X)), max(sc_X.inverse_transform(X)), 0.1)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(sc_X.inverse_transform(X), sc_y.inverse_transform(y), color = 'red')
plt.plot(X_grid, sc_y.inverse_transform(regressor.predict(sc_X.transform(X_grid))), color = 'blue')
plt.title('3B/G (SVR)')
plt.xlabel('Age')
plt.ylabel('3B/G')
plt.show()
# Out:
#  3B/G for 2021:  [0.017]
# [[0.013 0.013]
#  [0.02  0.021]]
# 1.6708085299913122e-07
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)

# %%
print(.017 * 105, " 3Bs")
# Out:
# 1.7850000000000001  3Bs

# %%
#import data
col_list = ["Age", "BB/G"]
dataset = pd.read_csv('PadresBatters.csv', usecols=col_list)
X = dataset.iloc[51:53, :-1].values
y = dataset.iloc[51:53, -1].values

y_train = y
y_test = y
X_test = X
X_train = X

#reshape y 
y = y.reshape(len(y),1)

#Feature scaling the data
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
sc_y = StandardScaler()
X = sc_X.fit_transform(X)
y = sc_y.fit_transform(y)

#Train the SVR
from sklearn.svm import SVR
regressor = SVR(kernel = 'rbf')
regressor.fit(X, y)

#Predict a new result
print(" BB/G for 2021: ", sc_y.inverse_transform(regressor.predict(sc_X.transform([[31]]))))


y_pred = sc_y.inverse_transform(regressor.predict(sc_X.transform(X_test)))
np.set_printoptions(precision=3)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))

from sklearn.metrics import mean_squared_error
print(mean_squared_error(y_test, y_pred))


X_grid = np.arange(min(sc_X.inverse_transform(X)), max(sc_X.inverse_transform(X)), 0.1)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(sc_X.inverse_transform(X), sc_y.inverse_transform(y), color = 'red')
plt.plot(X_grid, sc_y.inverse_transform(regressor.predict(sc_X.transform(X_grid))), color = 'blue')
plt.title('BB/G (SVR)')
plt.xlabel('Age')
plt.ylabel('BB/G')
# Out:
#  BB/G for 2021:  [0.334]
# [[0.295 0.291]
#  [0.371 0.375]]
# 1.7581567102460084e-05
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# Text(0, 0.5, 'BB/G')

# %%
print(.334 * 105, ' BBs')
# Out:
# 35.07  BBs

# %%
#import data
col_list = ["Age", "SO/G"]
dataset = pd.read_csv('PadresBatters.csv', usecols=col_list)
X = dataset.iloc[51:53, :-1].values
y = dataset.iloc[51:53, -1].values

y_train = y
y_test = y
X_test = X
X_train = X

#reshape y 
y = y.reshape(len(y),1)

#Feature scaling the data
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
sc_y = StandardScaler()
X = sc_X.fit_transform(X)
y = sc_y.fit_transform(y)

#Train the SVR
from sklearn.svm import SVR
regressor = SVR(kernel = 'rbf')
regressor.fit(X, y)

#Predict a new result
print(" SO/G for 2021: ", sc_y.inverse_transform(regressor.predict(sc_X.transform([[31]]))))


y_pred = sc_y.inverse_transform(regressor.predict(sc_X.transform(X_test)))
np.set_printoptions(precision=3)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))

from sklearn.metrics import mean_squared_error
print(mean_squared_error(y_test, y_pred))


X_grid = np.arange(min(sc_X.inverse_transform(X)), max(sc_X.inverse_transform(X)), 0.1)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(sc_X.inverse_transform(X), sc_y.inverse_transform(y), color = 'red')
plt.plot(X_grid, sc_y.inverse_transform(regressor.predict(sc_X.transform(X_grid))), color = 'blue')
plt.title('SO/G (SVR)')
plt.xlabel('Age')
plt.ylabel('SO/G')
# Out:
#  SO/G for 2021:  [0.752]
# [[0.793 0.797]
#  [0.713 0.708]]
# 1.9862629754835767e-05
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# Text(0, 0.5, 'SO/G')

# %%
print(.752 * 105, ' SOs')
# Out:
# 78.96  SOs
