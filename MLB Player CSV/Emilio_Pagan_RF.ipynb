# %%
#import packages
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

#import data
col_list = ["Name","Age", "ERA"]
dataset = pd.read_csv('PadresRelievers.csv', usecols=col_list)
X = dataset.iloc[25:29, :-1].values
y = dataset.iloc[25:29, -1].values

print(X)
# Out:
# [['Emilio Pagan' 26]
#  ['Emilio Pagan' 27]
#  ['Emilio Pagan' 28]
#  ['Emilio Pagan' 29]]

# %%
#import data
col_list = ["Age", "ERA"]
dataset = pd.read_csv('PadresRelievers.csv', usecols=col_list)
X = dataset.iloc[25:29, :-1].values
y = dataset.iloc[25:29, -1].values

from sklearn.model_selection import train_test_split
X_train = X
X_test = X
y_train = y
y_test = y

from sklearn.ensemble import RandomForestRegressor
regressor = RandomForestRegressor(n_estimators = 10, random_state = 0)
regressor.fit(X_train, y_train)

y_pred = regressor.predict(X_test)
np.set_printoptions(precision=2)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))

X_grid = np.arange(min(X), max(X), 0.01)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(X, y, color = 'red')
plt.plot(X_grid, regressor.predict(X_grid), color = 'blue')
plt.title('ERA (Random Forest Regression)')
plt.xlabel('Age')
plt.ylabel('ERA')
plt.show()

#reshape y 
y = y.reshape(len(y),1)

from sklearn.metrics import mean_squared_error
print("MSE: " , mean_squared_error(y_test, y_pred))

from sklearn.metrics import r2_score
print("R2 Score: " , r2_score(y_test, y_pred))

print("Predicted ERA in 2021: " ,regressor.predict([[30]]))
# Out:
# [[3.58 3.22]
#  [4.03 4.35]
#  [3.13 2.31]
#  [4.27 4.5 ]]
# MSE:  0.2378554999999999
# R2 Score:  0.7008953440850074
# Predicted ERA in 2021:  [4.27]

# %%
#import data
col_list = ["Age", "WHIP"]
dataset = pd.read_csv('PadresRelievers.csv', usecols=col_list)
X = dataset.iloc[25:29, :-1].values
y = dataset.iloc[25:29, -1].values

from sklearn.model_selection import train_test_split
X_train = X
X_test = X
y_train = y
y_test = y

from sklearn.ensemble import RandomForestRegressor
regressor = RandomForestRegressor(n_estimators = 10, random_state = 0)
regressor.fit(X_train, y_train)

y_pred = regressor.predict(X_test)
np.set_printoptions(precision=2)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))

X_grid = np.arange(min(X), max(X), 0.01)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(X, y, color = 'red')
plt.plot(X_grid, regressor.predict(X_grid), color = 'blue')
plt.title('WHIP (Random Forest Regression)')
plt.xlabel('Age')
plt.ylabel('WHIP')
plt.show()

#reshape y 
y = y.reshape(len(y),1)

from sklearn.metrics import mean_squared_error
print("MSE: " , mean_squared_error(y_test, y_pred))

from sklearn.metrics import r2_score
print("R2 Score: " , r2_score(y_test, y_pred))

print("Predicted WHIP in 2021: " ,regressor.predict([[30]]))
# Out:
# [[1.02 0.93]
#  [1.13 1.19]
#  [0.97 0.83]
#  [1.04 1.05]]
# MSE:  0.008369999999999997
# R2 Score:  0.5375690607734808
# Predicted WHIP in 2021:  [1.04]

# %%
#import data
col_list = ["Age", "AVG"]
dataset = pd.read_csv('PadresRelievers.csv', usecols=col_list)
X = dataset.iloc[25:29, :-1].values
y = dataset.iloc[25:29, -1].values

from sklearn.model_selection import train_test_split
X_train = X
X_test = X
y_train = y
y_test = y

from sklearn.ensemble import RandomForestRegressor
regressor = RandomForestRegressor(n_estimators = 10, random_state = 0)
regressor.fit(X_train, y_train)

y_pred = regressor.predict(X_test)
np.set_printoptions(precision=2)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))

X_grid = np.arange(min(X), max(X), 0.01)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(X, y, color = 'red')
plt.plot(X_grid, regressor.predict(X_grid), color = 'blue')
plt.title('AVG (Random Forest Regression)')
plt.xlabel('Age')
plt.ylabel('AVG')
plt.show()

#reshape y 
y = y.reshape(len(y),1)

from sklearn.metrics import mean_squared_error
print("MSE: " , mean_squared_error(y_test, y_pred))

from sklearn.metrics import r2_score
print("R2 Score: " , r2_score(y_test, y_pred))

print("Predicted AVG in 2021: " ,regressor.predict([[30]]))
# Out:
# [[0.21 0.21]
#  [0.22 0.23]
#  [0.2  0.18]
#  [0.18 0.18]]
# MSE:  0.00012864749999999967
# R2 Score:  0.7204454705962249
# Predicted AVG in 2021:  [0.18]

# %%
#import data
col_list = ["Age", "GS"]
dataset = pd.read_csv('PadresRelievers.csv', usecols=col_list)
X = dataset.iloc[25:29, :-1].values
y = dataset.iloc[25:29, -1].values

from sklearn.model_selection import train_test_split
X_train = X
X_test = X
y_train = y
y_test = y

from sklearn.ensemble import RandomForestRegressor
regressor = RandomForestRegressor(n_estimators = 10, random_state = 0)
regressor.fit(X_train, y_train)

y_pred = regressor.predict(X_test)
np.set_printoptions(precision=2)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))

X_grid = np.arange(min(X), max(X), 0.01)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(X, y, color = 'red')
plt.plot(X_grid, regressor.predict(X_grid), color = 'blue')
plt.title('GS (Random Forest Regression)')
plt.xlabel('Age')
plt.ylabel('GS')
plt.show()

#reshape y 
y = y.reshape(len(y),1)

from sklearn.metrics import mean_squared_error
print("MSE: " , mean_squared_error(y_test, y_pred))

from sklearn.metrics import r2_score
print("R2 Score: " , r2_score(y_test, y_pred))

print("Predicted GS in 2021: " ,regressor.predict([[30]]))
# Out:
# [[0. 0.]
#  [0. 0.]
#  [0. 0.]
#  [0. 0.]]
# MSE:  0.0
# R2 Score:  1.0
# Predicted GS in 2021:  [0.]

# %%
#import data
col_list = ["Age", "ADJ_IP"]
dataset = pd.read_csv('PadresRelievers.csv', usecols=col_list)
X = dataset.iloc[25:29, :-1].values
y = dataset.iloc[25:29, -1].values

from sklearn.model_selection import train_test_split
X_train = X
X_test = X
y_train = y
y_test = y

from sklearn.ensemble import RandomForestRegressor
regressor = RandomForestRegressor(n_estimators = 10, random_state = 0)
regressor.fit(X_train, y_train)

y_pred = regressor.predict(X_test)
np.set_printoptions(precision=2)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))

X_grid = np.arange(min(X), max(X), 0.01)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(X, y, color = 'red')
plt.plot(X_grid, regressor.predict(X_grid), color = 'blue')
plt.title('ADJ_IP (Random Forest Regression)')
plt.xlabel('Age')
plt.ylabel('IP')
plt.show()

#reshape y 
y = y.reshape(len(y),1)

from sklearn.metrics import mean_squared_error
print("MSE: " , mean_squared_error(y_test, y_pred))

from sklearn.metrics import r2_score
print("R2 Score: " , r2_score(y_test, y_pred))

print("Predicted IP in 2021: " ,regressor.predict([[30]]))
# Out:
# [[56.85 50.1 ]
#  [61.61 62.  ]
#  [66.8  70.  ]
#  [60.72 59.4 ]]
# MSE:  14.424249999999999
# R2 Score:  0.7140988318075394
# Predicted IP in 2021:  [60.72]

# %%
#import data
col_list = ["Age", "K/9"]
dataset = pd.read_csv('PadresRelievers.csv', usecols=col_list)
X = dataset.iloc[25:29, :-1].values
y = dataset.iloc[25:29, -1].values

from sklearn.model_selection import train_test_split
X_train = X
X_test = X
y_train = y
y_test = y

from sklearn.ensemble import RandomForestRegressor
regressor = RandomForestRegressor(n_estimators = 10, random_state = 0)
regressor.fit(X_train, y_train)

y_pred = regressor.predict(X_test)
np.set_printoptions(precision=2)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))

X_grid = np.arange(min(X), max(X), 0.01)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(X, y, color = 'red')
plt.plot(X_grid, regressor.predict(X_grid), color = 'blue')
plt.title('K/9 (Random Forest Regression)')
plt.xlabel('Age')
plt.ylabel('K/9')
plt.show()

#reshape y 
y = y.reshape(len(y),1)

from sklearn.metrics import mean_squared_error
print("MSE: " , mean_squared_error(y_test, y_pred))

from sklearn.metrics import r2_score
print("R2 Score: " , r2_score(y_test, y_pred))

print("Predicted K/9 in 2021: " ,regressor.predict([[30]]))
# Out:
# [[ 9.9  10.01]
#  [ 9.56  9.15]
#  [11.06 12.34]
#  [ 9.68  9.41]]
# MSE:  0.4689527499999988
# R2 Score:  0.7040969196004282
# Predicted K/9 in 2021:  [9.68]

# %%
#import data
col_list = ["Age", "BB/9"]
dataset = pd.read_csv('PadresRelievers.csv', usecols=col_list)
X = dataset.iloc[25:29, :-1].values
y = dataset.iloc[25:29, -1].values

from sklearn.model_selection import train_test_split
X_train = X
X_test = X
y_train = y
y_test = y

from sklearn.ensemble import RandomForestRegressor
regressor = RandomForestRegressor(n_estimators = 10, random_state = 0)
regressor.fit(X_train, y_train)

y_pred = regressor.predict(X_test)
np.set_printoptions(precision=2)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))

X_grid = np.arange(min(X), max(X), 0.01)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(X, y, color = 'red')
plt.plot(X_grid, regressor.predict(X_grid), color = 'blue')
plt.title('BB/9 (Random Forest Regression)')
plt.xlabel('Age')
plt.ylabel('BB/9')
plt.show()

#reshape y 
y = y.reshape(len(y),1)

from sklearn.metrics import mean_squared_error
print("MSE: " , mean_squared_error(y_test, y_pred))

from sklearn.metrics import r2_score
print("R2 Score: " , r2_score(y_test, y_pred))

print("Predicted BB/9 in 2021: " ,regressor.predict([[30]]))
# Out:
# [[1.99 1.43]
#  [2.52 2.76]
#  [2.11 1.67]
#  [3.39 3.68]]
# MSE:  0.16091125000000017
# R2 Score:  0.8013993026628404
# Predicted BB/9 in 2021:  [3.39]
