# %%
#import packages
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

#import data
col_list = ["Name","Age", "AVG"]
dataset = pd.read_csv('PadresBatters.csv', usecols=col_list)
X = dataset.iloc[39:43, :-1].values
y = dataset.iloc[39:43, -1].values

print(X)
# Out:
# [['Victor Caratini' 23]
#  ['Victor Caratini' 24]
#  ['Victor Caratini' 25]
#  ['Victor Caratini' 26]]

# %%
#import data
col_list = ["Age", "AVG"]
dataset = pd.read_csv('PadresBatters.csv', usecols=col_list)
X = dataset.iloc[39:43, :-1].values
y = dataset.iloc[39:43, -1].values

from sklearn.model_selection import train_test_split
X_train = X
X_test = X
y_train = y
y_test = y

from sklearn.ensemble import RandomForestRegressor
regressor = RandomForestRegressor(n_estimators = 10, random_state = 0)
regressor.fit(X_train, y_train)

y_pred = regressor.predict(X_test)
np.set_printoptions(precision=2)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))

X_grid = np.arange(min(X), max(X), 0.01)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(X, y, color = 'red')
plt.plot(X_grid, regressor.predict(X_grid), color = 'blue')
plt.title('Batting AVG (Random Forest Regression)')
plt.xlabel('Age')
plt.ylabel('AVG')
plt.show()

#reshape y 
y = y.reshape(len(y),1)

from sklearn.metrics import mean_squared_error
print("MSE: " , mean_squared_error(y_test, y_pred))

from sklearn.metrics import r2_score
print("R2 Score: " , r2_score(y_test, y_pred))

print("Predicted Batting AVG in 2021: " ,regressor.predict([[27]]))
# Out:
# [[0.25 0.25]
#  [0.24 0.23]
#  [0.25 0.27]
#  [0.24 0.24]]
# MSE:  6.915999999999997e-05
# R2 Score:  0.5838435502068453
# Predicted Batting AVG in 2021:  [0.24]

# %%
#import data
col_list = ["Age", "SLG"]
dataset = pd.read_csv('PadresBatters.csv', usecols=col_list)
X = dataset.iloc[39:43, :-1].values
y = dataset.iloc[39:43, -1].values

from sklearn.model_selection import train_test_split
X_train = X
X_test = X
y_train = y
y_test = y

from sklearn.ensemble import RandomForestRegressor
regressor = RandomForestRegressor(n_estimators = 10, random_state = 0)
regressor.fit(X_train, y_train)

y_pred = regressor.predict(X_test)
np.set_printoptions(precision=2)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))

X_grid = np.arange(min(X), max(X), 0.01)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(X, y, color = 'red')
plt.plot(X_grid, regressor.predict(X_grid), color = 'blue')
plt.title('SLG% (Random Forest Regression)')
plt.xlabel('Age')
plt.ylabel('SLG%')
plt.show()

#reshape y 
y = y.reshape(len(y),1)

from sklearn.metrics import mean_squared_error
print("MSE: " , mean_squared_error(y_test, y_pred))

from sklearn.metrics import r2_score
print("R2 Score: " , r2_score(y_test, y_pred))

print("Predicted SLG% in 2021: " ,regressor.predict([[27]]))
# Out:
# [[0.34 0.36]
#  [0.32 0.3 ]
#  [0.39 0.45]
#  [0.34 0.33]]
# MSE:  0.0009698074999999994
# R2 Score:  0.6695363646044088
# Predicted SLG% in 2021:  [0.34]

# %%
#import data
col_list = ["Age", "OBP"]
dataset = pd.read_csv('PadresBatters.csv', usecols=col_list)
X = dataset.iloc[39:43, :-1].values
y = dataset.iloc[39:43, -1].values

from sklearn.model_selection import train_test_split
X_train = X
X_test = X
y_train = y
y_test = y

from sklearn.ensemble import RandomForestRegressor
regressor = RandomForestRegressor(n_estimators = 10, random_state = 0)
regressor.fit(X_train, y_train)

y_pred = regressor.predict(X_test)
np.set_printoptions(precision=2)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))

X_grid = np.arange(min(X), max(X), 0.01)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(X, y, color = 'red')
plt.plot(X_grid, regressor.predict(X_grid), color = 'blue')
plt.title('OBP% (Random Forest Regression)')
plt.xlabel('Age')
plt.ylabel('OBP%')
plt.show()

#reshape y 
y = y.reshape(len(y),1)

from sklearn.metrics import mean_squared_error
print("MSE: " , mean_squared_error(y_test, y_pred))

from sklearn.metrics import r2_score
print("R2 Score: " , r2_score(y_test, y_pred))

print("Predicted OBP% in 2021: " ,regressor.predict([[27]]))
# Out:
# [[0.32 0.33]
#  [0.3  0.29]
#  [0.33 0.35]
#  [0.33 0.33]]
# MSE:  0.00019768750000000033
# R2 Score:  0.5261423220973773
# Predicted OBP% in 2021:  [0.33]

# %%
#import data
col_list = ["Age", "OPS"]
dataset = pd.read_csv('PadresBatters.csv', usecols=col_list)
X = dataset.iloc[39:43, :-1].values
y = dataset.iloc[39:43, -1].values

from sklearn.model_selection import train_test_split
X_train = X
X_test = X
y_train = y
y_test = y

from sklearn.ensemble import RandomForestRegressor
regressor = RandomForestRegressor(n_estimators = 10, random_state = 0)
regressor.fit(X_train, y_train)

y_pred = regressor.predict(X_test)
np.set_printoptions(precision=2)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))

X_grid = np.arange(min(X), max(X), 0.01)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(X, y, color = 'red')
plt.plot(X_grid, regressor.predict(X_grid), color = 'blue')
plt.title('OPS (Random Forest Regression)')
plt.xlabel('Age')
plt.ylabel('OPS')
plt.show()

#reshape y 
y = y.reshape(len(y),1)

from sklearn.metrics import mean_squared_error
print("MSE: " , mean_squared_error(y_test, y_pred))

from sklearn.metrics import r2_score
print("R2 Score: " , r2_score(y_test, y_pred))

print("Predicted OPS in 2021: " ,regressor.predict([[27]]))
# Out:
# [[0.66 0.69]
#  [0.63 0.6 ]
#  [0.72 0.79]
#  [0.67 0.66]]
# MSE:  0.001945987499999999
# R2 Score:  0.6149752062027779
# Predicted OPS in 2021:  [0.67]

# %%
#import data
col_list = ["Age", "%G"]
dataset = pd.read_csv('PadresBatters.csv', usecols=col_list)
X = dataset.iloc[39:43, :-1].values
y = dataset.iloc[39:43, -1].values

from sklearn.model_selection import train_test_split
X_train = X
X_test = X
y_train = y
y_test = y

from sklearn.ensemble import RandomForestRegressor
regressor = RandomForestRegressor(n_estimators = 10, random_state = 0)
regressor.fit(X_train, y_train)

y_pred = regressor.predict(X_test)
np.set_printoptions(precision=2)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))

X_grid = np.arange(min(X), max(X), 0.01)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(X, y, color = 'red')
plt.plot(X_grid, regressor.predict(X_grid), color = 'blue')
plt.title('%G Played (Random Forest Regression)')
plt.xlabel('Age')
plt.ylabel('%G')
plt.show()

#reshape y 
y = y.reshape(len(y),1)

from sklearn.metrics import mean_squared_error
print("MSE: " , mean_squared_error(y_test, y_pred))

from sklearn.metrics import r2_score
print("R2 Score: " , r2_score(y_test, y_pred))

print("Predicted %G in 2021: " ,regressor.predict([[27]]))
# Out:
# [[0.34 0.19]
#  [0.45 0.47]
#  [0.54 0.59]
#  [0.69 0.73]]
# MSE:  0.006708539070676953
# R2 Score:  0.8301933800011849
# Predicted %G in 2021:  [0.69]

# %%
#import data
col_list = ["Age", "PA/G"]
dataset = pd.read_csv('PadresBatters.csv', usecols=col_list)
X = dataset.iloc[39:43, :-1].values
y = dataset.iloc[39:43, -1].values

from sklearn.model_selection import train_test_split
X_train = X
X_test = X
y_train = y
y_test = y

from sklearn.ensemble import RandomForestRegressor
regressor = RandomForestRegressor(n_estimators = 10, random_state = 0)
regressor.fit(X_train, y_train)

y_pred = regressor.predict(X_test)
np.set_printoptions(precision=2)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))

X_grid = np.arange(min(X), max(X), 0.01)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(X, y, color = 'red')
plt.plot(X_grid, regressor.predict(X_grid), color = 'blue')
plt.title('PA/G (Random Forest Regression)')
plt.xlabel('Age')
plt.ylabel('PA/G')
plt.show()

#reshape y 
y = y.reshape(len(y),1)

from sklearn.metrics import mean_squared_error
print("MSE: " , mean_squared_error(y_test, y_pred))

from sklearn.metrics import r2_score
print("R2 Score: " , r2_score(y_test, y_pred))

print("Predicted PA/G in 2021: " ,regressor.predict([[27]]))
# Out:
# [[2.41 2.13]
#  [2.61 2.63]
#  [2.81 2.94]
#  [2.96 3.  ]]
# MSE:  0.024143138911485677
# R2 Score:  0.7963252416772817
# Predicted PA/G in 2021:  [2.96]

# %%
#import data
col_list = ["Age", "HR/G"]
dataset = pd.read_csv('PadresBatters.csv', usecols=col_list)
X = dataset.iloc[39:43, :-1].values
y = dataset.iloc[39:43, -1].values

from sklearn.model_selection import train_test_split
X_train = X
X_test = X
y_train = y
y_test = y

from sklearn.ensemble import RandomForestRegressor
regressor = RandomForestRegressor(n_estimators = 10, random_state = 0)
regressor.fit(X_train, y_train)

y_pred = regressor.predict(X_test)
np.set_printoptions(precision=2)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))

X_grid = np.arange(min(X), max(X), 0.01)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(X, y, color = 'red')
plt.plot(X_grid, regressor.predict(X_grid), color = 'blue')
plt.title('HR/G (Random Forest Regression)')
plt.xlabel('Age')
plt.ylabel('HR/G')
plt.show()

#reshape y 
y = y.reshape(len(y),1)

from sklearn.metrics import mean_squared_error
print("MSE: " , mean_squared_error(y_test, y_pred))

from sklearn.metrics import r2_score
print("R2 Score: " , r2_score(y_test, y_pred))

print("Predicted HR/G in 2021: " ,regressor.predict([[27]]))
# Out:
# [[0.04 0.03]
#  [0.04 0.03]
#  [0.08 0.12]
#  [0.03 0.02]]
# MSE:  0.00037526436182187063
# R2 Score:  0.7475372238211768
# Predicted HR/G in 2021:  [0.03]

# %%
#import data
col_list = ["Age", "RBI/G"]
dataset = pd.read_csv('PadresBatters.csv', usecols=col_list)
X = dataset.iloc[39:43, :-1].values
y = dataset.iloc[39:43, -1].values

from sklearn.model_selection import train_test_split
X_train = X
X_test = X
y_train = y
y_test = y

from sklearn.ensemble import RandomForestRegressor
regressor = RandomForestRegressor(n_estimators = 10, random_state = 0)
regressor.fit(X_train, y_train)

y_pred = regressor.predict(X_test)
np.set_printoptions(precision=2)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))

X_grid = np.arange(min(X), max(X), 0.01)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(X, y, color = 'red')
plt.plot(X_grid, regressor.predict(X_grid), color = 'blue')
plt.title('RBI/G (Random Forest Regression)')
plt.xlabel('Age')
plt.ylabel('RBI/G')
plt.show()

#reshape y 
y = y.reshape(len(y),1)

from sklearn.metrics import mean_squared_error
print("MSE: " , mean_squared_error(y_test, y_pred))

from sklearn.metrics import r2_score
print("R2 Score: " , r2_score(y_test, y_pred))

print("Predicted RBI/G in 2021: " ,regressor.predict([[27]]))
# Out:
# [[0.18 0.06]
#  [0.26 0.28]
#  [0.33 0.36]
#  [0.35 0.36]]
# MSE:  0.0035825411550967907
# R2 Score:  0.7557871626762591
# Predicted RBI/G in 2021:  [0.35]

# %%
#import data
col_list = ["Age", "R/G"]
dataset = pd.read_csv('PadresBatters.csv', usecols=col_list)
X = dataset.iloc[39:43, :-1].values
y = dataset.iloc[39:43, -1].values

from sklearn.model_selection import train_test_split
X_train = X
X_test = X
y_train = y
y_test = y

from sklearn.ensemble import RandomForestRegressor
regressor = RandomForestRegressor(n_estimators = 10, random_state = 0)
regressor.fit(X_train, y_train)

y_pred = regressor.predict(X_test)
np.set_printoptions(precision=2)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))

X_grid = np.arange(min(X), max(X), 0.01)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(X, y, color = 'red')
plt.plot(X_grid, regressor.predict(X_grid), color = 'blue')
plt.title('R/G (Random Forest Regression)')
plt.xlabel('Age')
plt.ylabel('R/G')
plt.show()

#reshape y 
y = y.reshape(len(y),1)

from sklearn.metrics import mean_squared_error
print("MSE: " , mean_squared_error(y_test, y_pred))

from sklearn.metrics import r2_score
print("R2 Score: " , r2_score(y_test, y_pred))

print("Predicted R/G in 2021: " ,regressor.predict([[27]]))
# Out:
# [[0.24 0.19]
#  [0.27 0.28]
#  [0.31 0.33]
#  [0.24 0.23]]
# MSE:  0.0006953699365022808
# R2 Score:  0.724125965658675
# Predicted R/G in 2021:  [0.24]

# %%
#import data
col_list = ["Age", "SB/G"]
dataset = pd.read_csv('PadresBatters.csv', usecols=col_list)
X = dataset.iloc[39:43, :-1].values
y = dataset.iloc[39:43, -1].values

from sklearn.model_selection import train_test_split
X_train = X
X_test = X
y_train = y
y_test = y

from sklearn.ensemble import RandomForestRegressor
regressor = RandomForestRegressor(n_estimators = 10, random_state = 0)
regressor.fit(X_train, y_train)

y_pred = regressor.predict(X_test)
np.set_printoptions(precision=2)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))

X_grid = np.arange(min(X), max(X), 0.01)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(X, y, color = 'red')
plt.plot(X_grid, regressor.predict(X_grid), color = 'blue')
plt.title('SB/G (Random Forest Regression)')
plt.xlabel('Age')
plt.ylabel('SB/G')
plt.show()

#reshape y 
y = y.reshape(len(y),1)

from sklearn.metrics import mean_squared_error
print("MSE: " , mean_squared_error(y_test, y_pred))

from sklearn.metrics import r2_score
print("R2 Score: " , r2_score(y_test, y_pred))

print("Predicted SB/G in 2021: " ,regressor.predict([[27]]))
# Out:
# [[0.   0.  ]
#  [0.   0.  ]
#  [0.01 0.01]
#  [0.   0.  ]]
# MSE:  5.26315810526316e-06
# R2 Score:  0.7466666666666667
# Predicted SB/G in 2021:  [0.]

# %%
#import data
col_list = ["Age", "2B/G"]
dataset = pd.read_csv('PadresBatters.csv', usecols=col_list)
X = dataset.iloc[39:43, :-1].values
y = dataset.iloc[39:43, -1].values

from sklearn.model_selection import train_test_split
X_train = X
X_test = X
y_train = y
y_test = y

from sklearn.ensemble import RandomForestRegressor
regressor = RandomForestRegressor(n_estimators = 10, random_state = 0)
regressor.fit(X_train, y_train)

y_pred = regressor.predict(X_test)
np.set_printoptions(precision=2)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))

X_grid = np.arange(min(X), max(X), 0.01)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(X, y, color = 'red')
plt.plot(X_grid, regressor.predict(X_grid), color = 'blue')
plt.title('2B/G (Random Forest Regression)')
plt.xlabel('Age')
plt.ylabel('2B/G')
plt.show()

#reshape y 
y = y.reshape(len(y),1)

from sklearn.metrics import mean_squared_error
print("MSE: " , mean_squared_error(y_test, y_pred))

from sklearn.metrics import r2_score
print("R2 Score: " , r2_score(y_test, y_pred))

print("Predicted 2B/G in 2021: " ,regressor.predict([[27]]))
# Out:
# [[0.1  0.1 ]
#  [0.09 0.09]
#  [0.11 0.12]
#  [0.15 0.16]]
# MSE:  5.485581451532531e-05
# R2 Score:  0.9215630165300308
# Predicted 2B/G in 2021:  [0.15]

# %%
#import data
col_list = ["Age", "3B/G"]
dataset = pd.read_csv('PadresBatters.csv', usecols=col_list)
X = dataset.iloc[39:43, :-1].values
y = dataset.iloc[39:43, -1].values

from sklearn.model_selection import train_test_split
X_train = X
X_test = X
y_train = y
y_test = y

from sklearn.ensemble import RandomForestRegressor
regressor = RandomForestRegressor(n_estimators = 10, random_state = 0)
regressor.fit(X_train, y_train)

y_pred = regressor.predict(X_test)
np.set_printoptions(precision=2)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))

X_grid = np.arange(min(X), max(X), 0.01)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(X, y, color = 'red')
plt.plot(X_grid, regressor.predict(X_grid), color = 'blue')
plt.title('3B/G (Random Forest Regression)')
plt.xlabel('Age')
plt.ylabel('3B/G')
plt.show()

#reshape y 
y = y.reshape(len(y),1)

from sklearn.metrics import mean_squared_error
print("MSE: " , mean_squared_error(y_test, y_pred))

from sklearn.metrics import r2_score
print("R2 Score: " , r2_score(y_test, y_pred))

print("Predicted 3B/G in 2021: " ,regressor.predict([[27]]))
# Out:
# [[0. 0.]
#  [0. 0.]
#  [0. 0.]
#  [0. 0.]]
# MSE:  0.0
# R2 Score:  1.0
# Predicted 3B/G in 2021:  [0.]

# %%
#import data
col_list = ["Age", "BB/G"]
dataset = pd.read_csv('PadresBatters.csv', usecols=col_list)
X = dataset.iloc[39:43, :-1].values
y = dataset.iloc[39:43, -1].values

from sklearn.model_selection import train_test_split
X_train = X
X_test = X
y_train = y
y_test = y

from sklearn.ensemble import RandomForestRegressor
regressor = RandomForestRegressor(n_estimators = 10, random_state = 0)
regressor.fit(X_train, y_train)

y_pred = regressor.predict(X_test)
np.set_printoptions(precision=2)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))

X_grid = np.arange(min(X), max(X), 0.01)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(X, y, color = 'red')
plt.plot(X_grid, regressor.predict(X_grid), color = 'blue')
plt.title('BB/G (Random Forest Regression)')
plt.xlabel('Age')
plt.ylabel('BB/G')
plt.show()

#reshape y 
y = y.reshape(len(y),1)

from sklearn.metrics import mean_squared_error
print("MSE: " , mean_squared_error(y_test, y_pred))

from sklearn.metrics import r2_score
print("R2 Score: " , r2_score(y_test, y_pred))

print("Predicted BB/G in 2021: " ,regressor.predict([[27]]))
# Out:
# [[0.16 0.13]
#  [0.17 0.16]
#  [0.25 0.31]
#  [0.26 0.27]]
# MSE:  0.0011334332990152022
# R2 Score:  0.7950882299865032
# Predicted BB/G in 2021:  [0.26]

# %%
#import data
col_list = ["Age", "SO/G"]
dataset = pd.read_csv('PadresBatters.csv', usecols=col_list)
X = dataset.iloc[39:43, :-1].values
y = dataset.iloc[39:43, -1].values

from sklearn.model_selection import train_test_split
X_train = X
X_test = X
y_train = y
y_test = y

from sklearn.ensemble import RandomForestRegressor
regressor = RandomForestRegressor(n_estimators = 10, random_state = 0)
regressor.fit(X_train, y_train)

y_pred = regressor.predict(X_test)
np.set_printoptions(precision=2)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))

X_grid = np.arange(min(X), max(X), 0.01)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(X, y, color = 'red')
plt.plot(X_grid, regressor.predict(X_grid), color = 'blue')
plt.title('SO/G (Random Forest Regression)')
plt.xlabel('Age')
plt.ylabel('SO/G')
plt.show()

#reshape y 
y = y.reshape(len(y),1)

from sklearn.metrics import mean_squared_error
print("MSE: " , mean_squared_error(y_test, y_pred))

from sklearn.metrics import r2_score
print("R2 Score: " , r2_score(y_test, y_pred))

print("Predicted SO/G in 2021: " ,regressor.predict([[27]]))
# Out:
# [[0.49 0.42]
#  [0.55 0.55]
#  [0.59 0.62]
#  [0.68 0.7 ]]
# MSE:  0.001686159117499423
# R2 Score:  0.8454028551983737
# Predicted SO/G in 2021:  [0.68]

# %% [markdown]
# ######
