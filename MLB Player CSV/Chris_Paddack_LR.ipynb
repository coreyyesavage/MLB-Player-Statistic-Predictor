# %%
#import packages
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

#import data
col_list = ["Name","Age", "ERA"]
dataset = pd.read_csv('PadresPitchers.csv', usecols=col_list)
X = dataset.iloc[9:11, :-1].values
y = dataset.iloc[9:11, -1].values

print(X)
# Out:
# [['Chris Paddack' 23]
#  ['Chris Paddack' 24]]

# %%
#import data
col_list = ["Age", "ERA"]
dataset = pd.read_csv('PadresPitchers.csv', usecols=col_list)
X = dataset.iloc[9:11, :-1].values
y = dataset.iloc[9:11, -1].values

y_train = y
y_test = y
X_test = X
X_train = X

from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)

y_pred = regressor.predict(X_test)
np.set_printoptions(precision=2)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))

#y_pred = regressor.predict(X_test)

plt.scatter(X_train, y_train, color = 'red')
plt.plot(X_train, regressor.predict(X_train), color = 'blue')
plt.title('ERA(Linear Reg)')
plt.xlabel('Age')
plt.ylabel('ERA')
plt.show()

#reshape y 
y = y.reshape(len(y),1)

#Feature scaling the data
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
sc_y = StandardScaler()
X = sc_X.fit_transform(X)
y = sc_y.fit_transform(y)


from sklearn.metrics import mean_squared_error
print("MSE: " , mean_squared_error(y_test, y_pred))

from sklearn.metrics import r2_score
print("R2 Score: " , r2_score(y_test, y_pred))

print("Predicted ERA in 2021: " ,regressor.predict([[25]]))
# Out:
# [[3.33 3.33]
#  [4.73 4.73]]
# MSE:  7.888609052210118e-30
# R2 Score:  1.0
# Predicted ERA in 2021:  [6.13]

# %%
#import data
col_list = ["Age", "WHIP"]
dataset = pd.read_csv('PadresPitchers.csv', usecols=col_list)
X = dataset.iloc[9:11, :-1].values
y = dataset.iloc[9:11, -1].values

y_train = y
y_test = y
X_test = X
X_train = X

from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)

y_pred = regressor.predict(X_test)
np.set_printoptions(precision=2)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))

#y_pred = regressor.predict(X_test)

plt.scatter(X_train, y_train, color = 'red')
plt.plot(X_train, regressor.predict(X_train), color = 'blue')
plt.title('WHIP(Linear Reg)')
plt.xlabel('Age')
plt.ylabel('WHIP')
plt.show()

#reshape y 
y = y.reshape(len(y),1)

#Feature scaling the data
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
sc_y = StandardScaler()
X = sc_X.fit_transform(X)
y = sc_y.fit_transform(y)


from sklearn.metrics import mean_squared_error
print("MSE: " , mean_squared_error(y_test, y_pred))

from sklearn.metrics import r2_score
print("R2 Score: " , r2_score(y_test, y_pred))

print("Predicted WHIP in 2021: " ,regressor.predict([[25]]))
# Out:
# [[0.98 0.98]
#  [1.22 1.22]]
# MSE:  3.2047474274603605e-31
# R2 Score:  1.0
# Predicted WHIP in 2021:  [1.46]

# %%
#import data
col_list = ["Age", "AVG"]
dataset = pd.read_csv('PadresPitchers.csv', usecols=col_list)
X = dataset.iloc[9:11, :-1].values
y = dataset.iloc[9:11, -1].values

y_train = y
y_test = y
X_test = X
X_train = X

from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)

y_pred = regressor.predict(X_test)
np.set_printoptions(precision=2)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))

#y_pred = regressor.predict(X_test)

plt.scatter(X_train, y_train, color = 'red')
plt.plot(X_train, regressor.predict(X_train), color = 'blue')
plt.title('AVG(Linear Reg)')
plt.xlabel('Age')
plt.ylabel('AVG')
plt.show()

#reshape y 
y = y.reshape(len(y),1)

#Feature scaling the data
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
sc_y = StandardScaler()
X = sc_X.fit_transform(X)
y = sc_y.fit_transform(y)


from sklearn.metrics import mean_squared_error
print("MSE: " , mean_squared_error(y_test, y_pred))

from sklearn.metrics import r2_score
print("R2 Score: " , r2_score(y_test, y_pred))

print("Predicted AVG in 2021: " ,regressor.predict([[25]]))
# Out:
# [[0.2  0.2 ]
#  [0.26 0.26]]
# MSE:  3.851859888774472e-34
# R2 Score:  1.0
# Predicted AVG in 2021:  [0.32]

# %%
#import data
col_list = ["Age", "K/9"]
dataset = pd.read_csv('PadresPitchers.csv', usecols=col_list)
X = dataset.iloc[9:11, :-1].values
y = dataset.iloc[9:11, -1].values

y_train = y
y_test = y
X_test = X
X_train = X

from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)

y_pred = regressor.predict(X_test)
np.set_printoptions(precision=2)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))

#y_pred = regressor.predict(X_test)

plt.scatter(X_train, y_train, color = 'red')
plt.plot(X_train, regressor.predict(X_train), color = 'blue')
plt.title('K/9(Linear Reg)')
plt.xlabel('Age')
plt.ylabel('K/9')
plt.show()

#reshape y 
y = y.reshape(len(y),1)

#Feature scaling the data
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
sc_y = StandardScaler()
X = sc_X.fit_transform(X)
y = sc_y.fit_transform(y)


from sklearn.metrics import mean_squared_error
print("MSE: " , mean_squared_error(y_test, y_pred))

from sklearn.metrics import r2_score
print("R2 Score: " , r2_score(y_test, y_pred))

print("Predicted K/9 in 2021: " ,regressor.predict([[25]]))
# Out:
# [[9.79 9.79]
#  [8.85 8.85]]
# MSE:  1.5777218104420236e-30
# R2 Score:  1.0
# Predicted K/9 in 2021:  [7.91]

# %%
#import data
col_list = ["Age", "BB/9"]
dataset = pd.read_csv('PadresPitchers.csv', usecols=col_list)
X = dataset.iloc[9:11, :-1].values
y = dataset.iloc[9:11, -1].values

y_train = y
y_test = y
X_test = X
X_train = X

from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)

y_pred = regressor.predict(X_test)
np.set_printoptions(precision=2)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))

#y_pred = regressor.predict(X_test)

plt.scatter(X_train, y_train, color = 'red')
plt.plot(X_train, regressor.predict(X_train), color = 'blue')
plt.title('BB/9(Linear Reg)')
plt.xlabel('Age')
plt.ylabel('BB/9')
plt.show()

#reshape y 
y = y.reshape(len(y),1)

#Feature scaling the data
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
sc_y = StandardScaler()
X = sc_X.fit_transform(X)
y = sc_y.fit_transform(y)


from sklearn.metrics import mean_squared_error
print("MSE: " , mean_squared_error(y_test, y_pred))

from sklearn.metrics import r2_score
print("R2 Score: " , r2_score(y_test, y_pred))

print("Predicted BB/9 in 2021: " ,regressor.predict([[25]]))
# Out:
# [[1.98 1.98]
#  [1.83 1.83]]
# MSE:  9.860761315262648e-32
# R2 Score:  1.0
# Predicted BB/9 in 2021:  [1.68]

# %%
#import data
col_list = ["Age", "ADJ_IP"]
dataset = pd.read_csv('PadresPitchers.csv', usecols=col_list)
X = dataset.iloc[9:11, :-1].values
y = dataset.iloc[9:11, -1].values

y_train = y
y_test = y
X_test = X
X_train = X

from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)

y_pred = regressor.predict(X_test)
np.set_printoptions(precision=2)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))

#y_pred = regressor.predict(X_test)

plt.scatter(X_train, y_train, color = 'red')
plt.plot(X_train, regressor.predict(X_train), color = 'blue')
plt.title('ADJ_IP(Linear Reg)')
plt.xlabel('Age')
plt.ylabel('ADJ_IP')
plt.show()

#reshape y 
y = y.reshape(len(y),1)

#Feature scaling the data
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
sc_y = StandardScaler()
X = sc_X.fit_transform(X)
y = sc_y.fit_transform(y)


from sklearn.metrics import mean_squared_error
print("MSE: " , mean_squared_error(y_test, y_pred))

from sklearn.metrics import r2_score
print("R2 Score: " , r2_score(y_test, y_pred))

print("Predicted IP in 2021: " ,regressor.predict([[25]]))
# Out:
# [[140.2 140.2]
#  [159.3 159.3]]
# MSE:  0.0
# R2 Score:  1.0
# Predicted IP in 2021:  [178.4]

# %%
#import data
col_list = ["Age", "ADJ_GS"]
dataset = pd.read_csv('PadresPitchers.csv', usecols=col_list)
X = dataset.iloc[9:11, :-1].values
y = dataset.iloc[9:11, -1].values

y_train = y
y_test = y
X_test = X
X_train = X

from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)

y_pred = regressor.predict(X_test)
np.set_printoptions(precision=2)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))

#y_pred = regressor.predict(X_test)

plt.scatter(X_train, y_train, color = 'red')
plt.plot(X_train, regressor.predict(X_train), color = 'blue')
plt.title('ADJ_GS(Linear Reg)')
plt.xlabel('Age')
plt.ylabel('ADJ_GS')
plt.show()

#reshape y 
y = y.reshape(len(y),1)

#Feature scaling the data
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
sc_y = StandardScaler()
X = sc_X.fit_transform(X)
y = sc_y.fit_transform(y)


from sklearn.metrics import mean_squared_error
print("MSE: " , mean_squared_error(y_test, y_pred))

from sklearn.metrics import r2_score
print("R2 Score: " , r2_score(y_test, y_pred))

print("Predicted GS in 2021: " ,regressor.predict([[25]]))
# Out:
# [[26.  26. ]
#  [32.4 32.4]]
# MSE:  1.262177448353619e-28
# R2 Score:  1.0
# Predicted GS in 2021:  [38.8]
