# %%
#import packages
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

#import data
col_list = ["Name","Age", "AVG"]
dataset = pd.read_csv('PadresBatters.csv', usecols=col_list)
X = dataset.iloc[10:12, :-1].values
y = dataset.iloc[10:12, -1].values

print(X)
# Out:
# [['Fernando Tatis Jr.' 20]
#  ['Fernando Tatis Jr.' 21]]

# %%
#import data
col_list = ["Age", "AVG"]
dataset = pd.read_csv('PadresBatters.csv', usecols=col_list)
X = dataset.iloc[10:12, :-1].values
y = dataset.iloc[10:12, -1].values

from sklearn.model_selection import train_test_split
X_train = X
X_test = X
y_train = y
y_test = y


from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
poly_reg = PolynomialFeatures(degree = 4)
X_poly = poly_reg.fit_transform(X_train)
regressor = LinearRegression()
regressor.fit(X_poly, y_train)

y_pred = regressor.predict(poly_reg.transform(X_test))
np.set_printoptions(precision=2)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))

#y_pred = regressor.predict(X_test)
X_grid = np.arange(min(X), max(X), 0.1)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(X_train, y_train, color = 'red')
plt.plot(X_grid, regressor.predict(poly_reg.fit_transform(X_grid)), color = 'blue')
plt.title('AVG (Polynomial Reg)')
plt.xlabel('Age')
plt.ylabel('AVG')
plt.show()

#reshape y 
y = y.reshape(len(y),1)

#Feature scaling the data
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
sc_y = StandardScaler()
X = sc_X.fit_transform(X)
y = sc_y.fit_transform(y)


from sklearn.metrics import mean_squared_error
print("MSE: " , mean_squared_error(y_test, y_pred))

from sklearn.metrics import r2_score
print("R2 Score: " , r2_score(y_test, y_pred))

print("Predicted AVG in 2021: " ,regressor.predict(poly_reg.fit_transform([[22]])))
# Out:
# [[0.32 0.32]
#  [0.28 0.28]]
# MSE:  0.0
# R2 Score:  1.0
# Predicted AVG in 2021:  [0.23]

# %%
#import data
col_list = ["Age", "SLG"]
dataset = pd.read_csv('PadresBatters.csv', usecols=col_list)
X = dataset.iloc[10:12, :-1].values
y = dataset.iloc[10:12, -1].values

from sklearn.model_selection import train_test_split
X_train = X
X_test = X
y_train = y
y_test = y


from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
poly_reg = PolynomialFeatures(degree = 4)
X_poly = poly_reg.fit_transform(X_train)
regressor = LinearRegression()
regressor.fit(X_poly, y_train)

y_pred = regressor.predict(poly_reg.transform(X_test))
np.set_printoptions(precision=2)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))

#y_pred = regressor.predict(X_test)
X_grid = np.arange(min(X), max(X), 0.1)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(X_train, y_train, color = 'red')
plt.plot(X_grid, regressor.predict(poly_reg.fit_transform(X_grid)), color = 'blue')
plt.title('SLG (Polynomial Reg)')
plt.xlabel('Age')
plt.ylabel('SLG')
plt.show()

#reshape y 
y = y.reshape(len(y),1)

#Feature scaling the data
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
sc_y = StandardScaler()
X = sc_X.fit_transform(X)
y = sc_y.fit_transform(y)


from sklearn.metrics import mean_squared_error
print("MSE: " , mean_squared_error(y_test, y_pred))

from sklearn.metrics import r2_score
print("R2 Score: " , r2_score(y_test, y_pred))

print("Predicted SLG in 2021: " ,regressor.predict(poly_reg.fit_transform([[22]])))
# Out:
# [[0.59 0.59]
#  [0.57 0.57]]
# MSE:  0.0
# R2 Score:  1.0
# Predicted SLG in 2021:  [0.55]

# %%
#import data
col_list = ["Age", "OBP"]
dataset = pd.read_csv('PadresBatters.csv', usecols=col_list)
X = dataset.iloc[10:12, :-1].values
y = dataset.iloc[10:12, -1].values


from sklearn.model_selection import train_test_split
X_train = X
X_test = X
y_train = y
y_test = y


from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
poly_reg = PolynomialFeatures(degree = 4)
X_poly = poly_reg.fit_transform(X_train)
regressor = LinearRegression()
regressor.fit(X_poly, y_train)

y_pred = regressor.predict(poly_reg.transform(X_test))
np.set_printoptions(precision=2)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))

#y_pred = regressor.predict(X_test)
X_grid = np.arange(min(X), max(X), 0.1)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(X_train, y_train, color = 'red')
plt.plot(X_grid, regressor.predict(poly_reg.fit_transform(X_grid)), color = 'blue')
plt.title('OBP (Polynomial Reg)')
plt.xlabel('Age')
plt.ylabel('OBP')
plt.show()

#reshape y 
y = y.reshape(len(y),1)

#Feature scaling the data
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
sc_y = StandardScaler()
X = sc_X.fit_transform(X)
y = sc_y.fit_transform(y)


from sklearn.metrics import mean_squared_error
print("MSE: " , mean_squared_error(y_test, y_pred))

from sklearn.metrics import r2_score
print("R2 Score: " , r2_score(y_test, y_pred))

print("Predicted OBP in 2021: " ,regressor.predict(poly_reg.fit_transform([[22]])))
# Out:
# [[0.38 0.38]
#  [0.37 0.37]]
# MSE:  0.0
# R2 Score:  1.0
# Predicted OBP in 2021:  [0.35]

# %%
#import data
col_list = ["Age", "OPS"]
dataset = pd.read_csv('PadresBatters.csv', usecols=col_list)
X = dataset.iloc[10:12, :-1].values
y = dataset.iloc[10:12, -1].values


from sklearn.model_selection import train_test_split
X_train = X
X_test = X
y_train = y
y_test = y


from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
poly_reg = PolynomialFeatures(degree = 4)
X_poly = poly_reg.fit_transform(X_train)
regressor = LinearRegression()
regressor.fit(X_poly, y_train)

y_pred = regressor.predict(poly_reg.transform(X_test))
np.set_printoptions(precision=2)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))

#y_pred = regressor.predict(X_test)
X_grid = np.arange(min(X), max(X), 0.1)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(X_train, y_train, color = 'red')
plt.plot(X_grid, regressor.predict(poly_reg.fit_transform(X_grid)), color = 'blue')
plt.title('OPS (Polynomial Reg)')
plt.xlabel('Age')
plt.ylabel('OPS')
plt.show()

#reshape y 
y = y.reshape(len(y),1)

#Feature scaling the data
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
sc_y = StandardScaler()
X = sc_X.fit_transform(X)
y = sc_y.fit_transform(y)


from sklearn.metrics import mean_squared_error
print("MSE: " , mean_squared_error(y_test, y_pred))

from sklearn.metrics import r2_score
print("R2 Score: " , r2_score(y_test, y_pred))

print("Predicted OPS in 2021: " ,regressor.predict(poly_reg.fit_transform([[22]])))
# Out:
# [[0.97 0.97]
#  [0.94 0.94]]
# MSE:  1.232595164407831e-32
# R2 Score:  1.0
# Predicted OPS in 2021:  [0.9]

# %%
#import data
col_list = ["Age", "%G"]
dataset = pd.read_csv('PadresBatters.csv', usecols=col_list)
X = dataset.iloc[10:12, :-1].values
y = dataset.iloc[10:12, -1].values


from sklearn.model_selection import train_test_split
X_train = X
X_test = X
y_train = y
y_test = y


from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
poly_reg = PolynomialFeatures(degree = 4)
X_poly = poly_reg.fit_transform(X_train)
regressor = LinearRegression()
regressor.fit(X_poly, y_train)

y_pred = regressor.predict(poly_reg.transform(X_test))
np.set_printoptions(precision=2)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))

#y_pred = regressor.predict(X_test)
X_grid = np.arange(min(X), max(X), 0.1)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(X_train, y_train, color = 'red')
plt.plot(X_grid, regressor.predict(poly_reg.fit_transform(X_grid)), color = 'blue')
plt.title('%G (Polynomial Reg)')
plt.xlabel('Age')
plt.ylabel('%G')
plt.show()

#reshape y 
y = y.reshape(len(y),1)

#Feature scaling the data
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
sc_y = StandardScaler()
X = sc_X.fit_transform(X)
y = sc_y.fit_transform(y)


from sklearn.metrics import mean_squared_error
print("MSE: " , mean_squared_error(y_test, y_pred))

from sklearn.metrics import r2_score
print("R2 Score: " , r2_score(y_test, y_pred))

print("Predicted %G in 2021: " ,regressor.predict(poly_reg.fit_transform([[22]])))
# Out:
# [[0.52 0.52]
#  [0.98 0.98]]
# MSE:  1.1093356479670479e-31
# R2 Score:  1.0
# Predicted %G in 2021:  [1.52]

# %%
#import data
col_list = ["Age", "PA/G"]
dataset = pd.read_csv('PadresBatters.csv', usecols=col_list)
X = dataset.iloc[10:12, :-1].values
y = dataset.iloc[10:12, -1].values


from sklearn.model_selection import train_test_split
X_train = X
X_test = X
y_train = y
y_test = y


from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
poly_reg = PolynomialFeatures(degree = 4)
X_poly = poly_reg.fit_transform(X_train)
regressor = LinearRegression()
regressor.fit(X_poly, y_train)

y_pred = regressor.predict(poly_reg.transform(X_test))
np.set_printoptions(precision=2)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))

#y_pred = regressor.predict(X_test)
X_grid = np.arange(min(X), max(X), 0.1)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(X_train, y_train, color = 'red')
plt.plot(X_grid, regressor.predict(poly_reg.fit_transform(X_grid)), color = 'blue')
plt.title('PA/G (Polynomial Reg)')
plt.xlabel('Age')
plt.ylabel('PA/G')
plt.show()

#reshape y 
y = y.reshape(len(y),1)

#Feature scaling the data
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
sc_y = StandardScaler()
X = sc_X.fit_transform(X)
y = sc_y.fit_transform(y)


from sklearn.metrics import mean_squared_error
print("MSE: " , mean_squared_error(y_test, y_pred))

from sklearn.metrics import r2_score
print("R2 Score: " , r2_score(y_test, y_pred))

print("Predicted PA/G in 2021: " ,regressor.predict(poly_reg.fit_transform([[22]])))
# Out:
# [[4.43 4.43]
#  [4.36 4.36]]
# MSE:  0.0
# R2 Score:  1.0
# Predicted PA/G in 2021:  [4.27]

# %%
#import data
col_list = ["Age", "HR/G"]
dataset = pd.read_csv('PadresBatters.csv', usecols=col_list)
X = dataset.iloc[10:12, :-1].values
y = dataset.iloc[10:12, -1].values


from sklearn.model_selection import train_test_split
X_train = X
X_test = X
y_train = y
y_test = y


from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
poly_reg = PolynomialFeatures(degree = 4)
X_poly = poly_reg.fit_transform(X_train)
regressor = LinearRegression()
regressor.fit(X_poly, y_train)

y_pred = regressor.predict(poly_reg.transform(X_test))
np.set_printoptions(precision=2)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))

#y_pred = regressor.predict(X_test)
X_grid = np.arange(min(X), max(X), 0.1)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(X_train, y_train, color = 'red')
plt.plot(X_grid, regressor.predict(poly_reg.fit_transform(X_grid)), color = 'blue')
plt.title('HR/G (Polynomial Reg)')
plt.xlabel('Age')
plt.ylabel('HR/G')
plt.show()

#reshape y 
y = y.reshape(len(y),1)

#Feature scaling the data
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
sc_y = StandardScaler()
X = sc_X.fit_transform(X)
y = sc_y.fit_transform(y)


from sklearn.metrics import mean_squared_error
print("MSE: " , mean_squared_error(y_test, y_pred))

from sklearn.metrics import r2_score
print("R2 Score: " , r2_score(y_test, y_pred))

print("Predicted HR/G in 2021: " ,regressor.predict(poly_reg.fit_transform([[22]])))
# Out:
# [[0.26 0.26]
#  [0.29 0.29]]
# MSE:  0.0
# R2 Score:  1.0
# Predicted HR/G in 2021:  [0.32]

# %%
#import data
col_list = ["Age", "RBI/G"]
dataset = pd.read_csv('PadresBatters.csv', usecols=col_list)
X = dataset.iloc[10:12, :-1].values
y = dataset.iloc[10:12, -1].values


from sklearn.model_selection import train_test_split
X_train = X
X_test = X
y_train = y
y_test = y


from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
poly_reg = PolynomialFeatures(degree = 4)
X_poly = poly_reg.fit_transform(X_train)
regressor = LinearRegression()
regressor.fit(X_poly, y_train)

y_pred = regressor.predict(poly_reg.transform(X_test))
np.set_printoptions(precision=2)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))

#y_pred = regressor.predict(X_test)
X_grid = np.arange(min(X), max(X), 0.1)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(X_train, y_train, color = 'red')
plt.plot(X_grid, regressor.predict(poly_reg.fit_transform(X_grid)), color = 'blue')
plt.title('RBI/G (Polynomial Reg)')
plt.xlabel('Age')
plt.ylabel('RBI/G')
plt.show()

#reshape y 
y = y.reshape(len(y),1)

#Feature scaling the data
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
sc_y = StandardScaler()
X = sc_X.fit_transform(X)
y = sc_y.fit_transform(y)


from sklearn.metrics import mean_squared_error
print("MSE: " , mean_squared_error(y_test, y_pred))

from sklearn.metrics import r2_score
print("R2 Score: " , r2_score(y_test, y_pred))

print("Predicted RBI/G in 2021: " ,regressor.predict(poly_reg.fit_transform([[22]])))
# Out:
# [[0.63 0.63]
#  [0.76 0.76]]
# MSE:  0.0
# R2 Score:  1.0
# Predicted RBI/G in 2021:  [0.91]

# %%
#import data
col_list = ["Age", "R/G"]
dataset = pd.read_csv('PadresBatters.csv', usecols=col_list)
X = dataset.iloc[10:12, :-1].values
y = dataset.iloc[10:12, -1].values


from sklearn.model_selection import train_test_split
X_train = X
X_test = X
y_train = y
y_test = y


from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
poly_reg = PolynomialFeatures(degree = 4)
X_poly = poly_reg.fit_transform(X_train)
regressor = LinearRegression()
regressor.fit(X_poly, y_train)

y_pred = regressor.predict(poly_reg.transform(X_test))
np.set_printoptions(precision=2)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))

#y_pred = regressor.predict(X_test)
X_grid = np.arange(min(X), max(X), 0.1)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(X_train, y_train, color = 'red')
plt.plot(X_grid, regressor.predict(poly_reg.fit_transform(X_grid)), color = 'blue')
plt.title('R/G (Polynomial Reg)')
plt.xlabel('Age')
plt.ylabel('R/G')
plt.show()

#reshape y 
y = y.reshape(len(y),1)

#Feature scaling the data
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
sc_y = StandardScaler()
X = sc_X.fit_transform(X)
y = sc_y.fit_transform(y)


from sklearn.metrics import mean_squared_error
print("MSE: " , mean_squared_error(y_test, y_pred))

from sklearn.metrics import r2_score
print("R2 Score: " , r2_score(y_test, y_pred))

print("Predicted R/G in 2021: " ,regressor.predict(poly_reg.fit_transform([[22]])))
# Out:
# [[0.73 0.73]
#  [0.85 0.85]]
# MSE:  0.0
# R2 Score:  1.0
# Predicted R/G in 2021:  [0.99]

# %%
#import data
col_list = ["Age", "SB/G"]
dataset = pd.read_csv('PadresBatters.csv', usecols=col_list)
X = dataset.iloc[10:12, :-1].values
y = dataset.iloc[10:12, -1].values


from sklearn.model_selection import train_test_split
X_train = X
X_test = X
y_train = y
y_test = y


from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
poly_reg = PolynomialFeatures(degree = 4)
X_poly = poly_reg.fit_transform(X_train)
regressor = LinearRegression()
regressor.fit(X_poly, y_train)

y_pred = regressor.predict(poly_reg.transform(X_test))
np.set_printoptions(precision=2)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))

#y_pred = regressor.predict(X_test)
X_grid = np.arange(min(X), max(X), 0.1)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(X_train, y_train, color = 'red')
plt.plot(X_grid, regressor.predict(poly_reg.fit_transform(X_grid)), color = 'blue')
plt.title('SB/G (Polynomial Reg)')
plt.xlabel('Age')
plt.ylabel('SB/G')
plt.show()

#reshape y 
y = y.reshape(len(y),1)

#Feature scaling the data
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
sc_y = StandardScaler()
X = sc_X.fit_transform(X)
y = sc_y.fit_transform(y)


from sklearn.metrics import mean_squared_error
print("MSE: " , mean_squared_error(y_test, y_pred))

from sklearn.metrics import r2_score
print("R2 Score: " , r2_score(y_test, y_pred))

print("Predicted SB/G in 2021: " ,regressor.predict(poly_reg.fit_transform([[22]])))
# Out:
# [[0.19 0.19]
#  [0.19 0.19]]
# MSE:  7.703719777548943e-34
# R2 Score:  1.0
# Predicted SB/G in 2021:  [0.18]

# %%
#import data
col_list = ["Age", "2B/G"]
dataset = pd.read_csv('PadresBatters.csv', usecols=col_list)
X = dataset.iloc[10:12, :-1].values
y = dataset.iloc[10:12, -1].values


from sklearn.model_selection import train_test_split
X_train = X
X_test = X
y_train = y
y_test = y


from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
poly_reg = PolynomialFeatures(degree = 4)
X_poly = poly_reg.fit_transform(X_train)
regressor = LinearRegression()
regressor.fit(X_poly, y_train)

y_pred = regressor.predict(poly_reg.transform(X_test))
np.set_printoptions(precision=2)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))

#y_pred = regressor.predict(X_test)
X_grid = np.arange(min(X), max(X), 0.1)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(X_train, y_train, color = 'red')
plt.plot(X_grid, regressor.predict(poly_reg.fit_transform(X_grid)), color = 'blue')
plt.title('2B/G (Polynomial Reg)')
plt.xlabel('Age')
plt.ylabel('2B/G')
plt.show()

#reshape y 
y = y.reshape(len(y),1)

#Feature scaling the data
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
sc_y = StandardScaler()
X = sc_X.fit_transform(X)
y = sc_y.fit_transform(y)


from sklearn.metrics import mean_squared_error
print("MSE: " , mean_squared_error(y_test, y_pred))

from sklearn.metrics import r2_score
print("R2 Score: " , r2_score(y_test, y_pred))

print("Predicted 2B/G in 2021: " ,regressor.predict(poly_reg.fit_transform([[22]])))
# Out:
# [[0.15 0.15]
#  [0.19 0.19]]
# MSE:  0.0
# R2 Score:  1.0
# Predicted 2B/G in 2021:  [0.22]

# %%
#import data
col_list = ["Age", "3B/G"]
dataset = pd.read_csv('PadresBatters.csv', usecols=col_list)
X = dataset.iloc[10:12, :-1].values
y = dataset.iloc[10:12, -1].values


from sklearn.model_selection import train_test_split
X_train = X
X_test = X
y_train = y
y_test = y


from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
poly_reg = PolynomialFeatures(degree = 4)
X_poly = poly_reg.fit_transform(X_train)
regressor = LinearRegression()
regressor.fit(X_poly, y_train)

y_pred = regressor.predict(poly_reg.transform(X_test))
np.set_printoptions(precision=2)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))

#y_pred = regressor.predict(X_test)
X_grid = np.arange(min(X), max(X), 0.1)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(X_train, y_train, color = 'red')
plt.plot(X_grid, regressor.predict(poly_reg.fit_transform(X_grid)), color = 'blue')
plt.title('3B/G (Polynomial Reg)')
plt.xlabel('Age')
plt.ylabel('3B/G')
plt.show()

#reshape y 
y = y.reshape(len(y),1)

#Feature scaling the data
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
sc_y = StandardScaler()
X = sc_X.fit_transform(X)
y = sc_y.fit_transform(y)


from sklearn.metrics import mean_squared_error
print("MSE: " , mean_squared_error(y_test, y_pred))

from sklearn.metrics import r2_score
print("R2 Score: " , r2_score(y_test, y_pred))

print("Predicted 3B/G in 2021: " ,regressor.predict(poly_reg.fit_transform([[22]])))
# Out:
# [[0.07 0.07]
#  [0.03 0.03]]
# MSE:  2.407412430484045e-35
# R2 Score:  1.0
# Predicted 3B/G in 2021:  [-0.01]

# %%
#import data
col_list = ["Age", "BB/G"]
dataset = pd.read_csv('PadresBatters.csv', usecols=col_list)
X = dataset.iloc[10:12, :-1].values
y = dataset.iloc[10:12, -1].values


from sklearn.model_selection import train_test_split
X_train = X
X_test = X
y_train = y
y_test = y


from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
poly_reg = PolynomialFeatures(degree = 4)
X_poly = poly_reg.fit_transform(X_train)
regressor = LinearRegression()
regressor.fit(X_poly, y_train)

y_pred = regressor.predict(poly_reg.transform(X_test))
np.set_printoptions(precision=2)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))

#y_pred = regressor.predict(X_test)
X_grid = np.arange(min(X), max(X), 0.1)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(X_train, y_train, color = 'red')
plt.plot(X_grid, regressor.predict(poly_reg.fit_transform(X_grid)), color = 'blue')
plt.title('BB/G (Polynomial Reg)')
plt.xlabel('Age')
plt.ylabel('BB/G')
plt.show()

#reshape y 
y = y.reshape(len(y),1)

#Feature scaling the data
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
sc_y = StandardScaler()
X = sc_X.fit_transform(X)
y = sc_y.fit_transform(y)


from sklearn.metrics import mean_squared_error
print("MSE: " , mean_squared_error(y_test, y_pred))

from sklearn.metrics import r2_score
print("R2 Score: " , r2_score(y_test, y_pred))

print("Predicted BB/G in 2021: " ,regressor.predict(poly_reg.fit_transform([[22]])))
# Out:
# [[0.36 0.36]
#  [0.46 0.46]]
# MSE:  1.5407439555097887e-33
# R2 Score:  1.0
# Predicted BB/G in 2021:  [0.57]

# %%
#import data
col_list = ["Age", "SO/G"]
dataset = pd.read_csv('PadresBatters.csv', usecols=col_list)
X = dataset.iloc[10:12, :-1].values
y = dataset.iloc[10:12, -1].values


from sklearn.model_selection import train_test_split
X_train = X
X_test = X
y_train = y
y_test = y


from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
poly_reg = PolynomialFeatures(degree = 4)
X_poly = poly_reg.fit_transform(X_train)
regressor = LinearRegression()
regressor.fit(X_poly, y_train)

y_pred = regressor.predict(poly_reg.transform(X_test))
np.set_printoptions(precision=2)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))

#y_pred = regressor.predict(X_test)
X_grid = np.arange(min(X), max(X), 0.1)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(X_train, y_train, color = 'red')
plt.plot(X_grid, regressor.predict(poly_reg.fit_transform(X_grid)), color = 'blue')
plt.title('So/G (Polynomial Reg)')
plt.xlabel('Age')
plt.ylabel('SO/G')
plt.show()

#reshape y 
y = y.reshape(len(y),1)

#Feature scaling the data
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
sc_y = StandardScaler()
X = sc_X.fit_transform(X)
y = sc_y.fit_transform(y)


from sklearn.metrics import mean_squared_error
print("MSE: " , mean_squared_error(y_test, y_pred))

from sklearn.metrics import r2_score
print("R2 Score: " , r2_score(y_test, y_pred))

print("Predicted SO/G in 2021: " ,regressor.predict(poly_reg.fit_transform([[22]])))
# Out:
# [[1.31 1.31]
#  [1.03 1.03]]
# MSE:  2.465190328815662e-32
# R2 Score:  1.0
# Predicted SO/G in 2021:  [0.72]
