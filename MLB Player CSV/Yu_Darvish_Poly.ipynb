# %%
#import packages
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

#import data
col_list = ["Name","Age", "ERA"]
dataset = pd.read_csv('PadresPitchers.csv', usecols=col_list)
X = dataset.iloc[56:64, :-1].values
y = dataset.iloc[56:64, -1].values

print(X)
# Out:
# [['Yu Darvish' 25]
#  ['Yu Darvish' 26]
#  ['Yu Darvish' 27]
#  ['Yu Darvish' 29]
#  ['Yu Darvish' 30]
#  ['Yu Darvish' 31]
#  ['Yu Darvish' 32]
#  ['Yu Darvish' 33]]

# %%
#import data
col_list = ["Age", "ERA"]
dataset = pd.read_csv('PadresPitchers.csv', usecols=col_list)
X = dataset.iloc[56:64, :-1].values
y = dataset.iloc[56:64, -1].values

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)


from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
poly_reg = PolynomialFeatures(degree = 4)
X_poly = poly_reg.fit_transform(X_train)
regressor = LinearRegression()
regressor.fit(X_poly, y_train)

y_pred = regressor.predict(poly_reg.transform(X_test))
np.set_printoptions(precision=2)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))

#y_pred = regressor.predict(X_test)
X_grid = np.arange(min(X), max(X), 0.1)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(X_train, y_train, color = 'red')
plt.plot(X_grid, regressor.predict(poly_reg.fit_transform(X_grid)), color = 'blue')
plt.title('ERA (Polynomial Reg)')
plt.xlabel('Age')
plt.ylabel('ERA')
plt.show()

#reshape y 
y = y.reshape(len(y),1)

#Feature scaling the data
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
sc_y = StandardScaler()
X = sc_X.fit_transform(X)
y = sc_y.fit_transform(y)


from sklearn.metrics import mean_squared_error
print("MSE: " , mean_squared_error(y_test, y_pred))

from sklearn.metrics import r2_score
print("R2 Score: " , r2_score(y_test, y_pred))

print("Predicted ERA in 2021: " ,regressor.predict(poly_reg.fit_transform([[34]])))
# Out:
# [[4.41 3.98]
#  [2.38 3.06]]
# MSE:  0.32385897670652886
# R2 Score:  -0.5305244645866207
# Predicted ERA in 2021:  [-3.54]

# %%
#import data
col_list = ["Age", "WHIP"]
dataset = pd.read_csv('PadresPitchers.csv', usecols=col_list)
X = dataset.iloc[56:64, :-1].values
y = dataset.iloc[56:64, -1].values

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)


from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
poly_reg = PolynomialFeatures(degree = 4)
X_poly = poly_reg.fit_transform(X_train)
regressor = LinearRegression()
regressor.fit(X_poly, y_train)

y_pred = regressor.predict(poly_reg.transform(X_test))
np.set_printoptions(precision=2)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))

#y_pred = regressor.predict(X_test)
X_grid = np.arange(min(X), max(X), 0.1)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(X_train, y_train, color = 'red')
plt.plot(X_grid, regressor.predict(poly_reg.fit_transform(X_grid)), color = 'blue')
plt.title('WHIP (Polynomial Reg)')
plt.xlabel('Age')
plt.ylabel('WHIP')
plt.show()

#reshape y 
y = y.reshape(len(y),1)

#Feature scaling the data
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
sc_y = StandardScaler()
X = sc_X.fit_transform(X)
y = sc_y.fit_transform(y)


from sklearn.metrics import mean_squared_error
print("MSE: " , mean_squared_error(y_test, y_pred))

from sklearn.metrics import r2_score
print("R2 Score: " , r2_score(y_test, y_pred))

print("Predicted wHIP in 2021: " ,regressor.predict(poly_reg.fit_transform([[34]])))
# Out:
# [[1.36 1.1 ]
#  [0.96 1.26]]
# MSE:  0.07803715779170682
# R2 Score:  -11.193305904954201
# Predicted wHIP in 2021:  [-0.03]

# %%
#import data
col_list = ["Age", "AVG"]
dataset = pd.read_csv('PadresPitchers.csv', usecols=col_list)
X = dataset.iloc[56:64, :-1].values
y = dataset.iloc[56:64, -1].values

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)


from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
poly_reg = PolynomialFeatures(degree = 4)
X_poly = poly_reg.fit_transform(X_train)
regressor = LinearRegression()
regressor.fit(X_poly, y_train)

y_pred = regressor.predict(poly_reg.transform(X_test))
np.set_printoptions(precision=2)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))

#y_pred = regressor.predict(X_test)
X_grid = np.arange(min(X), max(X), 0.1)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(X_train, y_train, color = 'red')
plt.plot(X_grid, regressor.predict(poly_reg.fit_transform(X_grid)), color = 'blue')
plt.title('AVG (Polynomial Reg)')
plt.xlabel('Age')
plt.ylabel('AVG')
plt.show()

#reshape y 
y = y.reshape(len(y),1)

#Feature scaling the data
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
sc_y = StandardScaler()
X = sc_X.fit_transform(X)
y = sc_y.fit_transform(y)


from sklearn.metrics import mean_squared_error
print("MSE: " , mean_squared_error(y_test, y_pred))

from sklearn.metrics import r2_score
print("R2 Score: " , r2_score(y_test, y_pred))

print("Predicted AVG in 2021: " ,regressor.predict(poly_reg.fit_transform([[34]])))
# Out:
# [[0.23 0.21]
#  [0.19 0.24]]
# MSE:  0.0014434686937356274
# R2 Score:  -5.865487247256268
# Predicted AVG in 2021:  [0.18]

# %%
#import data
col_list = ["Age", "K/9"]
dataset = pd.read_csv('PadresPitchers.csv', usecols=col_list)
X = dataset.iloc[56:64, :-1].values
y = dataset.iloc[56:64, -1].values

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
poly_reg = PolynomialFeatures(degree = 4)
X_poly = poly_reg.fit_transform(X_train)
regressor = LinearRegression()
regressor.fit(X_poly, y_train)

y_pred = regressor.predict(poly_reg.transform(X_test))
np.set_printoptions(precision=2)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))

#y_pred = regressor.predict(X_test)
X_grid = np.arange(min(X), max(X), 0.1)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(X_train, y_train, color = 'red')
plt.plot(X_grid, regressor.predict(poly_reg.fit_transform(X_grid)), color = 'blue')
plt.title('K/9 (Polynomial Reg)')
plt.xlabel('Age')
plt.ylabel('K/9')
plt.show()

#reshape y 
y = y.reshape(len(y),1)

#Feature scaling the data
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
sc_y = StandardScaler()
X = sc_X.fit_transform(X)
y = sc_y.fit_transform(y)


from sklearn.metrics import mean_squared_error
print("MSE: " , mean_squared_error(y_test, y_pred))

from sklearn.metrics import r2_score
print("R2 Score: " , r2_score(y_test, y_pred))

print("Predicted K/9 in 2021: " ,regressor.predict(poly_reg.fit_transform([[34]])))
# Out:
# [[10.74 11.54]
#  [12.33 11.35]]
# MSE:  0.796368818865556
# R2 Score:  -87.24031233967425
# Predicted K/9 in 2021:  [11.29]

# %%
#import data
col_list = ["Age", "BB/9"]
dataset = pd.read_csv('PadresPitchers.csv', usecols=col_list)
X = dataset.iloc[56:64, :-1].values
y = dataset.iloc[56:64, -1].values

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
poly_reg = PolynomialFeatures(degree = 4)
X_poly = poly_reg.fit_transform(X_train)
regressor = LinearRegression()
regressor.fit(X_poly, y_train)

y_pred = regressor.predict(poly_reg.transform(X_test))
np.set_printoptions(precision=2)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))

#y_pred = regressor.predict(X_test)
X_grid = np.arange(min(X), max(X), 0.1)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(X_train, y_train, color = 'red')
plt.plot(X_grid, regressor.predict(poly_reg.fit_transform(X_grid)), color = 'blue')
plt.title('BB/9 (Polynomial Reg)')
plt.xlabel('Age')
plt.ylabel('BB/9')
plt.show()

#reshape y 
y = y.reshape(len(y),1)

#Feature scaling the data
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
sc_y = StandardScaler()
X = sc_X.fit_transform(X)
y = sc_y.fit_transform(y)


from sklearn.metrics import mean_squared_error
print("MSE: " , mean_squared_error(y_test, y_pred))

from sklearn.metrics import r2_score
print("R2 Score: " , r2_score(y_test, y_pred))

print("Predicted BB/9 in 2021: " ,regressor.predict(poly_reg.fit_transform([[34]])))
# Out:
# [[4.39 2.82]
#  [2.55 3.06]]
# MSE:  1.3571465711610515
# R2 Score:  -93.24628966396175
# Predicted BB/9 in 2021:  [-5.74]

# %%
#import data
col_list = ["Age", "ADJ_IP"]
dataset = pd.read_csv('PadresPitchers.csv', usecols=col_list)
X = dataset.iloc[56:64, :-1].values
y = dataset.iloc[56:64, -1].values

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
poly_reg = PolynomialFeatures(degree = 4)
X_poly = poly_reg.fit_transform(X_train)
regressor = LinearRegression()
regressor.fit(X_poly, y_train)

y_pred = regressor.predict(poly_reg.transform(X_test))
np.set_printoptions(precision=2)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))

#y_pred = regressor.predict(X_test)
X_grid = np.arange(min(X), max(X), 0.1)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(X_train, y_train, color = 'red')
plt.plot(X_grid, regressor.predict(poly_reg.fit_transform(X_grid)), color = 'blue')
plt.title('ADJ_IP(Polynomial Reg)')
plt.xlabel('Age')
plt.ylabel('IP')
plt.show()

#reshape y 
y = y.reshape(len(y),1)

#Feature scaling the data
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
sc_y = StandardScaler()
X = sc_X.fit_transform(X)
y = sc_y.fit_transform(y)


from sklearn.metrics import mean_squared_error
print("MSE: " , mean_squared_error(y_test, y_pred))

from sklearn.metrics import r2_score
print("R2 Score: " , r2_score(y_test, y_pred))

print("Predicted IP in 2021: " ,regressor.predict(poly_reg.fit_transform([[34]])))
# Out:
# [[ 95.89 178.2 ]
#  [197.94 144.1 ]]
# MSE:  4837.202806513892
# R2 Score:  -15.639701435363968
# Predicted IP in 2021:  [452.05]

# %%
#import data
col_list = ["Age", "ADJ_GS"]
dataset = pd.read_csv('PadresPitchers.csv', usecols=col_list)
X = dataset.iloc[56:64, :-1].values
y = dataset.iloc[56:64, -1].values

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
poly_reg = PolynomialFeatures(degree = 4)
X_poly = poly_reg.fit_transform(X_train)
regressor = LinearRegression()
regressor.fit(X_poly, y_train)

y_pred = regressor.predict(poly_reg.transform(X_test))
np.set_printoptions(precision=2)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))

#y_pred = regressor.predict(X_test)
X_grid = np.arange(min(X), max(X), 0.1)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(X_train, y_train, color = 'red')
plt.plot(X_grid, regressor.predict(poly_reg.fit_transform(X_grid)), color = 'blue')
plt.title('ADJ_GS (Polynomial Reg)')
plt.xlabel('Age')
plt.ylabel('GS')
plt.show()

#reshape y 
y = y.reshape(len(y),1)

#Feature scaling the data
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
sc_y = StandardScaler()
X = sc_X.fit_transform(X)
y = sc_y.fit_transform(y)


from sklearn.metrics import mean_squared_error
print("MSE: " , mean_squared_error(y_test, y_pred))

from sklearn.metrics import r2_score
print("R2 Score: " , r2_score(y_test, y_pred))

print("Predicted GS in 2021: " ,regressor.predict(poly_reg.fit_transform([[34]])))
# Out:
# [[16.28 31.  ]
#  [30.86 22.  ]]
# MSE:  147.5835434494827
# R2 Score:  -6.288076219727541
# Predicted GS in 2021:  [69.6]
