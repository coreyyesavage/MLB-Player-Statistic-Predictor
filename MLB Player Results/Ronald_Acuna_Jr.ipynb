# %%
#import packages
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

#import data
col_list = ["Age", "AVG"]
dataset = pd.read_csv('Top50batters.csv', usecols=col_list)
X = dataset.iloc[230:233, :-1].values
y = dataset.iloc[230:233, -1].values

print(X)
# Out:
# [[20]
#  [21]
#  [22]]

# %%
y_train = y
y_test = y
X_test = X
X_train = X

#reshape y 
y = y.reshape(len(y),1)

#Feature scaling the data
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
sc_y = StandardScaler()
X = sc_X.fit_transform(X)
y = sc_y.fit_transform(y)

#Train the SVR
from sklearn.svm import SVR
regressor = SVR(kernel = 'rbf')
regressor.fit(X, y)

#Predict a new result
print("Batting AVG for 2021: ", sc_y.inverse_transform(regressor.predict(sc_X.transform([[23]]))))

y_pred = sc_y.inverse_transform(regressor.predict(sc_X.transform(X_test)))
np.set_printoptions(precision=3)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))

from sklearn.metrics import mean_squared_error
print(mean_squared_error(y_test, y_pred))


X_grid = np.arange(min(sc_X.inverse_transform(X)), max(sc_X.inverse_transform(X)), 0.1)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(sc_X.inverse_transform(X), sc_y.inverse_transform(y), color = 'red')
plt.plot(X_grid, sc_y.inverse_transform(regressor.predict(sc_X.transform(X_grid))), color = 'blue')
plt.title('Ronald Acuna Jr. AVG (SVR)')
plt.xlabel('Age')
plt.ylabel('AVG')
plt.show()
# Out:
# Batting AVG for 2021:  [0.272]
# [[0.291 0.293]
#  [0.278 0.28 ]
#  [0.258 0.25 ]]
# 2.6028146342233618e-05
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)

# %%
#import data
col_list = ["Age", "SLG"]
dataset = pd.read_csv('Top50batters.csv', usecols=col_list)
X = dataset.iloc[230:233, :-1].values
y = dataset.iloc[230:233, -1].values

y_train = y
y_test = y
X_test = X
X_train = X

#reshape y 
y = y.reshape(len(y),1)

#Feature scaling the data
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
sc_y = StandardScaler()
X = sc_X.fit_transform(X)
y = sc_y.fit_transform(y)

#Train the SVR
from sklearn.svm import SVR
regressor = SVR(kernel = 'rbf')
regressor.fit(X, y)

#Predict a new result
print("SLG for 2021: ", sc_y.inverse_transform(regressor.predict(sc_X.transform([[23]]))))

y_pred = sc_y.inverse_transform(regressor.predict(sc_X.transform(X_test)))
np.set_printoptions(precision=3)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))

from sklearn.metrics import mean_squared_error
print(mean_squared_error(y_test, y_pred))


X_grid = np.arange(min(sc_X.inverse_transform(X)), max(sc_X.inverse_transform(X)), 0.1)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(sc_X.inverse_transform(X), sc_y.inverse_transform(y), color = 'red')
plt.plot(X_grid, sc_y.inverse_transform(regressor.predict(sc_X.transform(X_grid))), color = 'blue')
plt.title('Ronald Acuna Jr. SLG (SVR)')
plt.xlabel('Age')
plt.ylabel('SLG')
plt.show()
# Out:
# SLG for 2021:  [0.562]
# [[0.551 0.552]
#  [0.537 0.518]
#  [0.577 0.581]]
# 0.00012360556665370925
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)

# %%
#import data
col_list = ["Age", "OBP"]
dataset = pd.read_csv('Top50batters.csv', usecols=col_list)
X = dataset.iloc[230:233, :-1].values
y = dataset.iloc[230:233, -1].values

y_train = y
y_test = y
X_test = X
X_train = X

#reshape y 
y = y.reshape(len(y),1)

#Feature scaling the data
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
sc_y = StandardScaler()
X = sc_X.fit_transform(X)
y = sc_y.fit_transform(y)

#Train the SVR
from sklearn.svm import SVR
regressor = SVR(kernel = 'rbf')
regressor.fit(X, y)

#Predict a new result
print("OBP for 2021: ", sc_y.inverse_transform(regressor.predict(sc_X.transform([[23]]))))

y_pred = sc_y.inverse_transform(regressor.predict(sc_X.transform(X_test)))
np.set_printoptions(precision=3)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))

from sklearn.metrics import mean_squared_error
print(mean_squared_error(y_test, y_pred))


X_grid = np.arange(min(sc_X.inverse_transform(X)), max(sc_X.inverse_transform(X)), 0.1)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(sc_X.inverse_transform(X), sc_y.inverse_transform(y), color = 'red')
plt.plot(X_grid, sc_y.inverse_transform(regressor.predict(sc_X.transform(X_grid))), color = 'blue')
plt.title('Ronald Acuna Jr OBP (SVR)')
plt.xlabel('Age')
plt.ylabel('OBP')
plt.show()
# Out:
# OBP for 2021:  [0.381]
# [[0.368 0.366]
#  [0.367 0.365]
#  [0.393 0.406]]
# 5.759378594086308e-05
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)

# %%
#import data
col_list = ["Age", "OPS"]
dataset = pd.read_csv('Top50batters.csv', usecols=col_list)
X = dataset.iloc[230:233, :-1].values
y = dataset.iloc[230:233, -1].values

y_train = y
y_test = y
X_test = X
X_train = X

#reshape y 
y = y.reshape(len(y),1)

#Feature scaling the data
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
sc_y = StandardScaler()
X = sc_X.fit_transform(X)
y = sc_y.fit_transform(y)

#Train the SVR
from sklearn.svm import SVR
regressor = SVR(kernel = 'rbf')
regressor.fit(X, y)

#Predict a new result
print("OPS for 2021: ", sc_y.inverse_transform(regressor.predict(sc_X.transform([[23]]))))

y_pred = sc_y.inverse_transform(regressor.predict(sc_X.transform(X_test)))
np.set_printoptions(precision=3)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))

from sklearn.metrics import mean_squared_error
print(mean_squared_error(y_test, y_pred))


X_grid = np.arange(min(sc_X.inverse_transform(X)), max(sc_X.inverse_transform(X)), 0.1)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(sc_X.inverse_transform(X), sc_y.inverse_transform(y), color = 'red')
plt.plot(X_grid, sc_y.inverse_transform(regressor.predict(sc_X.transform(X_grid))), color = 'blue')
plt.title('Ronald Acuna Jr OPS (SVR)')
plt.xlabel('Age')
plt.ylabel('OPS')
plt.show()
# Out:
# OPS for 2021:  [0.936]
# [[0.917 0.917]
#  [0.893 0.883]
#  [0.96  0.987]]
# 0.0002723737511406348
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)

# %%
#import data
col_list = ["Age", "%G"]
dataset = pd.read_csv('Top50batters.csv', usecols=col_list)
X = dataset.iloc[230:233, :-1].values
y = dataset.iloc[230:233, -1].values

y_train = y
y_test = y
X_test = X
X_train = X

#reshape y 
y = y.reshape(len(y),1)

#Feature scaling the data
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
sc_y = StandardScaler()
X = sc_X.fit_transform(X)
y = sc_y.fit_transform(y)

#Train the SVR
from sklearn.svm import SVR
regressor = SVR(kernel = 'rbf')
regressor.fit(X, y)

#Predict a new result
print(" %G for 2021: ", sc_y.inverse_transform(regressor.predict(sc_X.transform([[23]]))))


y_pred = sc_y.inverse_transform(regressor.predict(sc_X.transform(X_test)))
np.set_printoptions(precision=3)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))

from sklearn.metrics import mean_squared_error
print(mean_squared_error(y_test, y_pred))


X_grid = np.arange(min(sc_X.inverse_transform(X)), max(sc_X.inverse_transform(X)), 0.1)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(sc_X.inverse_transform(X), sc_y.inverse_transform(y), color = 'red')
plt.plot(X_grid, sc_y.inverse_transform(regressor.predict(sc_X.transform(X_grid))), color = 'blue')
plt.title('Ronald Acuna Jr %G (SVR)')
plt.xlabel('Age')
plt.ylabel('%G')
plt.show()
# Out:
#  %G for 2021:  [0.8]
# [[0.802 0.793]
#  [0.88  0.963]
#  [0.775 0.767]]
# 0.0023298852408885754
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)

# %%
.8 * 162
# Out:
# 129.6

# %%
#import data
col_list = ["Age", "PA/G"]
dataset = pd.read_csv('Top50batters.csv', usecols=col_list)
X = dataset.iloc[230:233, :-1].values
y = dataset.iloc[230:233, -1].values

y_train = y
y_test = y
X_test = X
X_train = X

#reshape y 
y = y.reshape(len(y),1)

#Feature scaling the data
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
sc_y = StandardScaler()
X = sc_X.fit_transform(X)
y = sc_y.fit_transform(y)

#Train the SVR
from sklearn.svm import SVR
regressor = SVR(kernel = 'rbf')
regressor.fit(X, y)

#Predict a new result
print(" PA/G for 2021: ", sc_y.inverse_transform(regressor.predict(sc_X.transform([[23]]))))


y_pred = sc_y.inverse_transform(regressor.predict(sc_X.transform(X_test)))
np.set_printoptions(precision=3)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))

from sklearn.metrics import mean_squared_error
print(mean_squared_error(y_test, y_pred))


X_grid = np.arange(min(sc_X.inverse_transform(X)), max(sc_X.inverse_transform(X)), 0.1)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(sc_X.inverse_transform(X), sc_y.inverse_transform(y), color = 'red')
plt.plot(X_grid, sc_y.inverse_transform(regressor.predict(sc_X.transform(X_grid))), color = 'blue')
plt.title('Ronald Acuna Jr PA/G (SVR)')
plt.xlabel('Age')
plt.ylabel('PA/G')
plt.show()
# Out:
#  PA/G for 2021:  [4.414]
# [[4.397 4.387]
#  [4.495 4.583]
#  [4.4   4.391]]
# 0.0026578185681225713
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)

# %%
print(4.414 * 130, "At bats")
# Out:
# 573.8199999999999 At bats

# %%
#import data
col_list = ["Age", "HR/G"]
dataset = pd.read_csv('Top50batters.csv', usecols=col_list)
X = dataset.iloc[230:233, :-1].values
y = dataset.iloc[230:233, -1].values

y_train = y
y_test = y
X_test = X
X_train = X

#reshape y 
y = y.reshape(len(y),1)

#Feature scaling the data
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
sc_y = StandardScaler()
X = sc_X.fit_transform(X)
y = sc_y.fit_transform(y)

#Train the SVR
from sklearn.svm import SVR
regressor = SVR(kernel = 'rbf')
regressor.fit(X, y)

#Predict a new result
print(" HR/G for 2021: ", sc_y.inverse_transform(regressor.predict(sc_X.transform([[23]]))))


y_pred = sc_y.inverse_transform(regressor.predict(sc_X.transform(X_test)))
np.set_printoptions(precision=3)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))

from sklearn.metrics import mean_squared_error
print(mean_squared_error(y_test, y_pred))


X_grid = np.arange(min(sc_X.inverse_transform(X)), max(sc_X.inverse_transform(X)), 0.1)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(sc_X.inverse_transform(X), sc_y.inverse_transform(y), color = 'red')
plt.plot(X_grid, sc_y.inverse_transform(regressor.predict(sc_X.transform(X_grid))), color = 'blue')
plt.title('Ronald Acuna Jr HR/G (SVR)')
plt.xlabel('Age')
plt.ylabel('HR')
plt.show()
# Out:
#  HR/G for 2021:  [0.272]
# [[0.237 0.234]
#  [0.266 0.263]
#  [0.294 0.304]]
# 3.811750767810364e-05
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)

# %%
.272 * 130
# Out:
# 35.36

# %%
#import data
col_list = ["Age", "RBI/G"]
dataset = pd.read_csv('Top50batters.csv', usecols=col_list)
X = dataset.iloc[230:233, :-1].values
y = dataset.iloc[230:233, -1].values

y_train = y
y_test = y
X_test = X
X_train = X

#reshape y 
y = y.reshape(len(y),1)

#Feature scaling the data
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
sc_y = StandardScaler()
X = sc_X.fit_transform(X)
y = sc_y.fit_transform(y)

#Train the SVR
from sklearn.svm import SVR
regressor = SVR(kernel = 'rbf')
regressor.fit(X, y)

#Predict a new result
print(" RBI/G for 2021: ", sc_y.inverse_transform(regressor.predict(sc_X.transform([[23]]))))


y_pred = sc_y.inverse_transform(regressor.predict(sc_X.transform(X_test)))
np.set_printoptions(precision=3)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))

from sklearn.metrics import mean_squared_error
print(mean_squared_error(y_test, y_pred))


X_grid = np.arange(min(sc_X.inverse_transform(X)), max(sc_X.inverse_transform(X)), 0.1)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(sc_X.inverse_transform(X), sc_y.inverse_transform(y), color = 'red')
plt.plot(X_grid, sc_y.inverse_transform(regressor.predict(sc_X.transform(X_grid))), color = 'blue')
plt.title('Ronald Acuna Jr RBI/G (SVR)')
plt.xlabel('Age')
plt.ylabel('RBI/G')
plt.show()
# Out:
#  RBI/G for 2021:  [0.621]
# [[0.597 0.577]
#  [0.644 0.647]
#  [0.628 0.63 ]]
# 0.00015042112839885432
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)

# %%
.621 * 130
# Out:
# 80.73

# %%
#import data
col_list = ["Age", "R/G"]
dataset = pd.read_csv('Top50batters.csv', usecols=col_list)
X = dataset.iloc[230:233, :-1].values
y = dataset.iloc[230:233, -1].values

y_train = y
y_test = y
X_test = X
X_train = X

#reshape y 
y = y.reshape(len(y),1)

#Feature scaling the data
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
sc_y = StandardScaler()
X = sc_X.fit_transform(X)
y = sc_y.fit_transform(y)

#Train the SVR
from sklearn.svm import SVR
regressor = SVR(kernel = 'rbf')
regressor.fit(X, y)

#Predict a new result
print(" R/G for 2021: ", sc_y.inverse_transform(regressor.predict(sc_X.transform([[23]]))))


y_pred = sc_y.inverse_transform(regressor.predict(sc_X.transform(X_test)))
np.set_printoptions(precision=3)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))

from sklearn.metrics import mean_squared_error
print(mean_squared_error(y_test, y_pred))


X_grid = np.arange(min(sc_X.inverse_transform(X)), max(sc_X.inverse_transform(X)), 0.1)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(sc_X.inverse_transform(X), sc_y.inverse_transform(y), color = 'red')
plt.plot(X_grid, sc_y.inverse_transform(regressor.predict(sc_X.transform(X_grid))), color = 'blue')
plt.title('Ronald Acuna Jr R/G (SVR)')
plt.xlabel('Age')
plt.ylabel('R/G')
plt.show()
# Out:
#  R/G for 2021:  [0.859]
# [[0.715 0.703]
#  [0.826 0.814]
#  [0.953 1.   ]]
# 0.0008488695175622061
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)

# %%
.859 * 130
# Out:
# 111.67

# %%
#import data
col_list = ["Age", "SB/G"]
dataset = pd.read_csv('Top50batters.csv', usecols=col_list)
X = dataset.iloc[230:233, :-1].values
y = dataset.iloc[230:233, -1].values

y_train = y
y_test = y
X_test = X
X_train = X

#reshape y 
y = y.reshape(len(y),1)

#Feature scaling the data
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
sc_y = StandardScaler()
X = sc_X.fit_transform(X)
y = sc_y.fit_transform(y)

#Train the SVR
from sklearn.svm import SVR
regressor = SVR(kernel = 'rbf')
regressor.fit(X, y)

#Predict a new result
print(" SB/G for 2021: ", sc_y.inverse_transform(regressor.predict(sc_X.transform([[23]]))))


y_pred = sc_y.inverse_transform(regressor.predict(sc_X.transform(X_test)))
np.set_printoptions(precision=3)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))

from sklearn.metrics import mean_squared_error
print(mean_squared_error(y_test, y_pred))


X_grid = np.arange(min(sc_X.inverse_transform(X)), max(sc_X.inverse_transform(X)), 0.1)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(sc_X.inverse_transform(X), sc_y.inverse_transform(y), color = 'red')
plt.plot(X_grid, sc_y.inverse_transform(regressor.predict(sc_X.transform(X_grid))), color = 'blue')
plt.title('Ronald Acuna Jr SB/G (SVR)')
plt.xlabel('Age')
plt.ylabel('SB/G')
plt.show()
# Out:
#  SB/G for 2021:  [0.173]
# [[0.148 0.144]
#  [0.204 0.237]
#  [0.178 0.174]]
# 0.00038066788617696813
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)

# %%
.173 * 130
# Out:
# 22.49

# %%
#import data
col_list = ["Age", "2B/G"]
dataset = pd.read_csv('Top50batters.csv', usecols=col_list)
X = dataset.iloc[230:233, :-1].values
y = dataset.iloc[230:233, -1].values

y_train = y
y_test = y
X_test = X
X_train = X

#reshape y 
y = y.reshape(len(y),1)

#Feature scaling the data
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
sc_y = StandardScaler()
X = sc_X.fit_transform(X)
y = sc_y.fit_transform(y)

#Train the SVR
from sklearn.svm import SVR
regressor = SVR(kernel = 'rbf')
regressor.fit(X, y)

#Predict a new result
print(" 2B/G for 2021: ", sc_y.inverse_transform(regressor.predict(sc_X.transform([[23]]))))


y_pred = sc_y.inverse_transform(regressor.predict(sc_X.transform(X_test)))
np.set_printoptions(precision=3)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))

from sklearn.metrics import mean_squared_error
print(mean_squared_error(y_test, y_pred))


X_grid = np.arange(min(sc_X.inverse_transform(X)), max(sc_X.inverse_transform(X)), 0.1)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(sc_X.inverse_transform(X), sc_y.inverse_transform(y), color = 'red')
plt.plot(X_grid, sc_y.inverse_transform(regressor.predict(sc_X.transform(X_grid))), color = 'blue')
plt.title('Ronald Acuna Jr 2B/G (SVR)')
plt.xlabel('Age')
plt.ylabel('2B/G')
plt.show()
# Out:
#  2B/G for 2021:  [0.225]
# [[0.23  0.234]
#  [0.185 0.141]
#  [0.235 0.239]]
# 0.0006450310761112978
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)

# %%
.225 * 130
# Out:
# 29.25

# %%
#import data
col_list = ["Age", "3B/G"]
dataset = pd.read_csv('Top50batters.csv', usecols=col_list)
X = dataset.iloc[230:233, :-1].values
y = dataset.iloc[230:233, -1].values

y_train = y
y_test = y
X_test = X
X_train = X

#reshape y 
y = y.reshape(len(y),1)

#Feature scaling the data
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
sc_y = StandardScaler()
X = sc_X.fit_transform(X)
y = sc_y.fit_transform(y)

#Train the SVR
from sklearn.svm import SVR
regressor = SVR(kernel = 'rbf')
regressor.fit(X, y)

#Predict a new result
print(" 3B/G for 2021: ", sc_y.inverse_transform(regressor.predict(sc_X.transform([[23]]))))


y_pred = sc_y.inverse_transform(regressor.predict(sc_X.transform(X_test)))
np.set_printoptions(precision=3)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))

from sklearn.metrics import mean_squared_error
print(mean_squared_error(y_test, y_pred))


X_grid = np.arange(min(sc_X.inverse_transform(X)), max(sc_X.inverse_transform(X)), 0.1)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(sc_X.inverse_transform(X), sc_y.inverse_transform(y), color = 'red')
plt.plot(X_grid, sc_y.inverse_transform(regressor.predict(sc_X.transform(X_grid))), color = 'blue')
plt.title('Ronald Acuna Jr 3B/G (SVR)')
plt.xlabel('Age')
plt.ylabel('3B/G')
plt.show()
# Out:
#  3B/G for 2021:  [0.012]
# [[0.03  0.036]
#  [0.014 0.013]
#  [0.001 0.   ]]
# 1.392887674997772e-05
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)

# %%
.012 * 130
# Out:
# 1.56

# %%
#import data
col_list = ["Age", "WAR/G"]
dataset = pd.read_csv('Top50batters.csv', usecols=col_list)
X = dataset.iloc[230:233, :-1].values
y = dataset.iloc[230:233, -1].values

y_train = y
y_test = y
X_test = X
X_train = X

#reshape y 
y = y.reshape(len(y),1)

#Feature scaling the data
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
sc_y = StandardScaler()
X = sc_X.fit_transform(X)
y = sc_y.fit_transform(y)

#Train the SVR
from sklearn.svm import SVR
regressor = SVR(kernel = 'rbf')
regressor.fit(X, y)

#Predict a new result
print(" WAR for 2021: ", sc_y.inverse_transform(regressor.predict(sc_X.transform([[23]]))))


y_pred = sc_y.inverse_transform(regressor.predict(sc_X.transform(X_test)))
np.set_printoptions(precision=3)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))

from sklearn.metrics import mean_squared_error
print(mean_squared_error(y_test, y_pred))


X_grid = np.arange(min(sc_X.inverse_transform(X)), max(sc_X.inverse_transform(X)), 0.1)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(sc_X.inverse_transform(X), sc_y.inverse_transform(y), color = 'red')
plt.plot(X_grid, sc_y.inverse_transform(regressor.predict(sc_X.transform(X_grid))), color = 'blue')
plt.title('Ronald Acuna WAR (SVR)')
plt.xlabel('Age')
plt.ylabel('WAR')
plt.show()
# Out:
#  WAR for 2021:  [0.041]
# [[0.034 0.033]
#  [0.037 0.036]
#  [0.047 0.052]]
# 8.99300486746227e-06
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)

# %%
.041 * 130
# Out:
# 5.33
