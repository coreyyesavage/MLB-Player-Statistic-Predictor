# %%
#import packages
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

#import data
col_list = ["Name","Age", "AVG"]
dataset = pd.read_csv('PadresBatters.csv', usecols=col_list)
X = dataset.iloc[15:21, :-1].values
y = dataset.iloc[15:21, -1].values

print(X)
# Out:
# [['Jurickson Profar' 20]
#  ['Jurickson Profar' 23]
#  ['Jurickson Profar' 24]
#  ['Jurickson Profar' 25]
#  ['Jurickson Profar' 26]
#  ['Jurickson Profar' 27]]

# %%
#import data
col_list = ["Age", "AVG"]
dataset = pd.read_csv('PadresBatters.csv', usecols=col_list)
X = dataset.iloc[15:21, :-1].values
y = dataset.iloc[15:21, -1].values

from sklearn.model_selection import train_test_split
X_train = X
X_test = X
y_train = y
y_test = y

from sklearn.ensemble import RandomForestRegressor
regressor = RandomForestRegressor(n_estimators = 10, random_state = 0)
regressor.fit(X_train, y_train)

y_pred = regressor.predict(X_test)
np.set_printoptions(precision=3)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))

X_grid = np.arange(min(X), max(X), 0.01)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(X, y, color = 'red')
plt.plot(X_grid, regressor.predict(X_grid), color = 'blue')
plt.title('Batting AVG (Random Forest Regression)')
plt.xlabel('Age')
plt.ylabel('AVG')
plt.show()

#reshape y 
y = y.reshape(len(y),1)

from sklearn.metrics import mean_squared_error
print("MSE: " , mean_squared_error(y_test, y_pred))

from sklearn.metrics import r2_score
print("R2 Score: " , r2_score(y_test, y_pred))

print("Predicted Batting AVG in 2021: " ,regressor.predict([[28]]))
# Out:
# [[0.229 0.234]
#  [0.229 0.239]
#  [0.195 0.172]
#  [0.238 0.254]
#  [0.225 0.218]
#  [0.258 0.278]]
# MSE:  0.00023347000000000024
# R2 Score:  0.7827343931756494
# Predicted Batting AVG in 2021:  [0.258]

# %%
#import data
col_list = ["Age", "SLG"]
dataset = pd.read_csv('PadresBatters.csv', usecols=col_list)
X = dataset.iloc[15:21, :-1].values
y = dataset.iloc[15:21, -1].values

from sklearn.model_selection import train_test_split
X_train = X
X_test = X
y_train = y
y_test = y

from sklearn.ensemble import RandomForestRegressor
regressor = RandomForestRegressor(n_estimators = 10, random_state = 0)
regressor.fit(X_train, y_train)

y_pred = regressor.predict(X_test)
np.set_printoptions(precision=3)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))

X_grid = np.arange(min(X), max(X), 0.01)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(X, y, color = 'red')
plt.plot(X_grid, regressor.predict(X_grid), color = 'blue')
plt.title('SLG% (Random Forest Regression)')
plt.xlabel('Age')
plt.ylabel('SLG%')
plt.show()

#reshape y 
y = y.reshape(len(y),1)

from sklearn.metrics import mean_squared_error
print("MSE: " , mean_squared_error(y_test, y_pred))

from sklearn.metrics import r2_score
print("R2 Score: " , r2_score(y_test, y_pred))

print("Predicted SLG% in 2021: " ,regressor.predict([[28]]))
# Out:
# [[0.324 0.336]
#  [0.336 0.338]
#  [0.27  0.207]
#  [0.408 0.458]
#  [0.42  0.41 ]
#  [0.426 0.428]]
# MSE:  0.0011301633333333308
# R2 Score:  0.8352084506243599
# Predicted SLG% in 2021:  [0.426]

# %%
#import data
col_list = ["Age", "OBP"]
dataset = pd.read_csv('PadresBatters.csv', usecols=col_list)
X = dataset.iloc[15:21, :-1].values
y = dataset.iloc[15:21, -1].values

from sklearn.model_selection import train_test_split
X_train = X
X_test = X
y_train = y
y_test = y

from sklearn.ensemble import RandomForestRegressor
regressor = RandomForestRegressor(n_estimators = 10, random_state = 0)
regressor.fit(X_train, y_train)

y_pred = regressor.predict(X_test)
np.set_printoptions(precision=3)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))

X_grid = np.arange(min(X), max(X), 0.01)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(X, y, color = 'red')
plt.plot(X_grid, regressor.predict(X_grid), color = 'blue')
plt.title('OBP% (Random Forest Regression)')
plt.xlabel('Age')
plt.ylabel('OBP%')
plt.show()

#reshape y 
y = y.reshape(len(y),1)

from sklearn.metrics import mean_squared_error
print("MSE: " , mean_squared_error(y_test, y_pred))

from sklearn.metrics import r2_score
print("R2 Score: " , r2_score(y_test, y_pred))

print("Predicted OBP% in 2021: " ,regressor.predict([[28]]))
# Out:
# [[0.31  0.308]
#  [0.318 0.321]
#  [0.305 0.294]
#  [0.327 0.335]
#  [0.308 0.301]
#  [0.33  0.343]]
# MSE:  7.08099999999999e-05
# R2 Score:  0.7742507970244424
# Predicted OBP% in 2021:  [0.33]

# %%
#import data
col_list = ["Age", "OPS"]
dataset = pd.read_csv('PadresBatters.csv', usecols=col_list)
X = dataset.iloc[15:21, :-1].values
y = dataset.iloc[15:21, -1].values

from sklearn.model_selection import train_test_split
X_train = X
X_test = X
y_train = y
y_test = y

from sklearn.ensemble import RandomForestRegressor
regressor = RandomForestRegressor(n_estimators = 10, random_state = 0)
regressor.fit(X_train, y_train)

y_pred = regressor.predict(X_test)
np.set_printoptions(precision=3)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))

X_grid = np.arange(min(X), max(X), 0.01)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(X, y, color = 'red')
plt.plot(X_grid, regressor.predict(X_grid), color = 'blue')
plt.title('OPS (Random Forest Regression)')
plt.xlabel('Age')
plt.ylabel('OPS')
plt.show()

#reshape y 
y = y.reshape(len(y),1)

from sklearn.metrics import mean_squared_error
print("MSE: " , mean_squared_error(y_test, y_pred))

from sklearn.metrics import r2_score
print("R2 Score: " , r2_score(y_test, y_pred))

print("Predicted OPS in 2021: " ,regressor.predict([[28]]))
# Out:
# [[0.635 0.644]
#  [0.655 0.66 ]
#  [0.575 0.501]
#  [0.735 0.793]
#  [0.727 0.711]
#  [0.755 0.771]]
# MSE:  0.0015944900000000014
# R2 Score:  0.8283895386381572
# Predicted OPS in 2021:  [0.755]

# %%
#import data
col_list = ["Age", "%G"]
dataset = pd.read_csv('PadresBatters.csv', usecols=col_list)
X = dataset.iloc[15:21, :-1].values
y = dataset.iloc[15:21, -1].values

from sklearn.model_selection import train_test_split
X_train = X
X_test = X
y_train = y
y_test = y

from sklearn.ensemble import RandomForestRegressor
regressor = RandomForestRegressor(n_estimators = 10, random_state = 0)
regressor.fit(X_train, y_train)

y_pred = regressor.predict(X_test)
np.set_printoptions(precision=2)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))

X_grid = np.arange(min(X), max(X), 0.01)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(X, y, color = 'red')
plt.plot(X_grid, regressor.predict(X_grid), color = 'blue')
plt.title('%G Played (Random Forest Regression)')
plt.xlabel('Age')
plt.ylabel('%G')
plt.show()

#reshape y 
y = y.reshape(len(y),1)

from sklearn.metrics import mean_squared_error
print("MSE: " , mean_squared_error(y_test, y_pred))

from sklearn.metrics import r2_score
print("R2 Score: " , r2_score(y_test, y_pred))

print("Predicted %G in 2021: " ,regressor.predict([[28]]))
# Out:
# [[0.5  0.52]
#  [0.54 0.56]
#  [0.33 0.14]
#  [0.75 0.9 ]
#  [0.87 0.86]
#  [0.91 0.93]]
# MSE:  0.010553729115141965
# R2 Score:  0.8668801745598843
# Predicted %G in 2021:  [0.91]

# %%
#import data
col_list = ["Age", "PA/G"]
dataset = pd.read_csv('PadresBatters.csv', usecols=col_list)
X = dataset.iloc[15:21, :-1].values
y = dataset.iloc[15:21, -1].values

from sklearn.model_selection import train_test_split
X_train = X
X_test = X
y_train = y
y_test = y

from sklearn.ensemble import RandomForestRegressor
regressor = RandomForestRegressor(n_estimators = 10, random_state = 0)
regressor.fit(X_train, y_train)

y_pred = regressor.predict(X_test)
np.set_printoptions(precision=2)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))

X_grid = np.arange(min(X), max(X), 0.01)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(X, y, color = 'red')
plt.plot(X_grid, regressor.predict(X_grid), color = 'blue')
plt.title('PA/G (Random Forest Regression)')
plt.xlabel('Age')
plt.ylabel('PA/G')
plt.show()

#reshape y 
y = y.reshape(len(y),1)

from sklearn.metrics import mean_squared_error
print("MSE: " , mean_squared_error(y_test, y_pred))

from sklearn.metrics import r2_score
print("R2 Score: " , r2_score(y_test, y_pred))

print("Predicted PA/G in 2021: " ,regressor.predict([[28]]))
# Out:
# [[3.63 3.81]
#  [3.5  3.41]
#  [3.38 3.18]
#  [3.89 4.07]
#  [3.79 3.73]
#  [3.69 3.61]]
# MSE:  0.02063970373822084
# R2 Score:  0.7440462799887657
# Predicted PA/G in 2021:  [3.69]

# %%
#import data
col_list = ["Age", "HR/G"]
dataset = pd.read_csv('PadresBatters.csv', usecols=col_list)
X = dataset.iloc[15:21, :-1].values
y = dataset.iloc[15:21, -1].values

from sklearn.model_selection import train_test_split
X_train = X
X_test = X
y_train = y
y_test = y

from sklearn.ensemble import RandomForestRegressor
regressor = RandomForestRegressor(n_estimators = 10, random_state = 0)
regressor.fit(X_train, y_train)

y_pred = regressor.predict(X_test)
np.set_printoptions(precision=2)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))

X_grid = np.arange(min(X), max(X), 0.01)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(X, y, color = 'red')
plt.plot(X_grid, regressor.predict(X_grid), color = 'blue')
plt.title('HR/G (Random Forest Regression)')
plt.xlabel('Age')
plt.ylabel('HR/G')
plt.show()

#reshape y 
y = y.reshape(len(y),1)

from sklearn.metrics import mean_squared_error
print("MSE: " , mean_squared_error(y_test, y_pred))

from sklearn.metrics import r2_score
print("R2 Score: " , r2_score(y_test, y_pred))

print("Predicted HR/G in 2021: " ,regressor.predict([[28]]))
# Out:
# [[0.06 0.07]
#  [0.06 0.06]
#  [0.03 0.  ]
#  [0.11 0.14]
#  [0.14 0.14]
#  [0.13 0.12]]
# MSE:  0.00034102192444763314
# R2 Score:  0.8720280270786678
# Predicted HR/G in 2021:  [0.13]

# %%
#import data
col_list = ["Age", "RBI/G"]
dataset = pd.read_csv('PadresBatters.csv', usecols=col_list)
X = dataset.iloc[15:21, :-1].values
y = dataset.iloc[15:21, -1].values

from sklearn.model_selection import train_test_split
X_train = X
X_test = X
y_train = y
y_test = y

from sklearn.ensemble import RandomForestRegressor
regressor = RandomForestRegressor(n_estimators = 10, random_state = 0)
regressor.fit(X_train, y_train)

y_pred = regressor.predict(X_test)
np.set_printoptions(precision=2)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))

X_grid = np.arange(min(X), max(X), 0.01)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(X, y, color = 'red')
plt.plot(X_grid, regressor.predict(X_grid), color = 'blue')
plt.title('RBI/G (Random Forest Regression)')
plt.xlabel('Age')
plt.ylabel('RBI/G')
plt.show()

#reshape y 
y = y.reshape(len(y),1)

from sklearn.metrics import mean_squared_error
print("MSE: " , mean_squared_error(y_test, y_pred))

from sklearn.metrics import r2_score
print("R2 Score: " , r2_score(y_test, y_pred))

print("Predicted RBI/G in 2021: " ,regressor.predict([[28]]))
# Out:
# [[0.27 0.31]
#  [0.28 0.22]
#  [0.29 0.23]
#  [0.47 0.53]
#  [0.49 0.48]
#  [0.47 0.45]]
# MSE:  0.0020860482048608605
# R2 Score:  0.8601063176486314
# Predicted RBI/G in 2021:  [0.47]

# %%
#import data
col_list = ["Age", "R/G"]
dataset = pd.read_csv('PadresBatters.csv', usecols=col_list)
X = dataset.iloc[15:21, :-1].values
y = dataset.iloc[15:21, -1].values

from sklearn.model_selection import train_test_split
X_train = X
X_test = X
y_train = y
y_test = y

from sklearn.ensemble import RandomForestRegressor
regressor = RandomForestRegressor(n_estimators = 10, random_state = 0)
regressor.fit(X_train, y_train)

y_pred = regressor.predict(X_test)
np.set_printoptions(precision=2)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))

X_grid = np.arange(min(X), max(X), 0.01)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(X, y, color = 'red')
plt.plot(X_grid, regressor.predict(X_grid), color = 'blue')
plt.title('R/G (Random Forest Regression)')
plt.xlabel('Age')
plt.ylabel('R/G')
plt.show()

#reshape y 
y = y.reshape(len(y),1)

from sklearn.metrics import mean_squared_error
print("MSE: " , mean_squared_error(y_test, y_pred))

from sklearn.metrics import r2_score
print("R2 Score: " , r2_score(y_test, y_pred))

print("Predicted R/G in 2021: " ,regressor.predict([[28]]))
# Out:
# [[0.36 0.35]
#  [0.42 0.39]
#  [0.41 0.36]
#  [0.52 0.56]
#  [0.49 0.47]
#  [0.5  0.5 ]]
# MSE:  0.0007866492013200445
# R2 Score:  0.8658312028390556
# Predicted R/G in 2021:  [0.5]

# %%
#import data
col_list = ["Age", "SB/G"]
dataset = pd.read_csv('PadresBatters.csv', usecols=col_list)
X = dataset.iloc[15:21, :-1].values
y = dataset.iloc[15:21, -1].values

from sklearn.model_selection import train_test_split
X_train = X
X_test = X
y_train = y
y_test = y

from sklearn.ensemble import RandomForestRegressor
regressor = RandomForestRegressor(n_estimators = 10, random_state = 0)
regressor.fit(X_train, y_train)

y_pred = regressor.predict(X_test)
np.set_printoptions(precision=2)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))

X_grid = np.arange(min(X), max(X), 0.01)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(X, y, color = 'red')
plt.plot(X_grid, regressor.predict(X_grid), color = 'blue')
plt.title('SB/G (Random Forest Regression)')
plt.xlabel('Age')
plt.ylabel('SB/G')
plt.show()

#reshape y 
y = y.reshape(len(y),1)

from sklearn.metrics import mean_squared_error
print("MSE: " , mean_squared_error(y_test, y_pred))

from sklearn.metrics import r2_score
print("R2 Score: " , r2_score(y_test, y_pred))

print("Predicted SB/G in 2021: " ,regressor.predict([[28]]))
# Out:
# [[0.03 0.02]
#  [0.04 0.02]
#  [0.05 0.05]
#  [0.06 0.07]
#  [0.07 0.06]
#  [0.1  0.12]]
# MSE:  0.00013106901138847796
# R2 Score:  0.8918268237138743
# Predicted SB/G in 2021:  [0.1]

# %%
#import data
col_list = ["Age", "2B/G"]
dataset = pd.read_csv('PadresBatters.csv', usecols=col_list)
X = dataset.iloc[15:21, :-1].values
y = dataset.iloc[15:21, -1].values

from sklearn.model_selection import train_test_split
X_train = X
X_test = X
y_train = y
y_test = y

from sklearn.ensemble import RandomForestRegressor
regressor = RandomForestRegressor(n_estimators = 10, random_state = 0)
regressor.fit(X_train, y_train)

y_pred = regressor.predict(X_test)
np.set_printoptions(precision=2)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))

X_grid = np.arange(min(X), max(X), 0.01)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(X, y, color = 'red')
plt.plot(X_grid, regressor.predict(X_grid), color = 'blue')
plt.title('2B/G (Random Forest Regression)')
plt.xlabel('Age')
plt.ylabel('2B/G')
plt.show()

#reshape y 
y = y.reshape(len(y),1)

from sklearn.metrics import mean_squared_error
print("MSE: " , mean_squared_error(y_test, y_pred))

from sklearn.metrics import r2_score
print("R2 Score: " , r2_score(y_test, y_pred))

print("Predicted 2B/G in 2021: " ,regressor.predict([[28]]))
# Out:
# [[0.11 0.13]
#  [0.11 0.07]
#  [0.12 0.09]
#  [0.21 0.24]
#  [0.19 0.17]
#  [0.14 0.11]]
# MSE:  0.0008279576180795392
# R2 Score:  0.7491625127077266
# Predicted 2B/G in 2021:  [0.14]

# %%
#import data
col_list = ["Age", "3B/G"]
dataset = pd.read_csv('PadresBatters.csv', usecols=col_list)
X = dataset.iloc[15:21, :-1].values
y = dataset.iloc[15:21, -1].values

from sklearn.model_selection import train_test_split
X_train = X
X_test = X
y_train = y
y_test = y

from sklearn.ensemble import RandomForestRegressor
regressor = RandomForestRegressor(n_estimators = 10, random_state = 0)
regressor.fit(X_train, y_train)

y_pred = regressor.predict(X_test)
np.set_printoptions(precision=2)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))

X_grid = np.arange(min(X), max(X), 0.01)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(X, y, color = 'red')
plt.plot(X_grid, regressor.predict(X_grid), color = 'blue')
plt.title('3B/G (Random Forest Regression)')
plt.xlabel('Age')
plt.ylabel('3B/G')
plt.show()

#reshape y 
y = y.reshape(len(y),1)

from sklearn.metrics import mean_squared_error
print("MSE: " , mean_squared_error(y_test, y_pred))

from sklearn.metrics import r2_score
print("R2 Score: " , r2_score(y_test, y_pred))

print("Predicted 3B/G in 2021: " ,regressor.predict([[28]]))
# Out:
# [[0.01 0.  ]
#  [0.03 0.03]
#  [0.01 0.  ]
#  [0.03 0.04]
#  [0.02 0.01]
#  [0.01 0.  ]]
# MSE:  7.111685988396755e-05
# R2 Score:  0.7478494450767936
# Predicted 3B/G in 2021:  [0.01]

# %%
#import data
col_list = ["Age", "BB/G"]
dataset = pd.read_csv('PadresBatters.csv', usecols=col_list)
X = dataset.iloc[15:21, :-1].values
y = dataset.iloc[15:21, -1].values

from sklearn.model_selection import train_test_split
X_train = X
X_test = X
y_train = y
y_test = y

from sklearn.ensemble import RandomForestRegressor
regressor = RandomForestRegressor(n_estimators = 10, random_state = 0)
regressor.fit(X_train, y_train)

y_pred = regressor.predict(X_test)
np.set_printoptions(precision=2)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))

X_grid = np.arange(min(X), max(X), 0.01)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(X, y, color = 'red')
plt.plot(X_grid, regressor.predict(X_grid), color = 'blue')
plt.title('BB/G (Random Forest Regression)')
plt.xlabel('Age')
plt.ylabel('BB/G')
plt.show()

#reshape y 
y = y.reshape(len(y),1)

from sklearn.metrics import mean_squared_error
print("MSE: " , mean_squared_error(y_test, y_pred))

from sklearn.metrics import r2_score
print("R2 Score: " , r2_score(y_test, y_pred))

print("Predicted BB/G in 2021: " ,regressor.predict([[28]]))
# Out:
# [[0.32 0.31]
#  [0.36 0.33]
#  [0.39 0.41]
#  [0.38 0.37]
#  [0.35 0.35]
#  [0.3  0.27]]
# MSE:  0.00038173284472539155
# R2 Score:  0.8106214090184143
# Predicted BB/G in 2021:  [0.3]

# %%
#import data
col_list = ["Age", "SO/G"]
dataset = pd.read_csv('PadresBatters.csv', usecols=col_list)
X = dataset.iloc[15:21, :-1].values
y = dataset.iloc[15:21, -1].values

from sklearn.model_selection import train_test_split
X_train = X
X_test = X
y_train = y
y_test = y

from sklearn.ensemble import RandomForestRegressor
regressor = RandomForestRegressor(n_estimators = 10, random_state = 0)
regressor.fit(X_train, y_train)

y_pred = regressor.predict(X_test)
np.set_printoptions(precision=2)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))

X_grid = np.arange(min(X), max(X), 0.01)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(X, y, color = 'red')
plt.plot(X_grid, regressor.predict(X_grid), color = 'blue')
plt.title('SO/G (Random Forest Regression)')
plt.xlabel('Age')
plt.ylabel('SO/G')
plt.show()

#reshape y 
y = y.reshape(len(y),1)

from sklearn.metrics import mean_squared_error
print("MSE: " , mean_squared_error(y_test, y_pred))

from sklearn.metrics import r2_score
print("R2 Score: " , r2_score(y_test, y_pred))

print("Predicted SO/G in 2021: " ,regressor.predict([[28]]))
# Out:
# [[0.71 0.74]
#  [0.65 0.68]
#  [0.63 0.64]
#  [0.61 0.6 ]
#  [0.55 0.54]
#  [0.52 0.5 ]]
# MSE:  0.0003524410619783488
# R2 Score:  0.9462926664396355
# Predicted SO/G in 2021:  [0.52]

# %% [markdown]
# ######
