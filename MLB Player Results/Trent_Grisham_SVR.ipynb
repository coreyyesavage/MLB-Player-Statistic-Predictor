# %%
#import packages
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

#import data
col_list = ["Age", "AVG"]
dataset = pd.read_csv('PadresBatters.csv', usecols=col_list)
X = dataset.iloc[37:39, :-1].values
y = dataset.iloc[37:39, -1].values

print(X)
# Out:
# [[22]
#  [23]]

# %%
y_train = y
y_test = y
X_test = X
X_train = X

#reshape y 
y = y.reshape(len(y),1)

#Feature scaling the data
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
sc_y = StandardScaler()
X = sc_X.fit_transform(X)
y = sc_y.fit_transform(y)

#Train the SVR
from sklearn.svm import SVR
regressor = SVR(kernel = 'rbf')
regressor.fit(X, y)

#Predict a new result
print("Batting AVG for 2021: ", sc_y.inverse_transform(regressor.predict(sc_X.transform([[24]]))))

y_pred = sc_y.inverse_transform(regressor.predict(sc_X.transform(X_test)))
np.set_printoptions(precision=3)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))

from sklearn.metrics import mean_squared_error
print(mean_squared_error(y_test, y_pred))


X_grid = np.arange(min(sc_X.inverse_transform(X)), max(sc_X.inverse_transform(X)), 0.1)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(sc_X.inverse_transform(X), sc_y.inverse_transform(y), color = 'red')
plt.plot(X_grid, sc_y.inverse_transform(regressor.predict(sc_X.transform(X_grid))), color = 'blue')
plt.title('AVG (SVR)')
plt.xlabel('Age')
plt.ylabel('AVG')
plt.show()
# Out:
# Batting AVG for 2021:  [0.241]
# [[0.232 0.231]
#  [0.25  0.251]]
# 9.999999916002764e-07
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)

# %%
#import data
col_list = ["Age", "SLG"]
dataset = pd.read_csv('PadresBatters.csv', usecols=col_list)
X = dataset.iloc[37:39, :-1].values
y = dataset.iloc[37:39, -1].values

y_train = y
y_test = y
X_test = X
X_train = X

#reshape y 
y = y.reshape(len(y),1)

#Feature scaling the data
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
sc_y = StandardScaler()
X = sc_X.fit_transform(X)
y = sc_y.fit_transform(y)

#Train the SVR
from sklearn.svm import SVR
regressor = SVR(kernel = 'rbf')
regressor.fit(X, y)

#Predict a new result
print("SLG for 2021: ", sc_y.inverse_transform(regressor.predict(sc_X.transform([[24]]))))

y_pred = sc_y.inverse_transform(regressor.predict(sc_X.transform(X_test)))
np.set_printoptions(precision=3)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))

from sklearn.metrics import mean_squared_error
print(mean_squared_error(y_test, y_pred))


X_grid = np.arange(min(sc_X.inverse_transform(X)), max(sc_X.inverse_transform(X)), 0.1)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(sc_X.inverse_transform(X), sc_y.inverse_transform(y), color = 'red')
plt.plot(X_grid, sc_y.inverse_transform(regressor.predict(sc_X.transform(X_grid))), color = 'blue')
plt.title('SLG (SVR)')
plt.xlabel('Age')
plt.ylabel('SLG')
plt.show()
# Out:
# SLG for 2021:  [0.433]
# [[0.412 0.41 ]
#  [0.454 0.456]]
# 5.2899999555654115e-06
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)

# %%
#import data
col_list = ["Age", "OBP"]
dataset = pd.read_csv('PadresBatters.csv', usecols=col_list)
X = dataset.iloc[37:39, :-1].values
y = dataset.iloc[37:39, -1].values

y_train = y
y_test = y
X_test = X
X_train = X

#reshape y 
y = y.reshape(len(y),1)

#Feature scaling the data
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
sc_y = StandardScaler()
X = sc_X.fit_transform(X)
y = sc_y.fit_transform(y)

#Train the SVR
from sklearn.svm import SVR
regressor = SVR(kernel = 'rbf')
regressor.fit(X, y)

#Predict a new result
print("OBP for 2021: ", sc_y.inverse_transform(regressor.predict(sc_X.transform([[24]]))))

y_pred = sc_y.inverse_transform(regressor.predict(sc_X.transform(X_test)))
np.set_printoptions(precision=3)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))

from sklearn.metrics import mean_squared_error
print(mean_squared_error(y_test, y_pred))


X_grid = np.arange(min(sc_X.inverse_transform(X)), max(sc_X.inverse_transform(X)), 0.1)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(sc_X.inverse_transform(X), sc_y.inverse_transform(y), color = 'red')
plt.plot(X_grid, sc_y.inverse_transform(regressor.predict(sc_X.transform(X_grid))), color = 'blue')
plt.title('OBP (SVR)')
plt.xlabel('Age')
plt.ylabel('OBP')
plt.show()
# Out:
# OBP for 2021:  [0.34]
# [[0.329 0.328]
#  [0.351 0.352]]
# 1.4399999879044248e-06
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)

# %%
#import data
col_list = ["Age", "OPS"]
dataset = pd.read_csv('PadresBatters.csv', usecols=col_list)
X = dataset.iloc[37:39, :-1].values
y = dataset.iloc[37:39, -1].values

y_train = y
y_test = y
X_test = X
X_train = X

#reshape y 
y = y.reshape(len(y),1)

#Feature scaling the data
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
sc_y = StandardScaler()
X = sc_X.fit_transform(X)
y = sc_y.fit_transform(y)

#Train the SVR
from sklearn.svm import SVR
regressor = SVR(kernel = 'rbf')
regressor.fit(X, y)

#Predict a new result
print("OPS for 2021: ", sc_y.inverse_transform(regressor.predict(sc_X.transform([[24]]))))

y_pred = sc_y.inverse_transform(regressor.predict(sc_X.transform(X_test)))
np.set_printoptions(precision=3)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))

from sklearn.metrics import mean_squared_error
print(mean_squared_error(y_test, y_pred))


X_grid = np.arange(min(sc_X.inverse_transform(X)), max(sc_X.inverse_transform(X)), 0.1)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(sc_X.inverse_transform(X), sc_y.inverse_transform(y), color = 'red')
plt.plot(X_grid, sc_y.inverse_transform(regressor.predict(sc_X.transform(X_grid))), color = 'blue')
plt.title('OPS (SVR)')
plt.xlabel('Age')
plt.ylabel('OPS')
plt.show()
# Out:
# OPS for 2021:  [0.774]
# [[0.741 0.738]
#  [0.805 0.808]]
# 1.2249999897103386e-05
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)

# %%
#import data
col_list = ["Age", "%G"]
dataset = pd.read_csv('PadresBatters.csv', usecols=col_list)
X = dataset.iloc[37:39, :-1].values
y = dataset.iloc[37:39, -1].values

y_train = y
y_test = y
X_test = X
X_train = X

#reshape y 
y = y.reshape(len(y),1)

#Feature scaling the data
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
sc_y = StandardScaler()
X = sc_X.fit_transform(X)
y = sc_y.fit_transform(y)

#Train the SVR
from sklearn.svm import SVR
regressor = SVR(kernel = 'rbf')
regressor.fit(X, y)

#Predict a new result
print(" %G for 2021: ", sc_y.inverse_transform(regressor.predict(sc_X.transform([[24]]))))


y_pred = sc_y.inverse_transform(regressor.predict(sc_X.transform(X_test)))
np.set_printoptions(precision=3)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))

from sklearn.metrics import mean_squared_error
print(mean_squared_error(y_test, y_pred))


X_grid = np.arange(min(sc_X.inverse_transform(X)), max(sc_X.inverse_transform(X)), 0.1)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(sc_X.inverse_transform(X), sc_y.inverse_transform(y), color = 'red')
plt.plot(X_grid, sc_y.inverse_transform(regressor.predict(sc_X.transform(X_grid))), color = 'blue')
plt.title('%G (SVR)')
plt.xlabel('Age')
plt.ylabel('%G')
plt.show()
# Out:
#  %G for 2021:  [0.973]
# [[0.963 0.962]
#  [0.982 0.983]]
# 1.1097760660510398e-06
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)

# %%
#going with 146 games played because he has only played 2 seasons
#print(.97 * 162, "Games Played")
print("146 Games Played")
# Out:
# 146 Games Played

# %%
#import data
col_list = ["Age", "PA/G"]
dataset = pd.read_csv('PadresBatters.csv', usecols=col_list)
X = dataset.iloc[37:39, :-1].values
y = dataset.iloc[37:39, -1].values

y_train = y
y_test = y
X_test = X
X_train = X

#reshape y 
y = y.reshape(len(y),1)

#Feature scaling the data
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
sc_y = StandardScaler()
X = sc_X.fit_transform(X)
y = sc_y.fit_transform(y)

#Train the SVR
from sklearn.svm import SVR
regressor = SVR(kernel = 'rbf')
regressor.fit(X, y)

#Predict a new result
print(" PA/G for 2021: ", sc_y.inverse_transform(regressor.predict(sc_X.transform([[24]]))))


y_pred = sc_y.inverse_transform(regressor.predict(sc_X.transform(X_test)))
np.set_printoptions(precision=3)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))

from sklearn.metrics import mean_squared_error
print(mean_squared_error(y_test, y_pred))


X_grid = np.arange(min(sc_X.inverse_transform(X)), max(sc_X.inverse_transform(X)), 0.1)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(sc_X.inverse_transform(X), sc_y.inverse_transform(y), color = 'red')
plt.plot(X_grid, sc_y.inverse_transform(regressor.predict(sc_X.transform(X_grid))), color = 'blue')
plt.title('PA/G (SVR)')
plt.xlabel('Age')
plt.ylabel('PA/G')
plt.show()
# Out:
#  PA/G for 2021:  [3.935]
# [[3.622 3.588]
#  [4.237 4.271]]
# 0.0011660556631769967
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)

# %%
print(3.935 * 154, "PA")
# Out:
# 605.99 PA

# %%
#import data
col_list = ["Age", "HR/G"]
dataset = pd.read_csv('PadresBatters.csv', usecols=col_list)
X = dataset.iloc[37:39, :-1].values
y = dataset.iloc[37:39, -1].values

y_train = y
y_test = y
X_test = X
X_train = X

#reshape y 
y = y.reshape(len(y),1)

#Feature scaling the data
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
sc_y = StandardScaler()
X = sc_X.fit_transform(X)
y = sc_y.fit_transform(y)

#Train the SVR
from sklearn.svm import SVR
regressor = SVR(kernel = 'rbf')
regressor.fit(X, y)

#Predict a new result
print(" HR/G for 2021: ", sc_y.inverse_transform(regressor.predict(sc_X.transform([[24]]))))


y_pred = sc_y.inverse_transform(regressor.predict(sc_X.transform(X_test)))
np.set_printoptions(precision=3)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))

from sklearn.metrics import mean_squared_error
print(mean_squared_error(y_test, y_pred))


X_grid = np.arange(min(sc_X.inverse_transform(X)), max(sc_X.inverse_transform(X)), 0.1)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(sc_X.inverse_transform(X), sc_y.inverse_transform(y), color = 'red')
plt.plot(X_grid, sc_y.inverse_transform(regressor.predict(sc_X.transform(X_grid))), color = 'blue')
plt.title('HR/G (SVR)')
plt.xlabel('Age')
plt.ylabel('HR')
plt.show()
# Out:
#  HR/G for 2021:  [0.144]
# [[0.12  0.118]
#  [0.167 0.169]]
# 6.719621580620011e-06
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)

# %%
print(.144 * 154, " HRs")
# Out:
# 22.176  HRs

# %%
#import data
col_list = ["Age", "RBI/G"]
dataset = pd.read_csv('PadresBatters.csv', usecols=col_list)
X = dataset.iloc[37:39, :-1].values
y = dataset.iloc[37:39, -1].values

y_train = y
y_test = y
X_test = X
X_train = X

#reshape y 
y = y.reshape(len(y),1)

#Feature scaling the data
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
sc_y = StandardScaler()
X = sc_X.fit_transform(X)
y = sc_y.fit_transform(y)

#Train the SVR
from sklearn.svm import SVR
regressor = SVR(kernel = 'rbf')
regressor.fit(X, y)

#Predict a new result
print(" RBI/G for 2021: ", sc_y.inverse_transform(regressor.predict(sc_X.transform([[24]]))))


y_pred = sc_y.inverse_transform(regressor.predict(sc_X.transform(X_test)))
np.set_printoptions(precision=3)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))

from sklearn.metrics import mean_squared_error
print(mean_squared_error(y_test, y_pred))


X_grid = np.arange(min(sc_X.inverse_transform(X)), max(sc_X.inverse_transform(X)), 0.1)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(sc_X.inverse_transform(X), sc_y.inverse_transform(y), color = 'red')
plt.plot(X_grid, sc_y.inverse_transform(regressor.predict(sc_X.transform(X_grid))), color = 'blue')
plt.title('RBI/G (SVR)')
plt.xlabel('Age')
plt.ylabel('RBI/G')
plt.show()
# Out:
#  RBI/G for 2021:  [0.455]
# [[0.469 0.471]
#  [0.442 0.441]]
# 2.2365604603444583e-06
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)

# %%
print(.455 * 154, " RBIs")
# Out:
# 70.07000000000001  RBIs

# %%
#import data
col_list = ["Age", "R/G"]
dataset = pd.read_csv('PadresBatters.csv', usecols=col_list)
X = dataset.iloc[37:39, :-1].values
y = dataset.iloc[37:39, -1].values

y_train = y
y_test = y
X_test = X
X_train = X

#reshape y 
y = y.reshape(len(y),1)

#Feature scaling the data
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
sc_y = StandardScaler()
X = sc_X.fit_transform(X)
y = sc_y.fit_transform(y)

#Train the SVR
from sklearn.svm import SVR
regressor = SVR(kernel = 'rbf')
regressor.fit(X, y)

#Predict a new result
print(" R/G for 2021: ", sc_y.inverse_transform(regressor.predict(sc_X.transform([[24]]))))


y_pred = sc_y.inverse_transform(regressor.predict(sc_X.transform(X_test)))
np.set_printoptions(precision=3)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))

from sklearn.metrics import mean_squared_error
print(mean_squared_error(y_test, y_pred))


X_grid = np.arange(min(sc_X.inverse_transform(X)), max(sc_X.inverse_transform(X)), 0.1)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(sc_X.inverse_transform(X), sc_y.inverse_transform(y), color = 'red')
plt.plot(X_grid, sc_y.inverse_transform(regressor.predict(sc_X.transform(X_grid))), color = 'blue')
plt.title('R/G (SVR)')
plt.xlabel('Age')
plt.ylabel('R/G')
plt.show()
# Out:
#  R/G for 2021:  [0.593]
# [[0.483 0.471]
#  [0.7   0.712]]
# 0.00014553547671497817
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)

# %%
print(.593 * 154, " runs")
# Out:
# 91.322  runs

# %%
#import data
col_list = ["Age", "SB/G"]
dataset = pd.read_csv('PadresBatters.csv', usecols=col_list)
X = dataset.iloc[37:39, :-1].values
y = dataset.iloc[37:39, -1].values

y_train = y
y_test = y
X_test = X
X_train = X

#reshape y 
y = y.reshape(len(y),1)

#Feature scaling the data
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
sc_y = StandardScaler()
X = sc_X.fit_transform(X)
y = sc_y.fit_transform(y)

#Train the SVR
from sklearn.svm import SVR
regressor = SVR(kernel = 'rbf')
regressor.fit(X, y)

#Predict a new result
print(" SB/G for 2021: ", sc_y.inverse_transform(regressor.predict(sc_X.transform([[24]]))))


y_pred = sc_y.inverse_transform(regressor.predict(sc_X.transform(X_test)))
np.set_printoptions(precision=3)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))

from sklearn.metrics import mean_squared_error
print(mean_squared_error(y_test, y_pred))


X_grid = np.arange(min(sc_X.inverse_transform(X)), max(sc_X.inverse_transform(X)), 0.1)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(sc_X.inverse_transform(X), sc_y.inverse_transform(y), color = 'red')
plt.plot(X_grid, sc_y.inverse_transform(regressor.predict(sc_X.transform(X_grid))), color = 'blue')
plt.title('SB/G (SVR)')
plt.xlabel('Age')
plt.ylabel('SB/G')
plt.show()
# Out:
#  SB/G for 2021:  [0.096]
# [[0.027 0.02 ]
#  [0.162 0.169]]
# 5.6162794852941504e-05
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)

# %%
print(.096 * 154, " SBs")
# Out:
# 14.784  SBs

# %%
#import data
col_list = ["Age", "2B/G"]
dataset = pd.read_csv('PadresBatters.csv', usecols=col_list)
X = dataset.iloc[37:39, :-1].values
y = dataset.iloc[37:39, -1].values

y_train = y
y_test = y
X_test = X
X_train = X

#reshape y 
y = y.reshape(len(y),1)

#Feature scaling the data
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
sc_y = StandardScaler()
X = sc_X.fit_transform(X)
y = sc_y.fit_transform(y)

#Train the SVR
from sklearn.svm import SVR
regressor = SVR(kernel = 'rbf')
regressor.fit(X, y)

#Predict a new result
print(" 2B/G for 2021: ", sc_y.inverse_transform(regressor.predict(sc_X.transform([[24]]))))


y_pred = sc_y.inverse_transform(regressor.predict(sc_X.transform(X_test)))
np.set_printoptions(precision=3)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))

from sklearn.metrics import mean_squared_error
print(mean_squared_error(y_test, y_pred))


X_grid = np.arange(min(sc_X.inverse_transform(X)), max(sc_X.inverse_transform(X)), 0.1)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(sc_X.inverse_transform(X), sc_y.inverse_transform(y), color = 'red')
plt.plot(X_grid, sc_y.inverse_transform(regressor.predict(sc_X.transform(X_grid))), color = 'blue')
plt.title('2B/G (SVR)')
plt.xlabel('Age')
plt.ylabel('2B/G')
plt.show()
# Out:
#  2B/G for 2021:  [0.127]
# [[0.119 0.118]
#  [0.135 0.136]]
# 8.051617298316622e-07
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)

# %%
print(.127 * 1, " 2Bs")
# Out:
# 18.542  2Bs

# %%
#import data
col_list = ["Age", "3B/G"]
dataset = pd.read_csv('PadresBatters.csv', usecols=col_list)
X = dataset.iloc[37:39, :-1].values
y = dataset.iloc[37:39, -1].values

y_train = y
y_test = y
X_test = X
X_train = X

#reshape y 
y = y.reshape(len(y),1)

#Feature scaling the data
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
sc_y = StandardScaler()
X = sc_X.fit_transform(X)
y = sc_y.fit_transform(y)

#Train the SVR
from sklearn.svm import SVR
regressor = SVR(kernel = 'rbf')
regressor.fit(X, y)

#Predict a new result
print(" 3B/G for 2021: ", sc_y.inverse_transform(regressor.predict(sc_X.transform([[24]]))))


y_pred = sc_y.inverse_transform(regressor.predict(sc_X.transform(X_test)))
np.set_printoptions(precision=3)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))

from sklearn.metrics import mean_squared_error
print(mean_squared_error(y_test, y_pred))


X_grid = np.arange(min(sc_X.inverse_transform(X)), max(sc_X.inverse_transform(X)), 0.1)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(sc_X.inverse_transform(X), sc_y.inverse_transform(y), color = 'red')
plt.plot(X_grid, sc_y.inverse_transform(regressor.predict(sc_X.transform(X_grid))), color = 'blue')
plt.title('3B/G (SVR)')
plt.xlabel('Age')
plt.ylabel('3B/G')
plt.show()
# Out:
#  3B/G for 2021:  [0.045]
# [[0.04  0.039]
#  [0.05  0.051]]
# 3.3824529680879993e-07
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)

# %%
print(.045 * 146, " 3Bs")
# Out:
# 6.569999999999999  3Bs

# %%
#import data
col_list = ["Age", "BB/G"]
dataset = pd.read_csv('PadresBatters.csv', usecols=col_list)
X = dataset.iloc[37:39, :-1].values
y = dataset.iloc[37:39, -1].values

y_train = y
y_test = y
X_test = X
X_train = X

#reshape y 
y = y.reshape(len(y),1)

#Feature scaling the data
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
sc_y = StandardScaler()
X = sc_X.fit_transform(X)
y = sc_y.fit_transform(y)

#Train the SVR
from sklearn.svm import SVR
regressor = SVR(kernel = 'rbf')
regressor.fit(X, y)

#Predict a new result
print(" BB/G for 2021: ", sc_y.inverse_transform(regressor.predict(sc_X.transform([[24]]))))


y_pred = sc_y.inverse_transform(regressor.predict(sc_X.transform(X_test)))
np.set_printoptions(precision=3)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))

from sklearn.metrics import mean_squared_error
print(mean_squared_error(y_test, y_pred))


X_grid = np.arange(min(sc_X.inverse_transform(X)), max(sc_X.inverse_transform(X)), 0.1)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(sc_X.inverse_transform(X), sc_y.inverse_transform(y), color = 'red')
plt.plot(X_grid, sc_y.inverse_transform(regressor.predict(sc_X.transform(X_grid))), color = 'blue')
plt.title('BB/G (SVR)')
plt.xlabel('Age')
plt.ylabel('BB/G')
# Out:
#  BB/G for 2021:  [0.46]
# [[0.399 0.392]
#  [0.519 0.525]]
# 4.440014356070622e-05
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# Text(0, 0.5, 'BB/G')

# %%
print(.46 * 146, ' BBs')
# Out:
# 67.16  BBs

# %%
#import data
col_list = ["Age", "SO/G"]
dataset = pd.read_csv('PadresBatters.csv', usecols=col_list)
X = dataset.iloc[37:39, :-1].values
y = dataset.iloc[37:39, -1].values

y_train = y
y_test = y
X_test = X
X_train = X

#reshape y 
y = y.reshape(len(y),1)

#Feature scaling the data
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
sc_y = StandardScaler()
X = sc_X.fit_transform(X)
y = sc_y.fit_transform(y)

#Train the SVR
from sklearn.svm import SVR
regressor = SVR(kernel = 'rbf')
regressor.fit(X, y)

#Predict a new result
print(" SO/G for 2021: ", sc_y.inverse_transform(regressor.predict(sc_X.transform([[24]]))))


y_pred = sc_y.inverse_transform(regressor.predict(sc_X.transform(X_test)))
np.set_printoptions(precision=3)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))

from sklearn.metrics import mean_squared_error
print(mean_squared_error(y_test, y_pred))


X_grid = np.arange(min(sc_X.inverse_transform(X)), max(sc_X.inverse_transform(X)), 0.1)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(sc_X.inverse_transform(X), sc_y.inverse_transform(y), color = 'red')
plt.plot(X_grid, sc_y.inverse_transform(regressor.predict(sc_X.transform(X_grid))), color = 'blue')
plt.title('SO/G (SVR)')
plt.xlabel('Age')
plt.ylabel('SO/G')
# Out:
#  SO/G for 2021:  [1.014]
# [[0.948 0.941]
#  [1.078 1.085]]
# 5.153035358061241e-05
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# Text(0, 0.5, 'SO/G')

# %%
print(1.014 * 146, ' SOs')
# Out:
# 148.044  SOs
