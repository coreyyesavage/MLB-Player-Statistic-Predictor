# %%
#import packages
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

#import data
col_list = ["Name","Age", "ERA"]
dataset = pd.read_csv('PadresPitchers.csv', usecols=col_list)
X = dataset.iloc[9:11, :-1].values
y = dataset.iloc[9:11, -1].values

print(X)
# Out:
# [['Chris Paddack' 23]
#  ['Chris Paddack' 24]]

# %%
#import data
col_list = ["Age", "ERA"]
dataset = pd.read_csv('PadresPitchers.csv', usecols=col_list)
X = dataset.iloc[9:11, :-1].values
y = dataset.iloc[9:11, -1].values

from sklearn.model_selection import train_test_split
X_train = X
X_test = X
y_train = y
y_test = y


from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
poly_reg = PolynomialFeatures(degree = 4)
X_poly = poly_reg.fit_transform(X_train)
regressor = LinearRegression()
regressor.fit(X_poly, y_train)

y_pred = regressor.predict(poly_reg.transform(X_test))
np.set_printoptions(precision=2)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))

#y_pred = regressor.predict(X_test)
X_grid = np.arange(min(X), max(X), 0.1)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(X_train, y_train, color = 'red')
plt.plot(X_grid, regressor.predict(poly_reg.fit_transform(X_grid)), color = 'blue')
plt.title('ERA (Polynomial Reg)')
plt.xlabel('Age')
plt.ylabel('ERA')
plt.show()

#reshape y 
y = y.reshape(len(y),1)

#Feature scaling the data
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
sc_y = StandardScaler()
X = sc_X.fit_transform(X)
y = sc_y.fit_transform(y)


from sklearn.metrics import mean_squared_error
print("MSE: " , mean_squared_error(y_test, y_pred))

from sklearn.metrics import r2_score
print("R2 Score: " , r2_score(y_test, y_pred))

print("Predicted ERA in 2021: " ,regressor.predict(poly_reg.fit_transform([[25]])))
# Out:
# [[3.33 3.33]
#  [4.73 4.73]]
# MSE:  3.944304526105059e-30
# R2 Score:  1.0
# Predicted ERA in 2021:  [6.32]

# %%
#import data
col_list = ["Age", "WHIP"]
dataset = pd.read_csv('PadresPitchers.csv', usecols=col_list)
X = dataset.iloc[9:11, :-1].values
y = dataset.iloc[9:11, -1].values

from sklearn.model_selection import train_test_split
X_train = X
X_test = X
y_train = y
y_test = y


from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
poly_reg = PolynomialFeatures(degree = 4)
X_poly = poly_reg.fit_transform(X_train)
regressor = LinearRegression()
regressor.fit(X_poly, y_train)

y_pred = regressor.predict(poly_reg.transform(X_test))
np.set_printoptions(precision=2)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))

#y_pred = regressor.predict(X_test)
X_grid = np.arange(min(X), max(X), 0.1)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(X_train, y_train, color = 'red')
plt.plot(X_grid, regressor.predict(poly_reg.fit_transform(X_grid)), color = 'blue')
plt.title('WHIP (Polynomial Reg)')
plt.xlabel('Age')
plt.ylabel('WHIP')
plt.show()

#reshape y 
y = y.reshape(len(y),1)

#Feature scaling the data
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
sc_y = StandardScaler()
X = sc_X.fit_transform(X)
y = sc_y.fit_transform(y)


from sklearn.metrics import mean_squared_error
print("MSE: " , mean_squared_error(y_test, y_pred))

from sklearn.metrics import r2_score
print("R2 Score: " , r2_score(y_test, y_pred))

print("Predicted wHIP in 2021: " ,regressor.predict(poly_reg.fit_transform([[25]])))
# Out:
# [[0.98 0.98]
#  [1.22 1.22]]
# MSE:  2.465190328815662e-32
# R2 Score:  1.0
# Predicted wHIP in 2021:  [1.49]

# %%
#import data
col_list = ["Age", "AVG"]
dataset = pd.read_csv('PadresPitchers.csv', usecols=col_list)
X = dataset.iloc[9:11, :-1].values
y = dataset.iloc[9:11, -1].values

from sklearn.model_selection import train_test_split
X_train = X
X_test = X
y_train = y
y_test = y

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)


from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
poly_reg = PolynomialFeatures(degree = 4)
X_poly = poly_reg.fit_transform(X_train)
regressor = LinearRegression()
regressor.fit(X_poly, y_train)

y_pred = regressor.predict(poly_reg.transform(X_test))
np.set_printoptions(precision=2)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))

#y_pred = regressor.predict(X_test)
X_grid = np.arange(min(X), max(X), 0.1)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(X_train, y_train, color = 'red')
plt.plot(X_grid, regressor.predict(poly_reg.fit_transform(X_grid)), color = 'blue')
plt.title('AVG (Polynomial Reg)')
plt.xlabel('Age')
plt.ylabel('AVG')
plt.show()

#reshape y 
y = y.reshape(len(y),1)

#Feature scaling the data
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
sc_y = StandardScaler()
X = sc_X.fit_transform(X)
y = sc_y.fit_transform(y)


from sklearn.metrics import mean_squared_error
print("MSE: " , mean_squared_error(y_test, y_pred))

from sklearn.metrics import r2_score
print("R2 Score: " , r2_score(y_test, y_pred))

print("Predicted AVG in 2021: " ,regressor.predict(poly_reg.fit_transform([[25]])))
# Out:
# [[0.2  0.26]]
# MSE:  0.003364000000000003
# R2 Score:  nan
# Predicted AVG in 2021:  [0.2]
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_regression.py:682: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)

# %%
#import data
col_list = ["Age", "K/9"]
dataset = pd.read_csv('PadresPitchers.csv', usecols=col_list)
X = dataset.iloc[9:11, :-1].values
y = dataset.iloc[9:11, -1].values

from sklearn.model_selection import train_test_split
X_train = X
X_test = X
y_train = y
y_test = y

from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
poly_reg = PolynomialFeatures(degree = 4)
X_poly = poly_reg.fit_transform(X_train)
regressor = LinearRegression()
regressor.fit(X_poly, y_train)

y_pred = regressor.predict(poly_reg.transform(X_test))
np.set_printoptions(precision=2)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))

#y_pred = regressor.predict(X_test)
X_grid = np.arange(min(X), max(X), 0.1)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(X_train, y_train, color = 'red')
plt.plot(X_grid, regressor.predict(poly_reg.fit_transform(X_grid)), color = 'blue')
plt.title('K/9 (Polynomial Reg)')
plt.xlabel('Age')
plt.ylabel('K/9')
plt.show()

#reshape y 
y = y.reshape(len(y),1)

#Feature scaling the data
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
sc_y = StandardScaler()
X = sc_X.fit_transform(X)
y = sc_y.fit_transform(y)


from sklearn.metrics import mean_squared_error
print("MSE: " , mean_squared_error(y_test, y_pred))

from sklearn.metrics import r2_score
print("R2 Score: " , r2_score(y_test, y_pred))

print("Predicted K/9 in 2021: " ,regressor.predict(poly_reg.fit_transform([[25]])))
# Out:
# [[9.79 9.79]
#  [8.85 8.85]]
# MSE:  0.0
# R2 Score:  1.0
# Predicted K/9 in 2021:  [7.78]

# %%
#import data
col_list = ["Age", "BB/9"]
dataset = pd.read_csv('PadresPitchers.csv', usecols=col_list)
X = dataset.iloc[9:11, :-1].values
y = dataset.iloc[9:11, -1].values

from sklearn.model_selection import train_test_split
X_train = X
X_test = X
y_train = y
y_test = y

from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
poly_reg = PolynomialFeatures(degree = 4)
X_poly = poly_reg.fit_transform(X_train)
regressor = LinearRegression()
regressor.fit(X_poly, y_train)

y_pred = regressor.predict(poly_reg.transform(X_test))
np.set_printoptions(precision=2)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))

#y_pred = regressor.predict(X_test)
X_grid = np.arange(min(X), max(X), 0.1)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(X_train, y_train, color = 'red')
plt.plot(X_grid, regressor.predict(poly_reg.fit_transform(X_grid)), color = 'blue')
plt.title('BB/9 (Polynomial Reg)')
plt.xlabel('Age')
plt.ylabel('BB/9')
plt.show()

#reshape y 
y = y.reshape(len(y),1)

#Feature scaling the data
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
sc_y = StandardScaler()
X = sc_X.fit_transform(X)
y = sc_y.fit_transform(y)


from sklearn.metrics import mean_squared_error
print("MSE: " , mean_squared_error(y_test, y_pred))

from sklearn.metrics import r2_score
print("R2 Score: " , r2_score(y_test, y_pred))

print("Predicted BB/9 in 2021: " ,regressor.predict(poly_reg.fit_transform([[25]])))
# Out:
# [[1.98 1.98]
#  [1.83 1.83]]
# MSE:  1.232595164407831e-31
# R2 Score:  1.0
# Predicted BB/9 in 2021:  [1.66]

# %%
#import data
col_list = ["Age", "ADJ_IP"]
dataset = pd.read_csv('PadresPitchers.csv', usecols=col_list)
X = dataset.iloc[9:11, :-1].values
y = dataset.iloc[9:11, -1].values

from sklearn.model_selection import train_test_split
X_train = X
X_test = X
y_train = y
y_test = y

from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
poly_reg = PolynomialFeatures(degree = 4)
X_poly = poly_reg.fit_transform(X_train)
regressor = LinearRegression()
regressor.fit(X_poly, y_train)

y_pred = regressor.predict(poly_reg.transform(X_test))
np.set_printoptions(precision=2)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))

#y_pred = regressor.predict(X_test)
X_grid = np.arange(min(X), max(X), 0.1)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(X_train, y_train, color = 'red')
plt.plot(X_grid, regressor.predict(poly_reg.fit_transform(X_grid)), color = 'blue')
plt.title('ADJ_IP(Polynomial Reg)')
plt.xlabel('Age')
plt.ylabel('IP')
plt.show()

#reshape y 
y = y.reshape(len(y),1)

#Feature scaling the data
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
sc_y = StandardScaler()
X = sc_X.fit_transform(X)
y = sc_y.fit_transform(y)


from sklearn.metrics import mean_squared_error
print("MSE: " , mean_squared_error(y_test, y_pred))

from sklearn.metrics import r2_score
print("R2 Score: " , r2_score(y_test, y_pred))

print("Predicted IP in 2021: " ,regressor.predict(poly_reg.fit_transform([[25]])))
# Out:
# [[140.2 140.2]
#  [159.3 159.3]]
# MSE:  0.0
# R2 Score:  1.0
# Predicted IP in 2021:  [180.94]

# %%
#import data
col_list = ["Age", "ADJ_GS"]
dataset = pd.read_csv('PadresPitchers.csv', usecols=col_list)
X = dataset.iloc[9:11, :-1].values
y = dataset.iloc[9:11, -1].values

from sklearn.model_selection import train_test_split
X_train = X
X_test = X
y_train = y
y_test = y

from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
poly_reg = PolynomialFeatures(degree = 4)
X_poly = poly_reg.fit_transform(X_train)
regressor = LinearRegression()
regressor.fit(X_poly, y_train)

y_pred = regressor.predict(poly_reg.transform(X_test))
np.set_printoptions(precision=2)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))

#y_pred = regressor.predict(X_test)
X_grid = np.arange(min(X), max(X), 0.1)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(X_train, y_train, color = 'red')
plt.plot(X_grid, regressor.predict(poly_reg.fit_transform(X_grid)), color = 'blue')
plt.title('ADJ_GS (Polynomial Reg)')
plt.xlabel('Age')
plt.ylabel('GS')
plt.show()

#reshape y 
y = y.reshape(len(y),1)

#Feature scaling the data
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
sc_y = StandardScaler()
X = sc_X.fit_transform(X)
y = sc_y.fit_transform(y)


from sklearn.metrics import mean_squared_error
print("MSE: " , mean_squared_error(y_test, y_pred))

from sklearn.metrics import r2_score
print("R2 Score: " , r2_score(y_test, y_pred))

print("Predicted GS in 2021: " ,regressor.predict(poly_reg.fit_transform([[25]])))
# Out:
# [[26.  26. ]
#  [32.4 32.4]]
# MSE:  3.155443620884047e-29
# R2 Score:  1.0
# Predicted GS in 2021:  [39.65]
