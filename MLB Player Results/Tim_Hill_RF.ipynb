# %%
#import packages
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

#import data
col_list = ["Name","Age", "ERA"]
dataset = pd.read_csv('PadresRelievers.csv', usecols=col_list)
X = dataset.iloc[56:59, :-1].values
y = dataset.iloc[56:59, -1].values

print(X)
# Out:
# [['Tim Hill' 28]
#  ['Tim Hill' 29]
#  ['Tim Hill' 30]]

# %%
#import data
col_list = ["Age", "ERA"]
dataset = pd.read_csv('PadresRelievers.csv', usecols=col_list)
X = dataset.iloc[56:59, :-1].values
y = dataset.iloc[56:59, -1].values

from sklearn.model_selection import train_test_split
X_train = X
X_test = X
y_train = y
y_test = y

from sklearn.ensemble import RandomForestRegressor
regressor = RandomForestRegressor(n_estimators = 10, random_state = 0)
regressor.fit(X_train, y_train)

y_pred = regressor.predict(X_test)
np.set_printoptions(precision=2)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))

X_grid = np.arange(min(X), max(X), 0.01)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(X, y, color = 'red')
plt.plot(X_grid, regressor.predict(X_grid), color = 'blue')
plt.title('ERA (Random Forest Regression)')
plt.xlabel('Age')
plt.ylabel('ERA')
plt.show()

#reshape y 
y = y.reshape(len(y),1)

from sklearn.metrics import mean_squared_error
print("MSE: " , mean_squared_error(y_test, y_pred))

from sklearn.metrics import r2_score
print("R2 Score: " , r2_score(y_test, y_pred))

print("Predicted ERA in 2021: " ,regressor.predict([[31]]))
# Out:
# [[4.26 4.53]
#  [3.81 3.63]
#  [4.15 4.5 ]]
# MSE:  0.07565400000000023
# R2 Score:  0.5657060849598152
# Predicted ERA in 2021:  [4.15]

# %%
#import data
col_list = ["Age", "WHIP"]
dataset = pd.read_csv('PadresRelievers.csv', usecols=col_list)
X = dataset.iloc[56:59, :-1].values
y = dataset.iloc[56:59, -1].values

from sklearn.model_selection import train_test_split
X_train = X
X_test = X
y_train = y
y_test = y

from sklearn.ensemble import RandomForestRegressor
regressor = RandomForestRegressor(n_estimators = 10, random_state = 0)
regressor.fit(X_train, y_train)

y_pred = regressor.predict(X_test)
np.set_printoptions(precision=2)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))

X_grid = np.arange(min(X), max(X), 0.01)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(X, y, color = 'red')
plt.plot(X_grid, regressor.predict(X_grid), color = 'blue')
plt.title('WHIP (Random Forest Regression)')
plt.xlabel('Age')
plt.ylabel('WHIP')
plt.show()

#reshape y 
y = y.reshape(len(y),1)

from sklearn.metrics import mean_squared_error
print("MSE: " , mean_squared_error(y_test, y_pred))

from sklearn.metrics import r2_score
print("R2 Score: " , r2_score(y_test, y_pred))

print("Predicted WHIP in 2021: " ,regressor.predict([[31]]))
# Out:
# [[1.25 1.31]
#  [1.15 1.11]
#  [1.21 1.28]]
# MSE:  0.003320666666666665
# R2 Score:  0.5718338108882521
# Predicted WHIP in 2021:  [1.21]

# %%
#import data
col_list = ["Age", "AVG"]
dataset = pd.read_csv('PadresRelievers.csv', usecols=col_list)
X = dataset.iloc[56:59, :-1].values
y = dataset.iloc[56:59, -1].values

from sklearn.model_selection import train_test_split
X_train = X
X_test = X
y_train = y
y_test = y

from sklearn.ensemble import RandomForestRegressor
regressor = RandomForestRegressor(n_estimators = 10, random_state = 0)
regressor.fit(X_train, y_train)

y_pred = regressor.predict(X_test)
np.set_printoptions(precision=2)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))

X_grid = np.arange(min(X), max(X), 0.01)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(X, y, color = 'red')
plt.plot(X_grid, regressor.predict(X_grid), color = 'blue')
plt.title('AVG (Random Forest Regression)')
plt.xlabel('Age')
plt.ylabel('AVG')
plt.show()

#reshape y 
y = y.reshape(len(y),1)

from sklearn.metrics import mean_squared_error
print("MSE: " , mean_squared_error(y_test, y_pred))

from sklearn.metrics import r2_score
print("R2 Score: " , r2_score(y_test, y_pred))

print("Predicted AVG in 2021: " ,regressor.predict([[31]]))
# Out:
# [[0.24 0.25]
#  [0.22 0.21]
#  [0.23 0.24]]
# MSE:  9.81466666666665e-05
# R2 Score:  0.6013898916967517
# Predicted AVG in 2021:  [0.23]

# %%
#import data
col_list = ["Age", "GS"]
dataset = pd.read_csv('PadresRelievers.csv', usecols=col_list)
X = dataset.iloc[56:59, :-1].values
y = dataset.iloc[56:59, -1].values

from sklearn.model_selection import train_test_split
X_train = X
X_test = X
y_train = y
y_test = y

from sklearn.ensemble import RandomForestRegressor
regressor = RandomForestRegressor(n_estimators = 10, random_state = 0)
regressor.fit(X_train, y_train)

y_pred = regressor.predict(X_test)
np.set_printoptions(precision=2)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))

X_grid = np.arange(min(X), max(X), 0.01)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(X, y, color = 'red')
plt.plot(X_grid, regressor.predict(X_grid), color = 'blue')
plt.title('GS (Random Forest Regression)')
plt.xlabel('Age')
plt.ylabel('GS')
plt.show()

#reshape y 
y = y.reshape(len(y),1)

from sklearn.metrics import mean_squared_error
print("MSE: " , mean_squared_error(y_test, y_pred))

from sklearn.metrics import r2_score
print("R2 Score: " , r2_score(y_test, y_pred))

print("Predicted GS in 2021: " ,regressor.predict([[31]]))
# Out:
# [[0. 0.]
#  [0. 0.]
#  [0. 0.]]
# MSE:  0.0
# R2 Score:  1.0
# Predicted GS in 2021:  [0.]

# %%
#import data
col_list = ["Age", "ADJ_IP"]
dataset = pd.read_csv('PadresRelievers.csv', usecols=col_list)
X = dataset.iloc[56:59, :-1].values
y = dataset.iloc[56:59, -1].values

from sklearn.model_selection import train_test_split
X_train = X
X_test = X
y_train = y
y_test = y

from sklearn.ensemble import RandomForestRegressor
regressor = RandomForestRegressor(n_estimators = 10, random_state = 0)
regressor.fit(X_train, y_train)

y_pred = regressor.predict(X_test)
np.set_printoptions(precision=2)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))

X_grid = np.arange(min(X), max(X), 0.01)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(X, y, color = 'red')
plt.plot(X_grid, regressor.predict(X_grid), color = 'blue')
plt.title('ADJ_IP (Random Forest Regression)')
plt.xlabel('Age')
plt.ylabel('IP')
plt.show()

#reshape y 
y = y.reshape(len(y),1)

from sklearn.metrics import mean_squared_error
print("MSE: " , mean_squared_error(y_test, y_pred))

from sklearn.metrics import r2_score
print("R2 Score: " , r2_score(y_test, y_pred))

print("Predicted IP in 2021: " ,regressor.predict([[31]]))
# Out:
# [[43.74 45.2 ]
#  [40.74 39.2 ]
#  [44.84 48.6 ]]
# MSE:  6.213599999999977
# R2 Score:  0.588563861094763
# Predicted IP in 2021:  [44.84]

# %%
#import data
col_list = ["Age", "K/9"]
dataset = pd.read_csv('PadresRelievers.csv', usecols=col_list)
X = dataset.iloc[56:59, :-1].values
y = dataset.iloc[56:59, -1].values

from sklearn.model_selection import train_test_split
X_train = X
X_test = X
y_train = y
y_test = y

from sklearn.ensemble import RandomForestRegressor
regressor = RandomForestRegressor(n_estimators = 10, random_state = 0)
regressor.fit(X_train, y_train)

y_pred = regressor.predict(X_test)
np.set_printoptions(precision=2)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))

X_grid = np.arange(min(X), max(X), 0.01)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(X, y, color = 'red')
plt.plot(X_grid, regressor.predict(X_grid), color = 'blue')
plt.title('K/9 (Random Forest Regression)')
plt.xlabel('Age')
plt.ylabel('K/9')
plt.show()

#reshape y 
y = y.reshape(len(y),1)

from sklearn.metrics import mean_squared_error
print("MSE: " , mean_squared_error(y_test, y_pred))

from sklearn.metrics import r2_score
print("R2 Score: " , r2_score(y_test, y_pred))

print("Predicted KK/9 in 2021: " ,regressor.predict([[31]]))
# Out:
# [[ 8.62  8.28]
#  [ 8.91  8.85]
#  [ 9.54 10.  ]]
# MSE:  0.11087100000000011
# R2 Score:  0.783351643579834
# Predicted KK/9 in 2021:  [9.54]

# %%
#import data
col_list = ["Age", "BB/9"]
dataset = pd.read_csv('PadresRelievers.csv', usecols=col_list)
X = dataset.iloc[56:59, :-1].values
y = dataset.iloc[56:59, -1].values

from sklearn.model_selection import train_test_split
X_train = X
X_test = X
y_train = y
y_test = y

from sklearn.ensemble import RandomForestRegressor
regressor = RandomForestRegressor(n_estimators = 10, random_state = 0)
regressor.fit(X_train, y_train)

y_pred = regressor.predict(X_test)
np.set_printoptions(precision=2)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))

X_grid = np.arange(min(X), max(X), 0.01)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(X, y, color = 'red')
plt.plot(X_grid, regressor.predict(X_grid), color = 'blue')
plt.title('BB/9 (Random Forest Regression)')
plt.xlabel('Age')
plt.ylabel('BB/9')
plt.show()

#reshape y 
y = y.reshape(len(y),1)

from sklearn.metrics import mean_squared_error
print("MSE: " , mean_squared_error(y_test, y_pred))

from sklearn.metrics import r2_score
print("R2 Score: " , r2_score(y_test, y_pred))

print("Predicted BB/9 in 2021: " ,regressor.predict([[31]]))
# Out:
# [[2.84 2.76]
#  [2.94 2.95]
#  [2.98 3.  ]]
# MSE:  0.0023856666666666674
# R2 Score:  0.7768087318087322
# Predicted BB/9 in 2021:  [2.98]
