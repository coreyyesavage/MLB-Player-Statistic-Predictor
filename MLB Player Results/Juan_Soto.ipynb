# %%
#import packages
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

#import data
col_list = ["Age", "AVG"]
dataset = pd.read_csv('Top50batters.csv', usecols=col_list)
X = dataset.iloc[141:144, :-1].values
y = dataset.iloc[141:144, -1].values

print(X)
# Out:
# [[19]
#  [20]
#  [21]]

# %%
y_train = y
y_test = y
X_test = X
X_train = X

#reshape y 
y = y.reshape(len(y),1)

#Feature scaling the data
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
sc_y = StandardScaler()
X = sc_X.fit_transform(X)
y = sc_y.fit_transform(y)

#Train the SVR
from sklearn.svm import SVR
regressor = SVR(kernel = 'rbf')
regressor.fit(X, y)

#Predict a new result
print("Batting AVG for 2021: ", sc_y.inverse_transform(regressor.predict(sc_X.transform([[22]]))))

y_pred = sc_y.inverse_transform(regressor.predict(sc_X.transform(X_test)))
np.set_printoptions(precision=3)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))

from sklearn.metrics import mean_squared_error
print(mean_squared_error(y_test, y_pred))


X_grid = np.arange(min(sc_X.inverse_transform(X)), max(sc_X.inverse_transform(X)), 0.1)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(sc_X.inverse_transform(X), sc_y.inverse_transform(y), color = 'red')
plt.plot(X_grid, sc_y.inverse_transform(regressor.predict(sc_X.transform(X_grid))), color = 'blue')
plt.title('Juan Soto AVG (SVR)')
plt.xlabel('Age')
plt.ylabel('AVG')
plt.show()
# Out:
# Batting AVG for 2021:  [0.312]
# [[0.295 0.292]
#  [0.285 0.282]
#  [0.33  0.351]]
# 0.00015506716145088508
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)

# %%
#import data
col_list = ["Age", "SLG"]
dataset = pd.read_csv('Top50batters.csv', usecols=col_list)
X = dataset.iloc[141:144, :-1].values
y = dataset.iloc[141:144, -1].values

y_train = y
y_test = y
X_test = X
X_train = X

#reshape y 
y = y.reshape(len(y),1)

#Feature scaling the data
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
sc_y = StandardScaler()
X = sc_X.fit_transform(X)
y = sc_y.fit_transform(y)

#Train the SVR
from sklearn.svm import SVR
regressor = SVR(kernel = 'rbf')
regressor.fit(X, y)

#Predict a new result
print("SLG for 2021: ", sc_y.inverse_transform(regressor.predict(sc_X.transform([[22]]))))

y_pred = sc_y.inverse_transform(regressor.predict(sc_X.transform(X_test)))
np.set_printoptions(precision=3)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))

from sklearn.metrics import mean_squared_error
print(mean_squared_error(y_test, y_pred))


X_grid = np.arange(min(sc_X.inverse_transform(X)), max(sc_X.inverse_transform(X)), 0.1)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(sc_X.inverse_transform(X), sc_y.inverse_transform(y), color = 'red')
plt.plot(X_grid, sc_y.inverse_transform(regressor.predict(sc_X.transform(X_grid))), color = 'blue')
plt.title('Juan Soto SLG (SVR)')
plt.xlabel('Age')
plt.ylabel('SLG')
plt.show()
# Out:
# SLG for 2021:  [0.596]
# [[0.525 0.517]
#  [0.556 0.548]
#  [0.65  0.695]]
# 0.000719950623947775
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)

# %%
#import data
col_list = ["Age", "OBP"]
dataset = pd.read_csv('Top50batters.csv', usecols=col_list)
X = dataset.iloc[141:144, :-1].values
y = dataset.iloc[141:144, -1].values

y_train = y
y_test = y
X_test = X
X_train = X

#reshape y 
y = y.reshape(len(y),1)

#Feature scaling the data
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
sc_y = StandardScaler()
X = sc_X.fit_transform(X)
y = sc_y.fit_transform(y)

#Train the SVR
from sklearn.svm import SVR
regressor = SVR(kernel = 'rbf')
regressor.fit(X, y)

#Predict a new result
print("OBP for 2021: ", sc_y.inverse_transform(regressor.predict(sc_X.transform([[22]]))))

y_pred = sc_y.inverse_transform(regressor.predict(sc_X.transform(X_test)))
np.set_printoptions(precision=3)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))

from sklearn.metrics import mean_squared_error
print(mean_squared_error(y_test, y_pred))


X_grid = np.arange(min(sc_X.inverse_transform(X)), max(sc_X.inverse_transform(X)), 0.1)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(sc_X.inverse_transform(X), sc_y.inverse_transform(y), color = 'red')
plt.plot(X_grid, sc_y.inverse_transform(regressor.predict(sc_X.transform(X_grid))), color = 'blue')
plt.title('Juan Soto OBP (SVR)')
plt.xlabel('Age')
plt.ylabel('OBP')
plt.show()
# Out:
# OBP for 2021:  [0.437]
# [[0.41  0.406]
#  [0.405 0.401]
#  [0.462 0.49 ]]
# 0.0002691238479023198
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)

# %%
#import data
col_list = ["Age", "OPS"]
dataset = pd.read_csv('Top50batters.csv', usecols=col_list)
X = dataset.iloc[141:144, :-1].values
y = dataset.iloc[141:144, -1].values

y_train = y
y_test = y
X_test = X
X_train = X

#reshape y 
y = y.reshape(len(y),1)

#Feature scaling the data
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
sc_y = StandardScaler()
X = sc_X.fit_transform(X)
y = sc_y.fit_transform(y)

#Train the SVR
from sklearn.svm import SVR
regressor = SVR(kernel = 'rbf')
regressor.fit(X, y)

#Predict a new result
print("OPS for 2021: ", sc_y.inverse_transform(regressor.predict(sc_X.transform([[22]]))))

y_pred = sc_y.inverse_transform(regressor.predict(sc_X.transform(X_test)))
np.set_printoptions(precision=3)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))

from sklearn.metrics import mean_squared_error
print(mean_squared_error(y_test, y_pred))


X_grid = np.arange(min(sc_X.inverse_transform(X)), max(sc_X.inverse_transform(X)), 0.1)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(sc_X.inverse_transform(X), sc_y.inverse_transform(y), color = 'red')
plt.plot(X_grid, sc_y.inverse_transform(regressor.predict(sc_X.transform(X_grid))), color = 'blue')
plt.title('Juan Soto OPS (SVR)')
plt.xlabel('Age')
plt.ylabel('OPS')
plt.show()
# Out:
# OPS for 2021:  [1.033]
# [[0.935 0.923]
#  [0.961 0.949]
#  [1.111 1.185]]
# 0.0019114308870610164
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)

# %%
#import data
col_list = ["Age", "%G"]
dataset = pd.read_csv('Top50batters.csv', usecols=col_list)
X = dataset.iloc[141:144, :-1].values
y = dataset.iloc[141:144, -1].values

y_train = y
y_test = y
X_test = X
X_train = X

#reshape y 
y = y.reshape(len(y),1)

#Feature scaling the data
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
sc_y = StandardScaler()
X = sc_X.fit_transform(X)
y = sc_y.fit_transform(y)

#Train the SVR
from sklearn.svm import SVR
regressor = SVR(kernel = 'rbf')
regressor.fit(X, y)

#Predict a new result
print(" %G for 2021: ", sc_y.inverse_transform(regressor.predict(sc_X.transform([[22]]))))


y_pred = sc_y.inverse_transform(regressor.predict(sc_X.transform(X_test)))
np.set_printoptions(precision=3)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))

from sklearn.metrics import mean_squared_error
print(mean_squared_error(y_test, y_pred))


X_grid = np.arange(min(sc_X.inverse_transform(X)), max(sc_X.inverse_transform(X)), 0.1)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(sc_X.inverse_transform(X), sc_y.inverse_transform(y), color = 'red')
plt.plot(X_grid, sc_y.inverse_transform(regressor.predict(sc_X.transform(X_grid))), color = 'blue')
plt.title('Juan Soto %G (SVR)')
plt.xlabel('Age')
plt.ylabel('%G')
plt.show()
# Out:
#  %G for 2021:  [0.889]
# [[0.991 1.   ]
#  [0.917 0.926]
#  [0.822 0.783]]
# 0.0005432812019004412
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)

# %%
.889 * 162
# Out:
# 144.018

# %%
#import data
col_list = ["Age", "PA/G"]
dataset = pd.read_csv('Top50batters.csv', usecols=col_list)
X = dataset.iloc[141:144, :-1].values
y = dataset.iloc[141:144, -1].values

y_train = y
y_test = y
X_test = X
X_train = X

#reshape y 
y = y.reshape(len(y),1)

#Feature scaling the data
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
sc_y = StandardScaler()
X = sc_X.fit_transform(X)
y = sc_y.fit_transform(y)

#Train the SVR
from sklearn.svm import SVR
regressor = SVR(kernel = 'rbf')
regressor.fit(X, y)

#Predict a new result
print(" PA/G for 2021: ", sc_y.inverse_transform(regressor.predict(sc_X.transform([[22]]))))


y_pred = sc_y.inverse_transform(regressor.predict(sc_X.transform(X_test)))
np.set_printoptions(precision=3)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))

from sklearn.metrics import mean_squared_error
print(mean_squared_error(y_test, y_pred))


X_grid = np.arange(min(sc_X.inverse_transform(X)), max(sc_X.inverse_transform(X)), 0.1)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(sc_X.inverse_transform(X), sc_y.inverse_transform(y), color = 'red')
plt.plot(X_grid, sc_y.inverse_transform(regressor.predict(sc_X.transform(X_grid))), color = 'blue')
plt.title('Juan Soto PA/G (SVR)')
plt.xlabel('Age')
plt.ylabel('PA/G')
plt.show()
# Out:
#  PA/G for 2021:  [4.229]
# [[4.268 4.259]
#  [4.32  4.393]
#  [4.179 4.17 ]]
# 0.001830431792493544
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)

# %%
print(4.229 * 144, "At bats")
# Out:
# 608.976 At bats

# %%
#import data
col_list = ["Age", "HR/G"]
dataset = pd.read_csv('Top50batters.csv', usecols=col_list)
X = dataset.iloc[141:144, :-1].values
y = dataset.iloc[141:144, -1].values

y_train = y
y_test = y
X_test = X
X_train = X

#reshape y 
y = y.reshape(len(y),1)

#Feature scaling the data
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
sc_y = StandardScaler()
X = sc_X.fit_transform(X)
y = sc_y.fit_transform(y)

#Train the SVR
from sklearn.svm import SVR
regressor = SVR(kernel = 'rbf')
regressor.fit(X, y)

#Predict a new result
print(" HR/G for 2021: ", sc_y.inverse_transform(regressor.predict(sc_X.transform([[22]]))))


y_pred = sc_y.inverse_transform(regressor.predict(sc_X.transform(X_test)))
np.set_printoptions(precision=3)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))

from sklearn.metrics import mean_squared_error
print(mean_squared_error(y_test, y_pred))


X_grid = np.arange(min(sc_X.inverse_transform(X)), max(sc_X.inverse_transform(X)), 0.1)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(sc_X.inverse_transform(X), sc_y.inverse_transform(y), color = 'red')
plt.plot(X_grid, sc_y.inverse_transform(regressor.predict(sc_X.transform(X_grid))), color = 'blue')
plt.title('Juan Soto HR/G (SVR)')
plt.xlabel('Age')
plt.ylabel('HR')
plt.show()
# Out:
#  HR/G for 2021:  [0.237]
# [[0.194 0.19 ]
#  [0.229 0.227]
#  [0.265 0.277]]
# 5.344025278809033e-05
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)

# %%
.237 * 144
# Out:
# 34.128

# %%
#import data
col_list = ["Age", "RBI/G"]
dataset = pd.read_csv('Top50batters.csv', usecols=col_list)
X = dataset.iloc[141:144, :-1].values
y = dataset.iloc[141:144, -1].values

y_train = y
y_test = y
X_test = X
X_train = X

#reshape y 
y = y.reshape(len(y),1)

#Feature scaling the data
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
sc_y = StandardScaler()
X = sc_X.fit_transform(X)
y = sc_y.fit_transform(y)

#Train the SVR
from sklearn.svm import SVR
regressor = SVR(kernel = 'rbf')
regressor.fit(X, y)

#Predict a new result
print(" RBI/G for 2021: ", sc_y.inverse_transform(regressor.predict(sc_X.transform([[22]]))))


y_pred = sc_y.inverse_transform(regressor.predict(sc_X.transform(X_test)))
np.set_printoptions(precision=3)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))

from sklearn.metrics import mean_squared_error
print(mean_squared_error(y_test, y_pred))


X_grid = np.arange(min(sc_X.inverse_transform(X)), max(sc_X.inverse_transform(X)), 0.1)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(sc_X.inverse_transform(X), sc_y.inverse_transform(y), color = 'red')
plt.plot(X_grid, sc_y.inverse_transform(regressor.predict(sc_X.transform(X_grid))), color = 'blue')
plt.title('Fernando Tatis Jr RBI/G (SVR)')
plt.xlabel('Age')
plt.ylabel('RBI/G')
plt.show()
# Out:
#  RBI/G for 2021:  [0.728]
# [[0.64  0.603]
#  [0.726 0.733]
#  [0.78  0.787]]
# 0.0004953626851956235
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)

# %%
.728 * 144
# Out:
# 104.832

# %%
#import data
col_list = ["Age", "R/G"]
dataset = pd.read_csv('Top50batters.csv', usecols=col_list)
X = dataset.iloc[141:144, :-1].values
y = dataset.iloc[141:144, -1].values

y_train = y
y_test = y
X_test = X
X_train = X

#reshape y 
y = y.reshape(len(y),1)

#Feature scaling the data
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
sc_y = StandardScaler()
X = sc_X.fit_transform(X)
y = sc_y.fit_transform(y)

#Train the SVR
from sklearn.svm import SVR
regressor = SVR(kernel = 'rbf')
regressor.fit(X, y)

#Predict a new result
print(" R/G for 2021: ", sc_y.inverse_transform(regressor.predict(sc_X.transform([[22]]))))


y_pred = sc_y.inverse_transform(regressor.predict(sc_X.transform(X_test)))
np.set_printoptions(precision=3)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))

from sklearn.metrics import mean_squared_error
print(mean_squared_error(y_test, y_pred))


X_grid = np.arange(min(sc_X.inverse_transform(X)), max(sc_X.inverse_transform(X)), 0.1)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(sc_X.inverse_transform(X), sc_y.inverse_transform(y), color = 'red')
plt.plot(X_grid, sc_y.inverse_transform(regressor.predict(sc_X.transform(X_grid))), color = 'blue')
plt.title('Juan Soto R/G (SVR)')
plt.xlabel('Age')
plt.ylabel('R/G')
plt.show()
# Out:
#  R/G for 2021:  [0.755]
# [[0.671 0.664]
#  [0.739 0.733]
#  [0.807 0.83 ]]
# 0.00020122953954888653
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)

# %%
.755 * 144
# Out:
# 108.72

# %%
#import data
col_list = ["Age", "SB/G"]
dataset = pd.read_csv('Top50batters.csv', usecols=col_list)
X = dataset.iloc[141:144, :-1].values
y = dataset.iloc[141:144, -1].values

y_train = y
y_test = y
X_test = X
X_train = X

#reshape y 
y = y.reshape(len(y),1)

#Feature scaling the data
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
sc_y = StandardScaler()
X = sc_X.fit_transform(X)
y = sc_y.fit_transform(y)

#Train the SVR
from sklearn.svm import SVR
regressor = SVR(kernel = 'rbf')
regressor.fit(X, y)

#Predict a new result
print(" SB/G for 2021: ", sc_y.inverse_transform(regressor.predict(sc_X.transform([[22]]))))


y_pred = sc_y.inverse_transform(regressor.predict(sc_X.transform(X_test)))
np.set_printoptions(precision=3)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))

from sklearn.metrics import mean_squared_error
print(mean_squared_error(y_test, y_pred))


X_grid = np.arange(min(sc_X.inverse_transform(X)), max(sc_X.inverse_transform(X)), 0.1)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(sc_X.inverse_transform(X), sc_y.inverse_transform(y), color = 'red')
plt.plot(X_grid, sc_y.inverse_transform(regressor.predict(sc_X.transform(X_grid))), color = 'blue')
plt.title('Jaun Soto SB/G (SVR)')
plt.xlabel('Age')
plt.ylabel('SB/G')
plt.show()
# Out:
#  SB/G for 2021:  [0.09]
# [[0.048 0.043]
#  [0.082 0.08 ]
#  [0.117 0.128]]
# 4.820527526579732e-05
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)

# %%
.09 * 144
# Out:
# 12.959999999999999

# %%
#import data
col_list = ["Age", "2B/G"]
dataset = pd.read_csv('Top50batters.csv', usecols=col_list)
X = dataset.iloc[141:144, :-1].values
y = dataset.iloc[141:144, -1].values

y_train = y
y_test = y
X_test = X
X_train = X

#reshape y 
y = y.reshape(len(y),1)

#Feature scaling the data
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
sc_y = StandardScaler()
X = sc_X.fit_transform(X)
y = sc_y.fit_transform(y)

#Train the SVR
from sklearn.svm import SVR
regressor = SVR(kernel = 'rbf')
regressor.fit(X, y)

#Predict a new result
print(" 2B/G for 2021: ", sc_y.inverse_transform(regressor.predict(sc_X.transform([[22]]))))


y_pred = sc_y.inverse_transform(regressor.predict(sc_X.transform(X_test)))
np.set_printoptions(precision=3)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))

from sklearn.metrics import mean_squared_error
print(mean_squared_error(y_test, y_pred))


X_grid = np.arange(min(sc_X.inverse_transform(X)), max(sc_X.inverse_transform(X)), 0.1)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(sc_X.inverse_transform(X), sc_y.inverse_transform(y), color = 'red')
plt.plot(X_grid, sc_y.inverse_transform(regressor.predict(sc_X.transform(X_grid))), color = 'blue')
plt.title('Juan Soto 2B/G (SVR)')
plt.xlabel('Age')
plt.ylabel('2B/G')
plt.show()
# Out:
#  2B/G for 2021:  [0.247]
# [[0.219 0.216]
#  [0.217 0.213]
#  [0.271 0.298]]
# 0.0002447869298354179
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)

# %%
.247 * 144
# Out:
# 35.568

# %%
#import data
col_list = ["Age", "3B/G"]
dataset = pd.read_csv('Top50batters.csv', usecols=col_list)
X = dataset.iloc[141:144, :-1].values
y = dataset.iloc[141:144, -1].values

y_train = y
y_test = y
X_test = X
X_train = X

#reshape y 
y = y.reshape(len(y),1)

#Feature scaling the data
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
sc_y = StandardScaler()
X = sc_X.fit_transform(X)
y = sc_y.fit_transform(y)

#Train the SVR
from sklearn.svm import SVR
regressor = SVR(kernel = 'rbf')
regressor.fit(X, y)

#Predict a new result
print(" 3B/G for 2021: ", sc_y.inverse_transform(regressor.predict(sc_X.transform([[22]]))))


y_pred = sc_y.inverse_transform(regressor.predict(sc_X.transform(X_test)))
np.set_printoptions(precision=3)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))

from sklearn.metrics import mean_squared_error
print(mean_squared_error(y_test, y_pred))


X_grid = np.arange(min(sc_X.inverse_transform(X)), max(sc_X.inverse_transform(X)), 0.1)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(sc_X.inverse_transform(X), sc_y.inverse_transform(y), color = 'red')
plt.plot(X_grid, sc_y.inverse_transform(regressor.predict(sc_X.transform(X_grid))), color = 'blue')
plt.title('Juan Soto 3B/G (SVR)')
plt.xlabel('Age')
plt.ylabel('3B/G')
plt.show()
# Out:
#  3B/G for 2021:  [0.007]
# [[0.01  0.009]
#  [0.021 0.033]
#  [0.001 0.   ]]
# 5.51499659138826e-05
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)

# %%
.007 * 144
# Out:
# 1.008

# %%
#import data
col_list = ["Age", "WAR/G"]
dataset = pd.read_csv('Top50batters.csv', usecols=col_list)
X = dataset.iloc[141:144, :-1].values
y = dataset.iloc[141:144, -1].values

y_train = y
y_test = y
X_test = X
X_train = X

#reshape y 
y = y.reshape(len(y),1)

#Feature scaling the data
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
sc_y = StandardScaler()
X = sc_X.fit_transform(X)
y = sc_y.fit_transform(y)

#Train the SVR
from sklearn.svm import SVR
regressor = SVR(kernel = 'rbf')
regressor.fit(X, y)

#Predict a new result
print(" WAR for 2021: ", sc_y.inverse_transform(regressor.predict(sc_X.transform([[22]]))))


y_pred = sc_y.inverse_transform(regressor.predict(sc_X.transform(X_test)))
np.set_printoptions(precision=3)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))

from sklearn.metrics import mean_squared_error
print(mean_squared_error(y_test, y_pred))


X_grid = np.arange(min(sc_X.inverse_transform(X)), max(sc_X.inverse_transform(X)), 0.1)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(sc_X.inverse_transform(X), sc_y.inverse_transform(y), color = 'red')
plt.plot(X_grid, sc_y.inverse_transform(regressor.predict(sc_X.transform(X_grid))), color = 'blue')
plt.title('Juan Soto WAR (SVR)')
plt.xlabel('Age')
plt.ylabel('WAR')
plt.show()
# Out:
#  WAR for 2021:  [0.04]
# [[0.033 0.032]
#  [0.034 0.033]
#  [0.045 0.051]]
# 1.1680582870517282e-05
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)

# %%
.04*144
# Out:
# 5.76
