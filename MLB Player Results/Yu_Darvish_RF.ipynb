# %%
#import packages
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

#import data
col_list = ["Name","Age", "ERA"]
dataset = pd.read_csv('PadresPitchers.csv', usecols=col_list)
X = dataset.iloc[56:64, :-1].values
y = dataset.iloc[56:64, -1].values

print(X)
# Out:
# [['Yu Darvish' 25]
#  ['Yu Darvish' 26]
#  ['Yu Darvish' 27]
#  ['Yu Darvish' 29]
#  ['Yu Darvish' 30]
#  ['Yu Darvish' 31]
#  ['Yu Darvish' 32]
#  ['Yu Darvish' 33]]

# %%
#import data
col_list = ["Age", "ERA"]
dataset = pd.read_csv('PadresPitchers.csv', usecols=col_list)
X = dataset.iloc[56:64, :-1].values
y = dataset.iloc[56:64, -1].values

from sklearn.model_selection import train_test_split
X_train = X
X_test = X
y_train = y
y_test = y

from sklearn.ensemble import RandomForestRegressor
regressor = RandomForestRegressor(n_estimators = 10, random_state = 0)
regressor.fit(X_train, y_train)

y_pred = regressor.predict(X_test)
np.set_printoptions(precision=2)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))

X_grid = np.arange(min(X), max(X), 0.01)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(X, y, color = 'red')
plt.plot(X_grid, regressor.predict(X_grid), color = 'blue')
plt.title('ERA (Random Forest Regression)')
plt.xlabel('Age')
plt.ylabel('ERA')
plt.show()

#reshape y 
y = y.reshape(len(y),1)

from sklearn.metrics import mean_squared_error
print("MSE: " , mean_squared_error(y_test, y_pred))

from sklearn.metrics import r2_score
print("R2 Score: " , r2_score(y_test, y_pred))

print("Predicted ERA in 2021: " ,regressor.predict([[34]]))
# Out:
# [[3.49 3.9 ]
#  [3.07 2.83]
#  [3.1  3.06]
#  [3.5  3.41]
#  [3.77 3.86]
#  [4.47 4.95]
#  [3.97 3.98]
#  [3.19 2.01]]
# MSE:  0.23240949999999974
# R2 Score:  0.6615313478482492
# Predicted ERA in 2021:  [3.19]

# %%
#import data
col_list = ["Age", "WHIP"]
dataset = pd.read_csv('PadresPitchers.csv', usecols=col_list)
X = dataset.iloc[56:64, :-1].values
y = dataset.iloc[56:64, -1].values

from sklearn.model_selection import train_test_split
X_train = X
X_test = X
y_train = y
y_test = y

from sklearn.ensemble import RandomForestRegressor
regressor = RandomForestRegressor(n_estimators = 10, random_state = 0)
regressor.fit(X_train, y_train)

y_pred = regressor.predict(X_test)
np.set_printoptions(precision=2)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))

X_grid = np.arange(min(X), max(X), 0.01)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(X, y, color = 'red')
plt.plot(X_grid, regressor.predict(X_grid), color = 'blue')
plt.title('WHIP (Random Forest Regression)')
plt.xlabel('Age')
plt.ylabel('WHIP')
plt.show()

#reshape y 
y = y.reshape(len(y),1)

from sklearn.metrics import mean_squared_error
print("MSE: " , mean_squared_error(y_test, y_pred))

from sklearn.metrics import r2_score
print("R2 Score: " , r2_score(y_test, y_pred))

print("Predicted WHIP in 2021: " ,regressor.predict([[34]]))
# Out:
# [[1.22 1.28]
#  [1.13 1.07]
#  [1.22 1.26]
#  [1.13 1.12]
#  [1.15 1.16]
#  [1.32 1.43]
#  [1.2  1.1 ]
#  [1.1  0.96]]
# MSE:  0.0064032499999999975
# R2 Score:  0.6570070304653499
# Predicted WHIP in 2021:  [1.1]

# %%
#import data
col_list = ["Age", "AVG"]
dataset = pd.read_csv('PadresPitchers.csv', usecols=col_list)
X = dataset.iloc[56:64, :-1].values
y = dataset.iloc[56:64, -1].values

from sklearn.model_selection import train_test_split
X_train = X
X_test = X
y_train = y
y_test = y

from sklearn.ensemble import RandomForestRegressor
regressor = RandomForestRegressor(n_estimators = 10, random_state = 0)
regressor.fit(X_train, y_train)

y_pred = regressor.predict(X_test)
np.set_printoptions(precision=2)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))

X_grid = np.arange(min(X), max(X), 0.01)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(X, y, color = 'red')
plt.plot(X_grid, regressor.predict(X_grid), color = 'blue')
plt.title('AVG (Random Forest Regression)')
plt.xlabel('Age')
plt.ylabel('AVG')
plt.show()

#reshape y 
y = y.reshape(len(y),1)

from sklearn.metrics import mean_squared_error
print("MSE: " , mean_squared_error(y_test, y_pred))

from sklearn.metrics import r2_score
print("R2 Score: " , r2_score(y_test, y_pred))

print("Predicted AVG in 2021: " ,regressor.predict([[34]]))
# Out:
# [[0.21 0.22]
#  [0.2  0.19]
#  [0.23 0.24]
#  [0.21 0.21]
#  [0.22 0.23]
#  [0.23 0.23]
#  [0.22 0.21]
#  [0.21 0.21]]
# MSE:  4.7023749999999944e-05
# R2 Score:  0.7520988467874795
# Predicted AVG in 2021:  [0.21]

# %%
#import data
col_list = ["Age", "K/9"]
dataset = pd.read_csv('PadresPitchers.csv', usecols=col_list)
X = dataset.iloc[56:64, :-1].values
y = dataset.iloc[56:64, -1].values

from sklearn.model_selection import train_test_split
X_train = X
X_test = X
y_train = y
y_test = y

from sklearn.ensemble import RandomForestRegressor
regressor = RandomForestRegressor(n_estimators = 10, random_state = 0)
regressor.fit(X_train, y_train)

y_pred = regressor.predict(X_test)
np.set_printoptions(precision=2)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))

X_grid = np.arange(min(X), max(X), 0.01)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(X, y, color = 'red')
plt.plot(X_grid, regressor.predict(X_grid), color = 'blue')
plt.title('K/9 (Random Forest Regression)')
plt.xlabel('Age')
plt.ylabel('K/9')
plt.show()

#reshape y 
y = y.reshape(len(y),1)

from sklearn.metrics import mean_squared_error
print("MSE: " , mean_squared_error(y_test, y_pred))

from sklearn.metrics import r2_score
print("R2 Score: " , r2_score(y_test, y_pred))

print("Predicted K/9 in 2021: " ,regressor.predict([[34]]))
# Out:
# [[10.94 10.4 ]
#  [11.54 11.89]
#  [11.36 11.35]
#  [11.49 11.84]
#  [10.43 10.08]
#  [10.83 11.03]
#  [11.23 11.54]
#  [11.17 11.01]]
# MSE:  0.10374125000000006
# R2 Score:  0.719310053267946
# Predicted K/9 in 2021:  [11.17]

# %%
#import data
col_list = ["Age", "BB/9"]
dataset = pd.read_csv('PadresPitchers.csv', usecols=col_list)
X = dataset.iloc[56:64, :-1].values
y = dataset.iloc[56:64, -1].values

from sklearn.model_selection import train_test_split
X_train = X
X_test = X
y_train = y
y_test = y

from sklearn.ensemble import RandomForestRegressor
regressor = RandomForestRegressor(n_estimators = 10, random_state = 0)
regressor.fit(X_train, y_train)

y_pred = regressor.predict(X_test)
np.set_printoptions(precision=2)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))

X_grid = np.arange(min(X), max(X), 0.01)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(X, y, color = 'red')
plt.plot(X_grid, regressor.predict(X_grid), color = 'blue')
plt.title('BB/9 (Random Forest Regression)')
plt.xlabel('Age')
plt.ylabel('BB/9')
plt.show()

#reshape y 
y = y.reshape(len(y),1)

from sklearn.metrics import mean_squared_error
print("MSE: " , mean_squared_error(y_test, y_pred))

from sklearn.metrics import r2_score
print("R2 Score: " , r2_score(y_test, y_pred))

print("Predicted BB/9 in 2021: " ,regressor.predict([[34]]))
# Out:
# [[3.85 4.19]
#  [3.55 3.43]
#  [3.25 3.06]
#  [2.78 2.78]
#  [2.8  2.8 ]
#  [3.96 4.73]
#  [3.35 2.82]
#  [2.62 1.66]]
# MSE:  0.2465063750000002
# R2 Score:  0.6841578929455878
# Predicted BB/9 in 2021:  [2.62]

# %%
#import data
col_list = ["Age", "ADJ_IP"]
dataset = pd.read_csv('PadresPitchers.csv', usecols=col_list)
X = dataset.iloc[56:64, :-1].values
y = dataset.iloc[56:64, -1].values

from sklearn.model_selection import train_test_split
X_train = X
X_test = X
y_train = y
y_test = y

from sklearn.ensemble import RandomForestRegressor
regressor = RandomForestRegressor(n_estimators = 10, random_state = 0)
regressor.fit(X_train, y_train)

y_pred = regressor.predict(X_test)
np.set_printoptions(precision=2)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))

X_grid = np.arange(min(X), max(X), 0.01)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(X, y, color = 'red')
plt.plot(X_grid, regressor.predict(X_grid), color = 'blue')
plt.title('ADJ_IP (Random Forest Regression)')
plt.xlabel('Age')
plt.ylabel('IP')
plt.show()

#reshape y 
y = y.reshape(len(y),1)

from sklearn.metrics import mean_squared_error
print("MSE: " , mean_squared_error(y_test, y_pred))

from sklearn.metrics import r2_score
print("R2 Score: " , r2_score(y_test, y_pred))

print("Predicted IP in 2021: " ,regressor.predict([[34]]))
# Out:
# [[191.83 191.1 ]
#  [199.07 209.2 ]
#  [161.82 144.1 ]
#  [117.32 100.1 ]
#  [168.98 186.2 ]
#  [ 89.87  40.  ]
#  [128.32 178.2 ]
#  [164.06 205.2 ]]
# MSE:  959.7169874999995
# R2 Score:  0.6879671695869696
# Predicted IP in 2021:  [164.06]

# %%
#import data
col_list = ["Age", "ADJ_GS"]
dataset = pd.read_csv('PadresPitchers.csv', usecols=col_list)
X = dataset.iloc[56:64, :-1].values
y = dataset.iloc[56:64, -1].values

from sklearn.model_selection import train_test_split
X_train = X
X_test = X
y_train = y
y_test = y

from sklearn.ensemble import RandomForestRegressor
regressor = RandomForestRegressor(n_estimators = 10, random_state = 0)
regressor.fit(X_train, y_train)

y_pred = regressor.predict(X_test)
np.set_printoptions(precision=2)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))

X_grid = np.arange(min(X), max(X), 0.01)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(X, y, color = 'red')
plt.plot(X_grid, regressor.predict(X_grid), color = 'blue')
plt.title('GS (Random Forest Regression)')
plt.xlabel('Age')
plt.ylabel('GS')
plt.show()

#reshape y 
y = y.reshape(len(y),1)

from sklearn.metrics import mean_squared_error
print("MSE: " , mean_squared_error(y_test, y_pred))

from sklearn.metrics import r2_score
print("R2 Score: " , r2_score(y_test, y_pred))

print("Predicted GS in 2021: " ,regressor.predict([[34]]))
# Out:
# [[29.2  29.  ]
#  [30.4  32.  ]
#  [24.7  22.  ]
#  [19.8  17.  ]
#  [28.2  31.  ]
#  [15.8   8.  ]
#  [22.08 31.  ]
#  [27.1  32.4 ]]
# MSE:  24.2583
# R2 Score:  0.6490915666136265
# Predicted GS in 2021:  [27.1]
